# %%
import numpy as np
import pandas as pd
from pathlib import Path
import random
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder

# --- CONFIG ---
DATA_DIR = Path("/kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask")
BATCH_SIZE = 32
EPOCHS = 150 # OneCycle handles convergence faster
MAX_LR = 6e-4 # Peak LR for OneCycle
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
MAX_FRAMES = 120
# Early stopping
PATIENCE = 25
pat_counter = 0      # counts epochs with no improvement
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(SEED)

# --- DATA LOADING ---
df = pd.read_csv(DATA_DIR / "splits/splits.csv")
df["filepath"] = df["filepath"].str.replace("\\", "/", regex=False)
df["full_path"] = df["filepath"].apply(lambda x: DATA_DIR / "splits" / x)
le = LabelEncoder()
df["label_id"] = le.fit_transform(df["label"])
num_classes = len(le.classes_)
# ✅ Save LabelEncoder as .npy
np.save("label_classes.npy", le.classes_)
train_df = df[df["split"] == "train"].reset_index(drop=True)
val_df   = df[df["split"] == "val"].reset_index(drop=True)
test_df  = df[df["split"] == "test"].reset_index(drop=True)

# --- ENHANCED DATASET ---
class ASLDataset(Dataset):
    def __init__(self, df, train=True):
        self.df = df
        self.train = train
    def pad_or_truncate(self, x):
        if x.shape[0] > MAX_FRAMES: return x[:MAX_FRAMES]
        elif x.shape[0] < MAX_FRAMES:
            pad = np.zeros((MAX_FRAMES - x.shape[0], x.shape[1]))
            return np.vstack([x, pad])
        return x
    def augment(self, x):
        if self.train:
            # Spatial scaling (simulates distance from camera)
            if random.random() < 0.5:
                scale = np.random.uniform(0.85, 1.15)
                x = x * scale
            # Pointwise jitter
            if random.random() < 0.4:
                x += np.random.normal(0, 0.002, x.shape)
        return x
    def __len__(self): return len(self.df)
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        x = np.load(row["full_path"])
        x = self.pad_or_truncate(x)
        x = self.augment(x)
        return torch.tensor(x, dtype=torch.float32), torch.tensor(row["label_id"])

# --- LOADERS ---
class_counts = (
    train_df["label_id"]
    .value_counts()
    .reindex(range(num_classes), fill_value=0)
    .values
)
class_weights = 1.0 / (class_counts + 1e-6)

sample_weights = train_df["label_id"].map(lambda x: class_weights[x]).values
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))

train_loader = DataLoader(ASLDataset(train_df, True), batch_size=BATCH_SIZE, sampler=sampler)
val_loader   = DataLoader(ASLDataset(val_df, False), batch_size=BATCH_SIZE)
test_loader  = DataLoader(ASLDataset(test_df, False), batch_size=BATCH_SIZE)

# --- ENHANCED MODEL ---
class ResidualBlock(nn.Module):
    def __init__(self, dim, drop_path=0.1):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(dim, dim, 3, padding=1, groups=dim), # Depthwise
            nn.Conv1d(dim, dim, 1), # Pointwise
            nn.BatchNorm1d(dim),
            nn.GELU(),
            nn.Dropout(drop_path),
            nn.Conv1d(dim, dim, 3, padding=1),
            nn.BatchNorm1d(dim)
        )
    def forward(self, x): 
        return x + self.conv(x)

class ASLModel(nn.Module):
    def __init__(self, input_dim=438, num_classes=105):
        super().__init__()
        self.input_bn = nn.BatchNorm1d(input_dim)
        self.stem = nn.Sequential(
            nn.Conv1d(input_dim, 256, 7, padding=3),
            nn.BatchNorm1d(256),
            nn.GELU()
        )
        self.res_layers = nn.Sequential(*[ResidualBlock(256) for _ in range(3)])
        self.lstm = nn.LSTM(256, 256, num_layers=2, batch_first=True, bidirectional=True, dropout=0.5)
        
        self.attention = nn.Sequential(
            nn.Linear(512, 128),
            nn.GELU(),
            nn.Linear(128, 1)
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.GELU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = x.transpose(1, 2)
        x = self.input_bn(x)
        x = self.stem(x)
        x = self.res_layers(x)
        x = x.transpose(1, 2) 
        lstm_out, _ = self.lstm(x) 
        
        attn_weights = torch.softmax(self.attention(lstm_out), dim=1)
        context = torch.sum(attn_weights * lstm_out, dim=1)
        return self.classifier(context)

model = ASLModel(num_classes=num_classes).to(DEVICE)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.AdamW(model.parameters(), lr=MAX_LR, weight_decay=0.05)

# OneCycleLR is better for fine-tuning
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=MAX_LR, steps_per_epoch=len(train_loader), epochs=EPOCHS
)

# --- TRAINING LOOP ---
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
best_val = 0
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
best_val = 0

pat_counter = 0
for epoch in range(EPOCHS):
    model.train()
    train_loss, train_correct, total = 0, 0, 0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        
        # Probabilistic Mixup
        if random.random() < 0.5:
            lam = np.random.beta(0.2, 0.2)
            perm = torch.randperm(x.size(0)).to(DEVICE)
            outputs = model(lam * x + (1 - lam) * x[perm])
            loss = lam * criterion(outputs, y) + (1 - lam) * criterion(outputs, y[perm])
            train_correct += (lam * (outputs.argmax(1) == y).sum().item() + (1 - lam) * (outputs.argmax(1) == y[perm]).sum().item())
        else:
            outputs = model(x)
            loss = criterion(outputs, y)
            train_correct += (outputs.argmax(1) == y).sum().item()

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        
        train_loss += loss.item() * y.size(0)
        total += y.size(0)

    # Validation
    model.eval()
    val_loss, val_correct, total_val = 0, 0, 0
    with torch.no_grad():
        for x, y in val_loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            outputs = model(x)
            v_loss = criterion(outputs, y)
            val_loss += v_loss.item() * y.size(0)
            val_correct += (outputs.argmax(1) == y).sum().item()
            total_val += y.size(0)
    
    t_loss, t_acc = train_loss/total, train_correct/total
    v_loss, v_acc = val_loss/total_val, val_correct/total_val
    for k, v in zip(history.keys(), [t_loss, v_loss, t_acc, v_acc]): history[k].append(v)

    print(f"Epoch {epoch+1:03d} | T-Loss: {t_loss:.3f} | T-Acc: {t_acc:.3f} | V-Loss: {v_loss:.3f} | V-Acc: {v_acc:.3f}")

    if v_acc > best_val:
        best_val = v_acc
        pat_counter = 0  # reset counter if improvement
        torch.save({
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "label_classes": le.classes_,
            "config": {
                "input_dim": 438,
                "num_classes": num_classes,
                "MAX_FRAMES": MAX_FRAMES
            },
            "best_val_acc": best_val
        }, "best_refined_model.pth")
        print(f"Epoch {epoch+1}: New best validation accuracy {v_acc:.4f}, model saved.")
    else:
        pat_counter += 1
        print(f" No improvement for {pat_counter} epochs.")
        if pat_counter >= PATIENCE:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break
import json

with open("training_history.json", "w") as f:
    json.dump(history, f)
# --- PLOTTING ---
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1); plt.plot(history["train_loss"], label="Train"); plt.plot(history["val_loss"], label="Val"); plt.title("Refined Loss"); plt.legend()
plt.subplot(1, 2, 2); plt.plot(history["train_acc"], label="Train"); plt.plot(history["val_acc"], label="Val"); plt.title("Refined Accuracy"); plt.legend()
plt.savefig("training_curves.png")
plt.show()

# --- FINAL TEST ---
checkpoint = torch.load("best_refined_model.pth", map_location=DEVICE, weights_only=False)

model.load_state_dict(checkpoint["model_state_dict"])
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

# restore label encoder from checkpoint
le.classes_ = checkpoint["label_classes"]
model.eval()
preds, labels = [], []
with torch.no_grad():
    for x, y in test_loader:
        out = model(x.to(DEVICE))
        preds.extend(out.argmax(1).cpu().numpy())
        labels.extend(y.numpy())

print(f"\nFinal Test Accuracy: {np.mean(np.array(preds) == np.array(labels)):.4f}")
# Out:
# Epoch 001 | T-Loss: 4.625 | T-Acc: 0.024 | V-Loss: 4.507 | V-Acc: 0.049
# Epoch 1: New best validation accuracy 0.0486, model saved.
# Epoch 002 | T-Loss: 4.380 | T-Acc: 0.072 | V-Loss: 4.254 | V-Acc: 0.130
# Epoch 2: New best validation accuracy 0.1296, model saved.
# Epoch 003 | T-Loss: 4.219 | T-Acc: 0.094 | V-Loss: 4.072 | V-Acc: 0.164
# Epoch 3: New best validation accuracy 0.1644, model saved.
# Epoch 004 | T-Loss: 4.015 | T-Acc: 0.161 | V-Loss: 3.841 | V-Acc: 0.222
# Epoch 4: New best validation accuracy 0.2222, model saved.
# Epoch 005 | T-Loss: 3.825 | T-Acc: 0.212 | V-Loss: 3.582 | V-Acc: 0.278
# Epoch 5: New best validation accuracy 0.2778, model saved.
# Epoch 006 | T-Loss: 3.650 | T-Acc: 0.265 | V-Loss: 3.322 | V-Acc: 0.308
# Epoch 6: New best validation accuracy 0.3079, model saved.
# Epoch 007 | T-Loss: 3.388 | T-Acc: 0.345 | V-Loss: 3.155 | V-Acc: 0.363
# Epoch 7: New best validation accuracy 0.3634, model saved.
# Epoch 008 | T-Loss: 3.221 | T-Acc: 0.393 | V-Loss: 2.881 | V-Acc: 0.440
# Epoch 8: New best validation accuracy 0.4398, model saved.
# Epoch 009 | T-Loss: 2.956 | T-Acc: 0.474 | V-Loss: 2.733 | V-Acc: 0.481
# Epoch 9: New best validation accuracy 0.4815, model saved.
# Epoch 010 | T-Loss: 2.807 | T-Acc: 0.512 | V-Loss: 2.465 | V-Acc: 0.539
# Epoch 10: New best validation accuracy 0.5394, model saved.
# Epoch 011 | T-Loss: 2.591 | T-Acc: 0.558 | V-Loss: 2.284 | V-Acc: 0.576
# Epoch 11: New best validation accuracy 0.5764, model saved.
# Epoch 012 | T-Loss: 2.436 | T-Acc: 0.610 | V-Loss: 2.215 | V-Acc: 0.581
# Epoch 12: New best validation accuracy 0.5810, model saved.
# Epoch 013 | T-Loss: 2.332 | T-Acc: 0.621 | V-Loss: 2.067 | V-Acc: 0.616
# Epoch 13: New best validation accuracy 0.6157, model saved.
# Epoch 014 | T-Loss: 2.230 | T-Acc: 0.645 | V-Loss: 2.057 | V-Acc: 0.597
#  No improvement for 1 epochs.
# Epoch 015 | T-Loss: 2.146 | T-Acc: 0.665 | V-Loss: 2.166 | V-Acc: 0.556
#  No improvement for 2 epochs.
# Epoch 016 | T-Loss: 1.925 | T-Acc: 0.710 | V-Loss: 1.879 | V-Acc: 0.664
# Epoch 16: New best validation accuracy 0.6644, model saved.
# Epoch 017 | T-Loss: 1.791 | T-Acc: 0.749 | V-Loss: 1.835 | V-Acc: 0.667
# Epoch 17: New best validation accuracy 0.6667, model saved.
# Epoch 018 | T-Loss: 1.771 | T-Acc: 0.753 | V-Loss: 1.728 | V-Acc: 0.704
# Epoch 18: New best validation accuracy 0.7037, model saved.
# Epoch 019 | T-Loss: 1.737 | T-Acc: 0.756 | V-Loss: 1.786 | V-Acc: 0.681
#  No improvement for 1 epochs.
# Epoch 020 | T-Loss: 1.725 | T-Acc: 0.762 | V-Loss: 1.762 | V-Acc: 0.685
#  No improvement for 2 epochs.
# Epoch 021 | T-Loss: 1.739 | T-Acc: 0.762 | V-Loss: 1.669 | V-Acc: 0.713
# Epoch 21: New best validation accuracy 0.7130, model saved.
# Epoch 022 | T-Loss: 1.674 | T-Acc: 0.775 | V-Loss: 1.757 | V-Acc: 0.718
# Epoch 22: New best validation accuracy 0.7176, model saved.
# Epoch 023 | T-Loss: 1.778 | T-Acc: 0.745 | V-Loss: 1.727 | V-Acc: 0.708
#  No improvement for 1 epochs.
# Epoch 024 | T-Loss: 1.825 | T-Acc: 0.747 | V-Loss: 1.761 | V-Acc: 0.715
#  No improvement for 2 epochs.
# Epoch 025 | T-Loss: 1.701 | T-Acc: 0.773 | V-Loss: 1.699 | V-Acc: 0.725
# Epoch 25: New best validation accuracy 0.7245, model saved.
# Epoch 026 | T-Loss: 1.524 | T-Acc: 0.819 | V-Loss: 1.743 | V-Acc: 0.718
#  No improvement for 1 epochs.
# Epoch 027 | T-Loss: 1.744 | T-Acc: 0.765 | V-Loss: 1.787 | V-Acc: 0.697
#  No improvement for 2 epochs.
# Epoch 028 | T-Loss: 1.744 | T-Acc: 0.767 | V-Loss: 1.685 | V-Acc: 0.736
# Epoch 28: New best validation accuracy 0.7361, model saved.
# Epoch 029 | T-Loss: 1.757 | T-Acc: 0.767 | V-Loss: 1.697 | V-Acc: 0.736
#  No improvement for 1 epochs.
# Epoch 030 | T-Loss: 1.697 | T-Acc: 0.773 | V-Loss: 1.795 | V-Acc: 0.706
#  No improvement for 2 epochs.
# Epoch 031 | T-Loss: 1.725 | T-Acc: 0.775 | V-Loss: 1.686 | V-Acc: 0.752
# Epoch 31: New best validation accuracy 0.7523, model saved.
# Epoch 032 | T-Loss: 1.727 | T-Acc: 0.767 | V-Loss: 1.758 | V-Acc: 0.685
#  No improvement for 1 epochs.
# Epoch 033 | T-Loss: 1.710 | T-Acc: 0.776 | V-Loss: 1.744 | V-Acc: 0.729
#  No improvement for 2 epochs.
# Epoch 034 | T-Loss: 1.717 | T-Acc: 0.781 | V-Loss: 1.605 | V-Acc: 0.759
# Epoch 34: New best validation accuracy 0.7593, model saved.
# Epoch 035 | T-Loss: 1.622 | T-Acc: 0.804 | V-Loss: 1.624 | V-Acc: 0.750
#  No improvement for 1 epochs.
# Epoch 036 | T-Loss: 1.507 | T-Acc: 0.823 | V-Loss: 1.604 | V-Acc: 0.771
# Epoch 36: New best validation accuracy 0.7708, model saved.
# Epoch 037 | T-Loss: 1.558 | T-Acc: 0.825 | V-Loss: 1.642 | V-Acc: 0.762
#  No improvement for 1 epochs.
# Epoch 038 | T-Loss: 1.541 | T-Acc: 0.834 | V-Loss: 1.917 | V-Acc: 0.671
#  No improvement for 2 epochs.
# Epoch 039 | T-Loss: 1.610 | T-Acc: 0.818 | V-Loss: 1.693 | V-Acc: 0.731
#  No improvement for 3 epochs.
# Epoch 040 | T-Loss: 1.421 | T-Acc: 0.858 | V-Loss: 1.725 | V-Acc: 0.711
#  No improvement for 4 epochs.
# Epoch 041 | T-Loss: 1.667 | T-Acc: 0.797 | V-Loss: 1.621 | V-Acc: 0.752
#  No improvement for 5 epochs.
# Epoch 042 | T-Loss: 1.571 | T-Acc: 0.829 | V-Loss: 1.477 | V-Acc: 0.801
# Epoch 42: New best validation accuracy 0.8009, model saved.
# Epoch 043 | T-Loss: 1.461 | T-Acc: 0.852 | V-Loss: 1.583 | V-Acc: 0.750
#  No improvement for 1 epochs.
# Epoch 044 | T-Loss: 1.549 | T-Acc: 0.836 | V-Loss: 1.547 | V-Acc: 0.778
#  No improvement for 2 epochs.
# Epoch 045 | T-Loss: 1.567 | T-Acc: 0.828 | V-Loss: 1.510 | V-Acc: 0.785
#  No improvement for 3 epochs.
# Epoch 046 | T-Loss: 1.446 | T-Acc: 0.864 | V-Loss: 1.488 | V-Acc: 0.803
# Epoch 46: New best validation accuracy 0.8032, model saved.
# Epoch 047 | T-Loss: 1.357 | T-Acc: 0.886 | V-Loss: 1.452 | V-Acc: 0.824
# Epoch 47: New best validation accuracy 0.8241, model saved.
# Epoch 048 | T-Loss: 1.316 | T-Acc: 0.898 | V-Loss: 1.566 | V-Acc: 0.764
#  No improvement for 1 epochs.
# Epoch 049 | T-Loss: 1.413 | T-Acc: 0.871 | V-Loss: 1.523 | V-Acc: 0.775
#  No improvement for 2 epochs.
# Epoch 050 | T-Loss: 1.337 | T-Acc: 0.889 | V-Loss: 1.407 | V-Acc: 0.806
#  No improvement for 3 epochs.
# Epoch 051 | T-Loss: 1.434 | T-Acc: 0.882 | V-Loss: 1.376 | V-Acc: 0.824
#  No improvement for 4 epochs.
# Epoch 052 | T-Loss: 1.409 | T-Acc: 0.886 | V-Loss: 1.502 | V-Acc: 0.803
#  No improvement for 5 epochs.
# Epoch 053 | T-Loss: 1.380 | T-Acc: 0.883 | V-Loss: 1.418 | V-Acc: 0.810
#  No improvement for 6 epochs.
# Epoch 054 | T-Loss: 1.284 | T-Acc: 0.906 | V-Loss: 1.391 | V-Acc: 0.817
#  No improvement for 7 epochs.
# Epoch 055 | T-Loss: 1.173 | T-Acc: 0.931 | V-Loss: 1.404 | V-Acc: 0.815
#  No improvement for 8 epochs.
# Epoch 056 | T-Loss: 1.338 | T-Acc: 0.899 | V-Loss: 1.398 | V-Acc: 0.822
#  No improvement for 9 epochs.
# Epoch 057 | T-Loss: 1.420 | T-Acc: 0.871 | V-Loss: 1.412 | V-Acc: 0.810
#  No improvement for 10 epochs.
# Epoch 058 | T-Loss: 1.399 | T-Acc: 0.878 | V-Loss: 1.350 | V-Acc: 0.838
# Epoch 58: New best validation accuracy 0.8380, model saved.
# Epoch 059 | T-Loss: 1.270 | T-Acc: 0.911 | V-Loss: 1.389 | V-Acc: 0.824
#  No improvement for 1 epochs.
# Epoch 060 | T-Loss: 1.213 | T-Acc: 0.925 | V-Loss: 1.418 | V-Acc: 0.810
#  No improvement for 2 epochs.
# Epoch 061 | T-Loss: 1.343 | T-Acc: 0.892 | V-Loss: 1.390 | V-Acc: 0.838
#  No improvement for 3 epochs.
# Epoch 062 | T-Loss: 1.245 | T-Acc: 0.914 | V-Loss: 1.410 | V-Acc: 0.824
#  No improvement for 4 epochs.
# Epoch 063 | T-Loss: 1.322 | T-Acc: 0.900 | V-Loss: 1.390 | V-Acc: 0.843
# Epoch 63: New best validation accuracy 0.8426, model saved.
# Epoch 064 | T-Loss: 1.197 | T-Acc: 0.932 | V-Loss: 1.415 | V-Acc: 0.826
#  No improvement for 1 epochs.
# Epoch 065 | T-Loss: 1.321 | T-Acc: 0.905 | V-Loss: 1.300 | V-Acc: 0.854
# Epoch 65: New best validation accuracy 0.8542, model saved.
# Epoch 066 | T-Loss: 1.079 | T-Acc: 0.955 | V-Loss: 1.421 | V-Acc: 0.829
#  No improvement for 1 epochs.
# Epoch 067 | T-Loss: 1.283 | T-Acc: 0.914 | V-Loss: 1.377 | V-Acc: 0.824
#  No improvement for 2 epochs.
# Epoch 068 | T-Loss: 1.275 | T-Acc: 0.911 | V-Loss: 1.345 | V-Acc: 0.829
#  No improvement for 3 epochs.
# Epoch 069 | T-Loss: 1.217 | T-Acc: 0.921 | V-Loss: 1.376 | V-Acc: 0.819
#  No improvement for 4 epochs.
# Epoch 070 | T-Loss: 1.278 | T-Acc: 0.914 | V-Loss: 1.392 | V-Acc: 0.815
#  No improvement for 5 epochs.
# Epoch 071 | T-Loss: 1.166 | T-Acc: 0.938 | V-Loss: 1.342 | V-Acc: 0.833
#  No improvement for 6 epochs.
# Epoch 072 | T-Loss: 1.220 | T-Acc: 0.931 | V-Loss: 1.380 | V-Acc: 0.836
#  No improvement for 7 epochs.
# Epoch 073 | T-Loss: 1.035 | T-Acc: 0.966 | V-Loss: 1.319 | V-Acc: 0.859
# Epoch 73: New best validation accuracy 0.8588, model saved.
# Epoch 074 | T-Loss: 1.264 | T-Acc: 0.914 | V-Loss: 1.361 | V-Acc: 0.845
#  No improvement for 1 epochs.
# Epoch 075 | T-Loss: 1.217 | T-Acc: 0.920 | V-Loss: 1.306 | V-Acc: 0.845
#  No improvement for 2 epochs.
# Epoch 076 | T-Loss: 1.153 | T-Acc: 0.939 | V-Loss: 1.261 | V-Acc: 0.852
#  No improvement for 3 epochs.
# Epoch 077 | T-Loss: 1.168 | T-Acc: 0.938 | V-Loss: 1.332 | V-Acc: 0.840
#  No improvement for 4 epochs.
# Epoch 078 | T-Loss: 1.174 | T-Acc: 0.940 | V-Loss: 1.352 | V-Acc: 0.850
#  No improvement for 5 epochs.
# Epoch 079 | T-Loss: 1.181 | T-Acc: 0.932 | V-Loss: 1.314 | V-Acc: 0.861
# Epoch 79: New best validation accuracy 0.8611, model saved.
# Epoch 080 | T-Loss: 1.176 | T-Acc: 0.932 | V-Loss: 1.324 | V-Acc: 0.845
#  No improvement for 1 epochs.
# Epoch 081 | T-Loss: 1.203 | T-Acc: 0.927 | V-Loss: 1.385 | V-Acc: 0.840
#  No improvement for 2 epochs.
# Epoch 082 | T-Loss: 1.194 | T-Acc: 0.928 | V-Loss: 1.305 | V-Acc: 0.863
# Epoch 82: New best validation accuracy 0.8634, model saved.
# Epoch 083 | T-Loss: 1.181 | T-Acc: 0.929 | V-Loss: 1.318 | V-Acc: 0.843
#  No improvement for 1 epochs.
# Epoch 084 | T-Loss: 1.126 | T-Acc: 0.943 | V-Loss: 1.286 | V-Acc: 0.854
#  No improvement for 2 epochs.
# Epoch 085 | T-Loss: 1.182 | T-Acc: 0.931 | V-Loss: 1.339 | V-Acc: 0.843
#  No improvement for 3 epochs.
# Epoch 086 | T-Loss: 1.227 | T-Acc: 0.919 | V-Loss: 1.294 | V-Acc: 0.856
#  No improvement for 4 epochs.
# Epoch 087 | T-Loss: 1.416 | T-Acc: 0.880 | V-Loss: 1.366 | V-Acc: 0.826
#  No improvement for 5 epochs.
# Epoch 088 | T-Loss: 1.019 | T-Acc: 0.964 | V-Loss: 1.294 | V-Acc: 0.854
#  No improvement for 6 epochs.
# Epoch 089 | T-Loss: 1.204 | T-Acc: 0.922 | V-Loss: 1.290 | V-Acc: 0.856
#  No improvement for 7 epochs.
# Epoch 090 | T-Loss: 1.075 | T-Acc: 0.956 | V-Loss: 1.278 | V-Acc: 0.847
#  No improvement for 8 epochs.
# Epoch 091 | T-Loss: 1.304 | T-Acc: 0.907 | V-Loss: 1.269 | V-Acc: 0.859
#  No improvement for 9 epochs.
# Epoch 092 | T-Loss: 1.174 | T-Acc: 0.926 | V-Loss: 1.291 | V-Acc: 0.852
#  No improvement for 10 epochs.
# Epoch 093 | T-Loss: 1.285 | T-Acc: 0.901 | V-Loss: 1.272 | V-Acc: 0.856
#  No improvement for 11 epochs.
# Epoch 094 | T-Loss: 1.159 | T-Acc: 0.933 | V-Loss: 1.289 | V-Acc: 0.852
#  No improvement for 12 epochs.
# Epoch 095 | T-Loss: 1.168 | T-Acc: 0.934 | V-Loss: 1.282 | V-Acc: 0.868
# Epoch 95: New best validation accuracy 0.8681, model saved.
# Epoch 096 | T-Loss: 1.107 | T-Acc: 0.943 | V-Loss: 1.335 | V-Acc: 0.843
#  No improvement for 1 epochs.
# Epoch 097 | T-Loss: 1.159 | T-Acc: 0.934 | V-Loss: 1.272 | V-Acc: 0.850
#  No improvement for 2 epochs.
# Epoch 098 | T-Loss: 1.106 | T-Acc: 0.940 | V-Loss: 1.259 | V-Acc: 0.861
#  No improvement for 3 epochs.
# Epoch 099 | T-Loss: 1.103 | T-Acc: 0.948 | V-Loss: 1.305 | V-Acc: 0.852
#  No improvement for 4 epochs.
# Epoch 100 | T-Loss: 1.132 | T-Acc: 0.941 | V-Loss: 1.258 | V-Acc: 0.863
#  No improvement for 5 epochs.
# Epoch 101 | T-Loss: 1.066 | T-Acc: 0.956 | V-Loss: 1.266 | V-Acc: 0.861
#  No improvement for 6 epochs.
# Epoch 102 | T-Loss: 1.077 | T-Acc: 0.956 | V-Loss: 1.262 | V-Acc: 0.856
#  No improvement for 7 epochs.
# Epoch 103 | T-Loss: 1.173 | T-Acc: 0.931 | V-Loss: 1.223 | V-Acc: 0.870
# Epoch 103: New best validation accuracy 0.8704, model saved.
# Epoch 104 | T-Loss: 1.014 | T-Acc: 0.963 | V-Loss: 1.224 | V-Acc: 0.863
#  No improvement for 1 epochs.
# Epoch 105 | T-Loss: 1.094 | T-Acc: 0.945 | V-Loss: 1.230 | V-Acc: 0.875
# Epoch 105: New best validation accuracy 0.8750, model saved.
# Epoch 106 | T-Loss: 0.935 | T-Acc: 0.981 | V-Loss: 1.223 | V-Acc: 0.884
# Epoch 106: New best validation accuracy 0.8843, model saved.
# Epoch 107 | T-Loss: 0.978 | T-Acc: 0.971 | V-Loss: 1.245 | V-Acc: 0.863
#  No improvement for 1 epochs.
# Epoch 108 | T-Loss: 1.084 | T-Acc: 0.949 | V-Loss: 1.239 | V-Acc: 0.868
#  No improvement for 2 epochs.
# Epoch 109 | T-Loss: 1.200 | T-Acc: 0.926 | V-Loss: 1.238 | V-Acc: 0.882
#  No improvement for 3 epochs.
# Epoch 110 | T-Loss: 1.151 | T-Acc: 0.939 | V-Loss: 1.227 | V-Acc: 0.887
# Epoch 110: New best validation accuracy 0.8866, model saved.
# Epoch 111 | T-Loss: 1.052 | T-Acc: 0.957 | V-Loss: 1.217 | V-Acc: 0.880
#  No improvement for 1 epochs.
# Epoch 112 | T-Loss: 1.088 | T-Acc: 0.952 | V-Loss: 1.219 | V-Acc: 0.882
#  No improvement for 2 epochs.
# Epoch 113 | T-Loss: 1.091 | T-Acc: 0.946 | V-Loss: 1.217 | V-Acc: 0.884
#  No improvement for 3 epochs.
# Epoch 114 | T-Loss: 1.111 | T-Acc: 0.940 | V-Loss: 1.237 | V-Acc: 0.868
#  No improvement for 4 epochs.
# Epoch 115 | T-Loss: 1.006 | T-Acc: 0.964 | V-Loss: 1.232 | V-Acc: 0.875
#  No improvement for 5 epochs.
# Epoch 116 | T-Loss: 1.040 | T-Acc: 0.962 | V-Loss: 1.229 | V-Acc: 0.873
#  No improvement for 6 epochs.
# Epoch 117 | T-Loss: 1.057 | T-Acc: 0.953 | V-Loss: 1.252 | V-Acc: 0.875
#  No improvement for 7 epochs.
# Epoch 118 | T-Loss: 1.022 | T-Acc: 0.961 | V-Loss: 1.231 | V-Acc: 0.880
#  No improvement for 8 epochs.
# Epoch 119 | T-Loss: 1.234 | T-Acc: 0.912 | V-Loss: 1.228 | V-Acc: 0.875
#  No improvement for 9 epochs.
# Epoch 120 | T-Loss: 1.059 | T-Acc: 0.951 | V-Loss: 1.218 | V-Acc: 0.873
#  No improvement for 10 epochs.
# Epoch 121 | T-Loss: 1.069 | T-Acc: 0.948 | V-Loss: 1.215 | V-Acc: 0.887
#  No improvement for 11 epochs.
# Epoch 122 | T-Loss: 1.116 | T-Acc: 0.941 | V-Loss: 1.221 | V-Acc: 0.877
#  No improvement for 12 epochs.
# Epoch 123 | T-Loss: 1.061 | T-Acc: 0.958 | V-Loss: 1.218 | V-Acc: 0.873
#  No improvement for 13 epochs.
# Epoch 124 | T-Loss: 1.149 | T-Acc: 0.935 | V-Loss: 1.213 | V-Acc: 0.887
#  No improvement for 14 epochs.
# Epoch 125 | T-Loss: 1.060 | T-Acc: 0.951 | V-Loss: 1.214 | V-Acc: 0.889
# Epoch 125: New best validation accuracy 0.8889, model saved.
# Epoch 126 | T-Loss: 1.129 | T-Acc: 0.938 | V-Loss: 1.202 | V-Acc: 0.887
#  No improvement for 1 epochs.
# Epoch 127 | T-Loss: 1.172 | T-Acc: 0.932 | V-Loss: 1.218 | V-Acc: 0.894
# Epoch 127: New best validation accuracy 0.8935, model saved.
# Epoch 128 | T-Loss: 1.133 | T-Acc: 0.932 | V-Loss: 1.205 | V-Acc: 0.894
#  No improvement for 1 epochs.
# Epoch 129 | T-Loss: 1.157 | T-Acc: 0.930 | V-Loss: 1.224 | V-Acc: 0.880
#  No improvement for 2 epochs.
# Epoch 130 | T-Loss: 1.040 | T-Acc: 0.957 | V-Loss: 1.225 | V-Acc: 0.877
#  No improvement for 3 epochs.
# Epoch 131 | T-Loss: 1.025 | T-Acc: 0.960 | V-Loss: 1.219 | V-Acc: 0.882
#  No improvement for 4 epochs.
# Epoch 132 | T-Loss: 1.151 | T-Acc: 0.933 | V-Loss: 1.216 | V-Acc: 0.884
#  No improvement for 5 epochs.
# Epoch 133 | T-Loss: 1.137 | T-Acc: 0.935 | V-Loss: 1.214 | V-Acc: 0.882
#  No improvement for 6 epochs.
# Epoch 134 | T-Loss: 1.078 | T-Acc: 0.952 | V-Loss: 1.206 | V-Acc: 0.884
#  No improvement for 7 epochs.
# Epoch 135 | T-Loss: 1.052 | T-Acc: 0.954 | V-Loss: 1.211 | V-Acc: 0.877
#  No improvement for 8 epochs.
# Epoch 136 | T-Loss: 0.967 | T-Acc: 0.971 | V-Loss: 1.216 | V-Acc: 0.884
#  No improvement for 9 epochs.
# Epoch 137 | T-Loss: 1.114 | T-Acc: 0.942 | V-Loss: 1.228 | V-Acc: 0.877
#  No improvement for 10 epochs.
# Epoch 138 | T-Loss: 1.019 | T-Acc: 0.959 | V-Loss: 1.213 | V-Acc: 0.880
#  No improvement for 11 epochs.
# Epoch 139 | T-Loss: 1.108 | T-Acc: 0.939 | V-Loss: 1.216 | V-Acc: 0.882
#  No improvement for 12 epochs.
# Epoch 140 | T-Loss: 1.221 | T-Acc: 0.915 | V-Loss: 1.217 | V-Acc: 0.882
#  No improvement for 13 epochs.
# Epoch 141 | T-Loss: 0.986 | T-Acc: 0.968 | V-Loss: 1.214 | V-Acc: 0.880
#  No improvement for 14 epochs.
# Epoch 142 | T-Loss: 1.090 | T-Acc: 0.946 | V-Loss: 1.225 | V-Acc: 0.870
#  No improvement for 15 epochs.
# Epoch 143 | T-Loss: 1.124 | T-Acc: 0.936 | V-Loss: 1.208 | V-Acc: 0.880
#  No improvement for 16 epochs.
# Epoch 144 | T-Loss: 1.132 | T-Acc: 0.940 | V-Loss: 1.217 | V-Acc: 0.889
#  No improvement for 17 epochs.
# Epoch 145 | T-Loss: 0.994 | T-Acc: 0.964 | V-Loss: 1.219 | V-Acc: 0.882
#  No improvement for 18 epochs.
# Epoch 146 | T-Loss: 1.119 | T-Acc: 0.935 | V-Loss: 1.218 | V-Acc: 0.880
#  No improvement for 19 epochs.
# Epoch 147 | T-Loss: 1.244 | T-Acc: 0.913 | V-Loss: 1.212 | V-Acc: 0.887
#  No improvement for 20 epochs.
# Epoch 148 | T-Loss: 1.170 | T-Acc: 0.923 | V-Loss: 1.213 | V-Acc: 0.882
#  No improvement for 21 epochs.
# Epoch 149 | T-Loss: 1.092 | T-Acc: 0.947 | V-Loss: 1.221 | V-Acc: 0.870
#  No improvement for 22 epochs.
# Epoch 150 | T-Loss: 1.125 | T-Acc: 0.935 | V-Loss: 1.219 | V-Acc: 0.884
#  No improvement for 23 epochs.
# Final Test Accuracy: 0.8739
