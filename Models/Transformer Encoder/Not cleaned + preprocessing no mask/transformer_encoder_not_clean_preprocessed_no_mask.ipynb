# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score
from tqdm import tqdm

# ==============================
# CONFIG
# ==============================
DATASET_PATH = "/kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits"

FEATURE_DIM = 438
D_MODEL = 128
N_HEADS = 4
N_LAYERS = 2

BATCH_SIZE = 32
LR = 3e-4
EPOCHS = 60
PATIENCE = 7

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# ==============================
# LOAD CSV
# ==============================
df = pd.read_csv(os.path.join(DATASET_PATH, "splits.csv"))
# FIX Windows backslashes in paths
df["fullpath"] = df["filepath"].apply(lambda x: os.path.join(DATASET_PATH, x.replace("\\","/")))

le = LabelEncoder()
df["label_enc"] = le.fit_transform(df["label"])
num_classes = len(le.classes_)
import joblib
joblib.dump(le, "label_encoder.pkl")
train_df = df[df["split"]=="train"]
val_df   = df[df["split"]=="val"]
test_df  = df[df["split"]=="test"]

X_train, y_train = train_df["fullpath"].values, train_df["label_enc"].values
X_val, y_val     = val_df["fullpath"].values, val_df["label_enc"].values
X_test, y_test   = test_df["fullpath"].values, test_df["label_enc"].values

print("Train samples:", len(X_train))
print("Val samples:", len(X_val))
print("Test samples:", len(X_test))

# ==============================
# DATASET WITH PADDING
# ==============================
def pad_sequence(x, max_len):
    if x.shape[0] >= max_len:
        return x[:max_len]
    else:
        pad = np.zeros((max_len - x.shape[0], x.shape[1]), dtype=np.float32)
        return np.vstack([x, pad])

# Determine max sequence length (90th percentile)
all_lengths = [np.load(f).shape[0] for f in X_train]
MAX_LEN = int(np.percentile(all_lengths, 90))
print("Padding sequences to length:", MAX_LEN)

class LandmarkDataset(Dataset):
    def __init__(self, files, labels, max_len=None, augment=False):
        self.files = files
        self.labels = labels
        self.max_len = max_len
        self.augment = augment

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        x = np.load(self.files[idx]).astype(np.float32)
        if self.augment:
            x += np.random.normal(0, 0.002, x.shape).astype(np.float32)
        if self.max_len:
            x = pad_sequence(x, self.max_len)
        return torch.tensor(x), torch.tensor(self.labels[idx], dtype=torch.long)

train_ds = LandmarkDataset(X_train, y_train, max_len=MAX_LEN, augment=True)
val_ds   = LandmarkDataset(X_val, y_val, max_len=MAX_LEN)
test_ds  = LandmarkDataset(X_test, y_test, max_len=MAX_LEN)

# ==============================
# CLASS IMBALANCE
# ==============================
train_classes = np.unique(y_train)
class_weights_np = compute_class_weight(class_weight="balanced", classes=train_classes, y=y_train)
class_weights = torch.zeros(num_classes, dtype=torch.float32)
class_weights[train_classes] = torch.tensor(class_weights_np, dtype=torch.float32)
class_weights = class_weights.to(DEVICE)

sample_weights = class_weights_np[[np.where(train_classes==y)[0][0] for y in y_train]]
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# ==============================
# TRANSFORMER MODEL
# ==============================
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=300):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2) * (-np.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(pos*div)
        pe[:,1::2] = torch.cos(pos*div)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:,:x.size(1)]

class SignTransformer(nn.Module):
    def __init__(self):
        super().__init__()
        self.input_proj = nn.Linear(FEATURE_DIM, D_MODEL)
        self.cls_token = nn.Parameter(torch.zeros(1,1,D_MODEL))
        self.pos_enc = PositionalEncoding(D_MODEL, max_len=MAX_LEN+1)
        enc_layer = nn.TransformerEncoderLayer(d_model=D_MODEL, nhead=N_HEADS,
                                               dim_feedforward=D_MODEL*4,
                                               dropout=0.1, batch_first=True)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=N_LAYERS)
        self.classifier = nn.Sequential(nn.LayerNorm(D_MODEL), nn.Linear(D_MODEL,num_classes))

    def forward(self, x):
        x = self.input_proj(x)
        B = x.size(0)
        cls = self.cls_token.expand(B, -1, -1)
        x = torch.cat([cls, x], dim=1)
        x = self.pos_enc(x)
        x = self.encoder(x)
        return self.classifier(x[:,0])

model = SignTransformer().to(DEVICE)

# ==============================
# TRAINING SETUP
# ==============================
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_losses, val_losses = [], []
train_accs, val_accs = [], []

best_val = 0
pat = 0

# ==============================
# TRAIN LOOP
# ==============================
for epoch in range(EPOCHS):
    model.train()
    t_loss, correct, total = 0,0,0

    for x,y in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        t_loss += loss.item()
        correct += (out.argmax(1) == y).sum().item()
        total += y.size(0)

    train_loss = t_loss / len(train_loader)
    train_acc = correct / total

    model.eval()
    v_loss, v_correct, v_total = 0,0,0
    with torch.no_grad():
        for x,y in val_loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss = criterion(out, y)
            v_loss += loss.item()
            v_correct += (out.argmax(1) == y).sum().item()
            v_total += y.size(0)

    val_loss = v_loss / len(val_loader)
    val_acc = v_correct / v_total

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs.append(train_acc)
    val_accs.append(val_acc)

    print(f"\nEpoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val:
        best_val = val_acc
        torch.save({
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "label_encoder_classes": le.classes_,
        "config": {
            "FEATURE_DIM": FEATURE_DIM,
            "D_MODEL": D_MODEL,
            "N_HEADS": N_HEADS,
            "N_LAYERS": N_LAYERS,
            "MAX_LEN": MAX_LEN,
            "num_classes": num_classes
        }
    }, "best_model.pth")
        pat = 0
        print("✅ Model Saved")
    else:
        pat += 1
        if pat >= PATIENCE:
            print("⛔ Early stopping triggered")
            break
import json

history = {
    "train_loss": train_losses,
    "val_loss": val_losses,
    "train_acc": train_accs,
    "val_acc": val_accs
}

with open("training_history.json", "w") as f:
    json.dump(history, f)
# ==============================
# TEST
# ==============================
checkpoint = torch.load("best_model.pth", map_location=DEVICE, weights_only=False)

model.load_state_dict(checkpoint["model_state_dict"])
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

# restore label encoder
le.classes_ = checkpoint["label_encoder_classes"]

model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for x,y in test_loader:
        x = x.to(DEVICE)
        out = model(x)
        preds = out.argmax(1).cpu().numpy()
        y_pred.extend(preds)
        y_true.extend(y.numpy())

test_acc = accuracy_score(y_true, y_pred)
print("\n✅ Test Accuracy:", test_acc)
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# ==============================
# PLOTS
# ==============================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Loss Curve")

plt.subplot(1,2,2)
plt.plot(train_accs, label="Train Acc")
plt.plot(val_accs, label="Val Acc")
plt.legend()
plt.title("Accuracy Curve")
plt.savefig("training_curves.png")
plt.show()
# Out:
# Using device: cuda
# Train samples: 2256
# Val samples: 432
# Test samples: 595
# Padding sequences to length: 127
# Epoch 1/60: 100%|██████████| 71/71 [00:08<00:00,  8.27it/s]
# Epoch 1 | Train Loss: 4.6482 | Train Acc: 0.0164 | Val Loss: 4.5899 | Val Acc: 0.0301
# ✅ Model Saved
# Epoch 2/60: 100%|██████████| 71/71 [00:08<00:00,  8.44it/s]
# Epoch 2 | Train Loss: 4.1844 | Train Acc: 0.0554 | Val Loss: 3.9814 | Val Acc: 0.0833
# ✅ Model Saved
# Epoch 3/60: 100%|██████████| 71/71 [00:08<00:00,  7.89it/s]
# Epoch 3 | Train Loss: 3.6768 | Train Acc: 0.1308 | Val Loss: 3.6064 | Val Acc: 0.1088
# ✅ Model Saved
# Epoch 4/60: 100%|██████████| 71/71 [00:08<00:00,  8.47it/s]
# Epoch 17 | Train Loss: 0.8347 | Train Acc: 0.8205 | Val Loss: 1.2357 | Val Acc: 0.6528
# ✅ Model Saved
# Epoch 18/60: 100%|██████████| 71/71 [00:07<00:00,  9.36it/s]
# Epoch 18 | Train Loss: 0.7231 | Train Acc: 0.8382 | Val Loss: 1.1622 | Val Acc: 0.6875
# ✅ Model Saved
# Epoch 19/60: 100%|██████████| 71/71 [00:07<00:00,  9.51it/s]
# Epoch 19 | Train Loss: 0.6419 | Train Acc: 0.8728 | Val Loss: 1.1263 | Val Acc: 0.6713
# Epoch 20/60: 100%|██████████| 71/71 [00:07<00:00,  9.44it/s]
# Epoch 20 | Train Loss: 0.6116 | Train Acc: 0.8697 | Val Loss: 1.1163 | Val Acc: 0.6944
# ✅ Model Saved
# Epoch 21/60: 100%|██████████| 71/71 [00:07<00:00,  9.28it/s]
# Epoch 21 | Train Loss: 0.5520 | Train Acc: 0.8794 | Val Loss: 1.0544 | Val Acc: 0.7176
# ✅ Model Saved
# Epoch 22/60: 100%|██████████| 71/71 [00:07<00:00,  9.51it/s]
# Epoch 22 | Train Loss: 0.4844 | Train Acc: 0.9047 | Val Loss: 1.0183 | Val Acc: 0.6921
# Epoch 23/60: 100%|██████████| 71/71 [00:07<00:00,  9.39it/s]
# Epoch 23 | Train Loss: 0.4463 | Train Acc: 0.9100 | Val Loss: 0.9877 | Val Acc: 0.6921
# Epoch 24/60: 100%|██████████| 71/71 [00:07<00:00,  9.37it/s]
# Epoch 24 | Train Loss: 0.4023 | Train Acc: 0.9180 | Val Loss: 0.9625 | Val Acc: 0.6944
# Epoch 25/60: 100%|██████████| 71/71 [00:07<00:00,  9.37it/s]
# Epoch 25 | Train Loss: 0.3752 | Train Acc: 0.9229 | Val Loss: 0.8793 | Val Acc: 0.7338
# ✅ Model Saved
# Epoch 26/60: 100%|██████████| 71/71 [00:07<00:00,  9.53it/s]
# Epoch 26 | Train Loss: 0.3248 | Train Acc: 0.9277 | Val Loss: 0.8663 | Val Acc: 0.7269
# Epoch 27/60: 100%|██████████| 71/71 [00:07<00:00,  9.54it/s]
# Epoch 27 | Train Loss: 0.2925 | Train Acc: 0.9388 | Val Loss: 0.8958 | Val Acc: 0.7199
# Epoch 28/60: 100%|██████████| 71/71 [00:07<00:00,  9.51it/s]
# Epoch 28 | Train Loss: 0.2676 | Train Acc: 0.9481 | Val Loss: 0.9301 | Val Acc: 0.7315
# Epoch 29/60: 100%|██████████| 71/71 [00:07<00:00,  9.45it/s]
# Epoch 29 | Train Loss: 0.2421 | Train Acc: 0.9499 | Val Loss: 0.8375 | Val Acc: 0.7639
# ✅ Model Saved
# Epoch 30/60: 100%|██████████| 71/71 [00:07<00:00,  9.12it/s]
# Epoch 30 | Train Loss: 0.2105 | Train Acc: 0.9592 | Val Loss: 0.7967 | Val Acc: 0.7639
# Epoch 45/60: 100%|██████████| 71/71 [00:07<00:00,  9.02it/s]
# Epoch 45 | Train Loss: 0.0577 | Train Acc: 0.9898 | Val Loss: 0.8663 | Val Acc: 0.7639
# Epoch 46/60: 100%|██████████| 71/71 [00:07<00:00,  9.19it/s]
# Epoch 46 | Train Loss: 0.0623 | Train Acc: 0.9832 | Val Loss: 0.8707 | Val Acc: 0.7801
# Epoch 47/60: 100%|██████████| 71/71 [00:07<00:00,  9.04it/s]
# Epoch 47 | Train Loss: 0.0476 | Train Acc: 0.9889 | Val Loss: 0.8852 | Val Acc: 0.7593
# Epoch 48/60: 100%|██████████| 71/71 [00:07<00:00,  8.94it/s]
# Epoch 48 | Train Loss: 0.0481 | Train Acc: 0.9889 | Val Loss: 0.8698 | Val Acc: 0.7870
# ⛔ Early stopping triggered
#
# ✅ Test Accuracy: 0.7983193277310925
#
# Classification Report:
#
#                     precision    recall  f1-score   support
#
#           1 DOLLAR       0.62      0.83      0.71         6
#          5 DOLLARS       0.83      0.83      0.83         6
#         7-SEEDSOUR       0.00      0.00      0.00         1
#             8 HOUR       0.62      0.83      0.71         6
#           9 OCLOCK       0.80      0.67      0.73         6
#       A LITTLE BIT       0.40      0.67      0.50         6
#         A-LINE BOB       1.00      1.00      1.00         5
#         ABBREVIATE       1.00      0.83      0.91         6
#              ABOUT       1.00      0.90      0.95        10
#              ABOVE       1.00      0.83      0.91         6
# ABSOLUTELY NOTHING       0.83      0.83      0.83         6
#             ACCENT       0.71      1.00      0.83         5
#             ACCEPT       1.00      0.80      0.89         5
#             ACCESS       1.00      1.00      1.00         6
#           ACCIDENT       0.83      1.00      0.91         5
#         ACCOMPLISH       0.71      1.00      0.83         5
#          ACCORDION       1.00      1.00      1.00         6
#         ACCOUNTANT       1.00      1.00      1.00         6
#            ACQUIRE       1.00      0.20      0.33         5
#                ACT       0.71      0.83      0.77         6
#             ACTION       0.62      0.83      0.71         6
#              ACTOR       1.00      0.67      0.80         6
#                ADD       0.57      0.67      0.62         6
#             ADDICT       0.80      0.67      0.73         6
#            ADDRESS       0.83      1.00      0.91         5
#             ADMIRE       0.80      0.80      0.80         5
#              ADMIT       1.00      0.67      0.80         6
#              ADOPT       0.67      0.80      0.73         5
#              ADULT       1.00      1.00      1.00         5
#          ADVANTAGE       0.80      0.67      0.73         6
#          ADVERTISE       1.00      1.00      1.00         6
#             AFRICA       1.00      0.67      0.80         6
#              AFTER       0.29      0.33      0.31         6
#          AFTERNOON       0.67      0.40      0.50         5
#              AGAIN       0.57      0.80      0.67         5
#            AGAINST       0.80      0.80      0.80         5
#                AGE       1.00      0.60      0.75         5
#             AGENCY       1.00      1.00      1.00         5
#          AGREEMENT       1.00      1.00      1.00         5
#           AIRPLANE       1.00      0.80      0.89         5
#              ALARM       1.00      0.67      0.80         6
#             ALASKA       0.83      1.00      0.91         5
#            ALCOHOL       0.83      0.83      0.83         6
#              ALIGN       1.00      1.00      1.00         6
#                ALL       0.86      1.00      0.92         6
#            ALL DAY       0.67      0.40      0.50         5
#           ALL GONE       1.00      0.83      0.91         6
#      ALL OF_SUDDEN       0.60      0.50      0.55         6
#           ALL OVER       0.62      0.83      0.71         6
#      ALL OVER_BODY       1.00      0.80      0.89         5
#       ALL TOGETHER       0.71      1.00      0.83         5
#            ALL WAY       0.80      0.67      0.73         6
#              ALONE       0.75      0.50      0.60         6
#           ALPHABET       0.56      0.83      0.67         6
#            ALRIGHT       0.67      0.67      0.67         6
#             ALWAYS       0.80      0.67      0.73         6
#            AMAZING       1.00      0.60      0.75         5
#            AMERICA       0.86      1.00      0.92         6
#            ANALYZE       1.00      1.00      1.00         6
#                AND       0.50      0.83      0.62         6
#              ANGEL       1.00      0.80      0.89         5
#              ANGRY       1.00      0.83      0.91         6
#             ANIMAL       1.00      1.00      1.00         6
#           ANNOUNCE       1.00      0.83      0.91         6
#             ANSWER       0.75      1.00      0.86         6
#            ANTLERS       1.00      1.00      1.00         5
#                ANY       1.00      1.00      1.00         6
#             ANYONE       0.67      0.67      0.67         6
#              APART       1.00      1.00      1.00         5
#             APPEAR       0.55      1.00      0.71         6
#              APPLE       0.86      1.00      0.92         6
#        APPOINTMENT       0.40      0.40      0.40         5
#              APRIL       1.00      0.80      0.89         5
#         ARCHEOLOGY       1.00      0.60      0.75         5
#               AREA       0.83      0.83      0.83         6
#              ARGUE       1.00      1.00      1.00         5
#            ARIZONA       1.00      0.67      0.80         6
#                ARM       0.86      0.80      0.83        15
#               ARMY       1.00      0.83      0.91         6
#             ARREST       1.00      0.60      0.75        15
#             ARRIVE       0.56      1.00      0.71         5
#                ART       0.80      0.80      0.80         5
#            ARTICLE       0.86      1.00      0.92         6
#    ARTICULATE SIGN       0.83      1.00      0.91         5
#               ASIA       0.57      0.67      0.62         6
#                ASK       1.00      1.00      1.00         6
#           ASSEMBLY       0.25      0.17      0.20         6
#             ASSIGN       0.67      0.80      0.73         5
#             ASSIST       0.75      0.50      0.60         6
#          ASSISTANT       0.60      0.50      0.55         6
#          ASTRONAUT       1.00      1.00      1.00         6
#                 AT       0.71      0.83      0.77         6
#            ATHLETE       1.00      1.00      1.00         5
#            ATLANTA       0.25      0.20      0.22         5
#          ATTENTION       0.83      1.00      0.91         5
#           ATTITUDE       0.62      0.83      0.71         6
#           AUDIENCE       1.00      1.00      1.00         5
#         AUDITORIUM       0.83      0.83      0.83         6
#               AUNT       1.00      1.00      1.00         6
#          AUSTRALIA       0.57      0.80      0.67         5
#             AUTISM       0.82      0.90      0.86        10
#          AUTOMATIC       0.80      0.67      0.73         6
#
#           accuracy                           0.80       595
#          macro avg       0.81      0.79      0.79       595
#       weighted avg       0.82      0.80      0.80       595
