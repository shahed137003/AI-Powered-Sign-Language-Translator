# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score
from tqdm import tqdm

# ==============================
# CONFIG
# ==============================
DATASET_PATH = "/kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits"

FEATURE_DIM = 438
D_MODEL = 128
N_HEADS = 4
N_LAYERS = 2

BATCH_SIZE = 32
LR = 3e-4
EPOCHS = 60
PATIENCE = 7

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# ==============================
# LOAD CSV
# ==============================
df = pd.read_csv(os.path.join(DATASET_PATH, "splits.csv"))
# FIX Windows backslashes in paths
df["fullpath"] = df["filepath"].apply(lambda x: os.path.join(DATASET_PATH, x.replace("\\","/")))

le = LabelEncoder()
df["label_enc"] = le.fit_transform(df["label"])
num_classes = len(le.classes_)

train_df = df[df["split"]=="train"]
val_df   = df[df["split"]=="val"]
test_df  = df[df["split"]=="test"]

X_train, y_train = train_df["fullpath"].values, train_df["label_enc"].values
X_val, y_val     = val_df["fullpath"].values, val_df["label_enc"].values
X_test, y_test   = test_df["fullpath"].values, test_df["label_enc"].values

print("Train samples:", len(X_train))
print("Val samples:", len(X_val))
print("Test samples:", len(X_test))

# ==============================
# DATASET WITH PADDING
# ==============================
def pad_sequence(x, max_len):
    if x.shape[0] >= max_len:
        return x[:max_len]
    else:
        pad = np.zeros((max_len - x.shape[0], x.shape[1]), dtype=np.float32)
        return np.vstack([x, pad])

# Determine max sequence length (90th percentile)
all_lengths = [np.load(f).shape[0] for f in X_train]
MAX_LEN = int(np.percentile(all_lengths, 90))
print("Padding sequences to length:", MAX_LEN)

class LandmarkDataset(Dataset):
    def __init__(self, files, labels, max_len=None, augment=False):
        self.files = files
        self.labels = labels
        self.max_len = max_len
        self.augment = augment

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        x = np.load(self.files[idx]).astype(np.float32)
        if self.augment:
            x += np.random.normal(0, 0.002, x.shape).astype(np.float32)
        if self.max_len:
            x = pad_sequence(x, self.max_len)
        return torch.tensor(x), torch.tensor(self.labels[idx], dtype=torch.long)

train_ds = LandmarkDataset(X_train, y_train, max_len=MAX_LEN, augment=True)
val_ds   = LandmarkDataset(X_val, y_val, max_len=MAX_LEN)
test_ds  = LandmarkDataset(X_test, y_test, max_len=MAX_LEN)

# ==============================
# CLASS IMBALANCE
# ==============================
train_classes = np.unique(y_train)
class_weights_np = compute_class_weight(class_weight="balanced", classes=train_classes, y=y_train)
class_weights = torch.zeros(num_classes, dtype=torch.float32)
class_weights[train_classes] = torch.tensor(class_weights_np, dtype=torch.float32)
class_weights = class_weights.to(DEVICE)

sample_weights = class_weights_np[[np.where(train_classes==y)[0][0] for y in y_train]]
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# ==============================
# TRANSFORMER MODEL
# ==============================
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=300):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2) * (-np.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(pos*div)
        pe[:,1::2] = torch.cos(pos*div)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:,:x.size(1)]

class SignTransformer(nn.Module):
    def __init__(self):
        super().__init__()
        self.input_proj = nn.Linear(FEATURE_DIM, D_MODEL)
        self.cls_token = nn.Parameter(torch.zeros(1,1,D_MODEL))
        self.pos_enc = PositionalEncoding(D_MODEL, max_len=MAX_LEN+1)
        enc_layer = nn.TransformerEncoderLayer(d_model=D_MODEL, nhead=N_HEADS,
                                               dim_feedforward=D_MODEL*4,
                                               dropout=0.1, batch_first=True)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=N_LAYERS)
        self.classifier = nn.Sequential(nn.LayerNorm(D_MODEL), nn.Linear(D_MODEL,num_classes))

    def forward(self, x):
        x = self.input_proj(x)
        B = x.size(0)
        cls = self.cls_token.expand(B, -1, -1)
        x = torch.cat([cls, x], dim=1)
        x = self.pos_enc(x)
        x = self.encoder(x)
        return self.classifier(x[:,0])

model = SignTransformer().to(DEVICE)

# ==============================
# TRAINING SETUP
# ==============================
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_losses, val_losses = [], []
train_accs, val_accs = [], []

best_val = 0
pat = 0

# ==============================
# TRAIN LOOP
# ==============================
for epoch in range(EPOCHS):
    model.train()
    t_loss, correct, total = 0,0,0

    for x,y in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        t_loss += loss.item()
        correct += (out.argmax(1) == y).sum().item()
        total += y.size(0)

    train_loss = t_loss / len(train_loader)
    train_acc = correct / total

    model.eval()
    v_loss, v_correct, v_total = 0,0,0
    with torch.no_grad():
        for x,y in val_loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss = criterion(out, y)
            v_loss += loss.item()
            v_correct += (out.argmax(1) == y).sum().item()
            v_total += y.size(0)

    val_loss = v_loss / len(val_loader)
    val_acc = v_correct / v_total

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs.append(train_acc)
    val_accs.append(val_acc)

    print(f"\nEpoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val:
        best_val = val_acc
        torch.save(model.state_dict(), "best_model.pth")
        pat = 0
        print("✅ Model Saved")
    else:
        pat += 1
        if pat >= PATIENCE:
            print("⛔ Early stopping triggered")
            break

# ==============================
# TEST
# ==============================
model.load_state_dict(torch.load("best_model.pth"))
model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for x,y in test_loader:
        x = x.to(DEVICE)
        out = model(x)
        preds = out.argmax(1).cpu().numpy()
        y_pred.extend(preds)
        y_true.extend(y.numpy())

test_acc = accuracy_score(y_true, y_pred)
print("\n✅ Test Accuracy:", test_acc)
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# ==============================
# PLOTS
# ==============================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Loss Curve")

plt.subplot(1,2,2)
plt.plot(train_accs, label="Train Acc")
plt.plot(val_accs, label="Val Acc")
plt.legend()
plt.title("Accuracy Curve")
plt.show()
# Out:
# Using device: cuda
# Train samples: 2256
# Val samples: 432
# Test samples: 595
# Padding sequences to length: 127
# Epoch 1/60: 100%|██████████| 71/71 [00:06<00:00, 10.29it/s]
# Epoch 1 | Train Loss: 4.6447 | Train Acc: 0.0168 | Val Loss: 4.5854 | Val Acc: 0.0162
# ✅ Model Saved
# Epoch 2/60: 100%|██████████| 71/71 [00:06<00:00, 10.37it/s]
# Epoch 2 | Train Loss: 4.2318 | Train Acc: 0.0479 | Val Loss: 4.0081 | Val Acc: 0.0810
# ✅ Model Saved
# Epoch 3/60: 100%|██████████| 71/71 [00:06<00:00, 10.46it/s]
# Epoch 3 | Train Loss: 3.7181 | Train Acc: 0.1082 | Val Loss: 3.5640 | Val Acc: 0.1412
# ✅ Model Saved
# Epoch 4/60: 100%|██████████| 71/71 [00:06<00:00, 10.22it/s]
# Epoch 4 | Train Loss: 3.3134 | Train Acc: 0.1893 | Val Loss: 3.2878 | Val Acc: 0.1852
# ✅ Model Saved
# Epoch 5/60: 100%|██████████| 71/71 [00:06<00:00, 10.15it/s]
# Epoch 5 | Train Loss: 2.9907 | Train Acc: 0.2810 | Val Loss: 3.0107 | Val Acc: 0.2523
# ✅ Model Saved
# Epoch 6/60: 100%|██████████| 71/71 [00:07<00:00,  9.11it/s]
# Epoch 6 | Train Loss: 2.6961 | Train Acc: 0.3635 | Val Loss: 2.7399 | Val Acc: 0.3356
# ✅ Model Saved
# Epoch 7/60: 100%|██████████| 71/71 [00:06<00:00, 10.52it/s]
# Epoch 7 | Train Loss: 2.3667 | Train Acc: 0.4450 | Val Loss: 2.5107 | Val Acc: 0.4051
# ✅ Model Saved
# Epoch 8/60: 100%|██████████| 71/71 [00:06<00:00, 10.16it/s]
# Epoch 8 | Train Loss: 2.1351 | Train Acc: 0.5297 | Val Loss: 2.2905 | Val Acc: 0.4236
# ✅ Model Saved
# Epoch 9/60: 100%|██████████| 71/71 [00:07<00:00,  9.99it/s]
# Epoch 9 | Train Loss: 1.8582 | Train Acc: 0.6046 | Val Loss: 2.0429 | Val Acc: 0.4977
# ✅ Model Saved
# Epoch 10/60: 100%|██████████| 71/71 [00:07<00:00,  9.99it/s]
# Epoch 10 | Train Loss: 1.6364 | Train Acc: 0.6547 | Val Loss: 1.8860 | Val Acc: 0.5463
# ✅ Model Saved
# Epoch 11/60: 100%|██████████| 71/71 [00:07<00:00,  9.58it/s]
# Epoch 11 | Train Loss: 1.4311 | Train Acc: 0.6973 | Val Loss: 1.7421 | Val Acc: 0.5694
# ✅ Model Saved
# Epoch 12/60: 100%|██████████| 71/71 [00:06<00:00, 10.32it/s]
# Epoch 12 | Train Loss: 1.2810 | Train Acc: 0.7371 | Val Loss: 1.6209 | Val Acc: 0.5741
# ✅ Model Saved
# Epoch 13/60: 100%|██████████| 71/71 [00:06<00:00, 10.30it/s]
# Epoch 13 | Train Loss: 1.1690 | Train Acc: 0.7389 | Val Loss: 1.4994 | Val Acc: 0.5926
# ✅ Model Saved
# Epoch 14/60: 100%|██████████| 71/71 [00:06<00:00, 10.30it/s]
# Epoch 14 | Train Loss: 1.0446 | Train Acc: 0.7717 | Val Loss: 1.3907 | Val Acc: 0.6412
# ✅ Model Saved
# Epoch 15/60: 100%|██████████| 71/71 [00:06<00:00, 10.57it/s]
# Epoch 15 | Train Loss: 0.8977 | Train Acc: 0.8129 | Val Loss: 1.3408 | Val Acc: 0.6412
# Epoch 16/60: 100%|██████████| 71/71 [00:06<00:00, 10.42it/s]
# Epoch 16 | Train Loss: 0.8514 | Train Acc: 0.8240 | Val Loss: 1.3389 | Val Acc: 0.6273
# Epoch 17/60: 100%|██████████| 71/71 [00:06<00:00, 10.48it/s]
# Epoch 17 | Train Loss: 0.7754 | Train Acc: 0.8378 | Val Loss: 1.2329 | Val Acc: 0.6667
# ✅ Model Saved
# Epoch 18/60: 100%|██████████| 71/71 [00:06<00:00, 10.26it/s]
# Epoch 18 | Train Loss: 0.7016 | Train Acc: 0.8515 | Val Loss: 1.2042 | Val Acc: 0.6667
# Epoch 19/60: 100%|██████████| 71/71 [00:06<00:00, 10.33it/s]
# Epoch 19 | Train Loss: 0.6323 | Train Acc: 0.8710 | Val Loss: 1.1718 | Val Acc: 0.6875
# ✅ Model Saved
# Epoch 20/60: 100%|██████████| 71/71 [00:06<00:00, 10.16it/s]
# Epoch 47 | Train Loss: 0.0437 | Train Acc: 0.9929 | Val Loss: 0.9157 | Val Acc: 0.7639
# Epoch 48/60: 100%|██████████| 71/71 [00:06<00:00, 10.38it/s]
# Epoch 48 | Train Loss: 0.0501 | Train Acc: 0.9898 | Val Loss: 0.9202 | Val Acc: 0.7824
# Epoch 49/60: 100%|██████████| 71/71 [00:06<00:00, 10.28it/s]
# Epoch 49 | Train Loss: 0.0406 | Train Acc: 0.9938 | Val Loss: 0.9205 | Val Acc: 0.7801
# Epoch 50/60: 100%|██████████| 71/71 [00:06<00:00, 10.31it/s]
# Epoch 50 | Train Loss: 0.0460 | Train Acc: 0.9898 | Val Loss: 0.9583 | Val Acc: 0.7801
# Epoch 51/60: 100%|██████████| 71/71 [00:07<00:00, 10.12it/s]
# Epoch 51 | Train Loss: 0.0486 | Train Acc: 0.9863 | Val Loss: 0.9443 | Val Acc: 0.7824
# ⛔ Early stopping triggered
#
# ✅ Test Accuracy: 0.7949579831932773
#
# Classification Report:
#
#                     precision    recall  f1-score   support
#
#           1 DOLLAR       1.00      1.00      1.00         6
#          5 DOLLARS       1.00      0.83      0.91         6
#         7-SEEDSOUR       0.00      0.00      0.00         1
#             8 HOUR       0.83      0.83      0.83         6
#           9 OCLOCK       0.80      0.67      0.73         6
#       A LITTLE BIT       0.43      0.50      0.46         6
#         A-LINE BOB       1.00      1.00      1.00         5
#         ABBREVIATE       1.00      0.83      0.91         6
#              ABOUT       0.82      0.90      0.86        10
#              ABOVE       1.00      1.00      1.00         6
# ABSOLUTELY NOTHING       0.83      0.83      0.83         6
#             ACCENT       0.80      0.80      0.80         5
#             ACCEPT       1.00      0.80      0.89         5
#             ACCESS       1.00      1.00      1.00         6
#           ACCIDENT       0.80      0.80      0.80         5
#         ACCOMPLISH       0.83      1.00      0.91         5
#          ACCORDION       1.00      1.00      1.00         6
#         ACCOUNTANT       0.83      0.83      0.83         6
#            ACQUIRE       0.83      1.00      0.91         5
#                ACT       0.60      0.50      0.55         6
#             ACTION       0.75      1.00      0.86         6
#              ACTOR       1.00      0.50      0.67         6
#                ADD       0.57      0.67      0.62         6
#             ADDICT       0.86      1.00      0.92         6
#            ADDRESS       0.80      0.80      0.80         5
#             ADMIRE       1.00      1.00      1.00         5
#              ADMIT       1.00      0.67      0.80         6
#              ADOPT       0.40      0.40      0.40         5
#              ADULT       0.83      1.00      0.91         5
#          ADVANTAGE       1.00      0.67      0.80         6
#          ADVERTISE       1.00      1.00      1.00         6
#             AFRICA       0.80      0.67      0.73         6
#              AFTER       0.67      0.33      0.44         6
#          AFTERNOON       1.00      0.40      0.57         5
#              AGAIN       0.75      0.60      0.67         5
#            AGAINST       0.80      0.80      0.80         5
#                AGE       1.00      0.80      0.89         5
#             AGENCY       1.00      0.80      0.89         5
#          AGREEMENT       1.00      1.00      1.00         5
#           AIRPLANE       0.50      0.80      0.62         5
#              ALARM       0.62      0.83      0.71         6
#             ALASKA       1.00      1.00      1.00         5
#            ALCOHOL       1.00      0.67      0.80         6
#              ALIGN       0.75      1.00      0.86         6
#                ALL       0.75      1.00      0.86         6
#            ALL DAY       0.67      0.40      0.50         5
#           ALL GONE       0.83      0.83      0.83         6
#      ALL OF_SUDDEN       0.57      0.67      0.62         6
#           ALL OVER       0.86      1.00      0.92         6
#      ALL OVER_BODY       0.83      1.00      0.91         5
#       ALL TOGETHER       1.00      0.80      0.89         5
#            ALL WAY       0.83      0.83      0.83         6
#              ALONE       0.50      0.17      0.25         6
#           ALPHABET       1.00      0.67      0.80         6
#            ALRIGHT       1.00      0.50      0.67         6
#             ALWAYS       0.57      0.67      0.62         6
#            AMAZING       0.75      0.60      0.67         5
#            AMERICA       0.83      0.83      0.83         6
#            ANALYZE       1.00      1.00      1.00         6
#                AND       0.83      0.83      0.83         6
#              ANGEL       1.00      1.00      1.00         5
#              ANGRY       0.83      0.83      0.83         6
#             ANIMAL       0.86      1.00      0.92         6
#           ANNOUNCE       1.00      0.83      0.91         6
#             ANSWER       0.67      1.00      0.80         6
#            ANTLERS       1.00      1.00      1.00         5
#                ANY       0.86      1.00      0.92         6
#             ANYONE       0.67      0.33      0.44         6
#              APART       1.00      0.80      0.89         5
#             APPEAR       0.56      0.83      0.67         6
#              APPLE       0.75      1.00      0.86         6
#        APPOINTMENT       1.00      0.40      0.57         5
#              APRIL       0.71      1.00      0.83         5
#         ARCHEOLOGY       0.67      0.40      0.50         5
#               AREA       0.71      0.83      0.77         6
#              ARGUE       1.00      1.00      1.00         5
#            ARIZONA       1.00      0.67      0.80         6
#                ARM       0.76      0.87      0.81        15
#               ARMY       1.00      0.67      0.80         6
#             ARREST       0.92      0.73      0.81        15
#             ARRIVE       1.00      0.80      0.89         5
#                ART       0.67      0.80      0.73         5
#            ARTICLE       0.86      1.00      0.92         6
#    ARTICULATE SIGN       1.00      1.00      1.00         5
#               ASIA       0.62      0.83      0.71         6
#                ASK       0.67      1.00      0.80         6
#           ASSEMBLY       0.44      0.67      0.53         6
#             ASSIGN       0.57      0.80      0.67         5
#             ASSIST       0.50      0.67      0.57         6
#          ASSISTANT       0.67      0.33      0.44         6
#          ASTRONAUT       0.86      1.00      0.92         6
#                 AT       0.67      1.00      0.80         6
#            ATHLETE       0.80      0.80      0.80         5
#            ATLANTA       0.00      0.00      0.00         5
#          ATTENTION       0.83      1.00      0.91         5
#           ATTITUDE       0.83      0.83      0.83         6
#           AUDIENCE       0.50      0.80      0.62         5
#         AUDITORIUM       0.83      0.83      0.83         6
#               AUNT       1.00      0.83      0.91         6
#          AUSTRALIA       0.80      0.80      0.80         5
#             AUTISM       0.64      0.90      0.75        10
#          AUTOMATIC       0.86      1.00      0.92         6
#
#           accuracy                           0.79       595
#          macro avg       0.80      0.79      0.78       595
#       weighted avg       0.81      0.79      0.79       595
