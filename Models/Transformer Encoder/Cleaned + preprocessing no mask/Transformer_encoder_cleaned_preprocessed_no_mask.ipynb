# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score
from tqdm import tqdm

# ==============================
# CONFIG
# ==============================
DATASET_PATH = "/kaggle/input/datasets/mariamhany44/100-words-preprocessed-landmarks-cleaned-no-mask/splits"

FEATURE_DIM = 438
D_MODEL = 128
N_HEADS = 4
N_LAYERS = 2

BATCH_SIZE = 32
LR = 3e-4
EPOCHS = 60
PATIENCE = 7

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# ==============================
# LOAD CSV
# ==============================
df = pd.read_csv(os.path.join(DATASET_PATH, "splits.csv"))
# FIX Windows backslashes in paths
df["fullpath"] = df["filepath"].apply(lambda x: os.path.join(DATASET_PATH, x.replace("\\","/")))

le = LabelEncoder()
df["label_enc"] = le.fit_transform(df["label"])
num_classes = len(le.classes_)

train_df = df[df["split"]=="train"]
val_df   = df[df["split"]=="val"]
test_df  = df[df["split"]=="test"]

X_train, y_train = train_df["fullpath"].values, train_df["label_enc"].values
X_val, y_val     = val_df["fullpath"].values, val_df["label_enc"].values
X_test, y_test   = test_df["fullpath"].values, test_df["label_enc"].values

print("Train samples:", len(X_train))
print("Val samples:", len(X_val))
print("Test samples:", len(X_test))

# ==============================
# DATASET WITH PADDING
# ==============================
def pad_sequence(x, max_len):
    if x.shape[0] >= max_len:
        return x[:max_len]
    else:
        pad = np.zeros((max_len - x.shape[0], x.shape[1]), dtype=np.float32)
        return np.vstack([x, pad])

# Determine max sequence length (90th percentile)
all_lengths = [np.load(f).shape[0] for f in X_train]
MAX_LEN = int(np.percentile(all_lengths, 90))
print("Padding sequences to length:", MAX_LEN)

class LandmarkDataset(Dataset):
    def __init__(self, files, labels, max_len=None, augment=False):
        self.files = files
        self.labels = labels
        self.max_len = max_len
        self.augment = augment

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        x = np.load(self.files[idx]).astype(np.float32)
        if self.augment:
            x += np.random.normal(0, 0.002, x.shape).astype(np.float32)
        if self.max_len:
            x = pad_sequence(x, self.max_len)
        return torch.tensor(x), torch.tensor(self.labels[idx], dtype=torch.long)

train_ds = LandmarkDataset(X_train, y_train, max_len=MAX_LEN, augment=True)
val_ds   = LandmarkDataset(X_val, y_val, max_len=MAX_LEN)
test_ds  = LandmarkDataset(X_test, y_test, max_len=MAX_LEN)

# ==============================
# CLASS IMBALANCE
# ==============================
train_classes = np.unique(y_train)
class_weights_np = compute_class_weight(class_weight="balanced", classes=train_classes, y=y_train)
class_weights = torch.zeros(num_classes, dtype=torch.float32)
class_weights[train_classes] = torch.tensor(class_weights_np, dtype=torch.float32)
class_weights = class_weights.to(DEVICE)

sample_weights = class_weights_np[[np.where(train_classes==y)[0][0] for y in y_train]]
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# ==============================
# TRANSFORMER MODEL
# ==============================
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=300):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2) * (-np.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(pos*div)
        pe[:,1::2] = torch.cos(pos*div)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:,:x.size(1)]

class SignTransformer(nn.Module):
    def __init__(self):
        super().__init__()
        self.input_proj = nn.Linear(FEATURE_DIM, D_MODEL)
        self.cls_token = nn.Parameter(torch.zeros(1,1,D_MODEL))
        self.pos_enc = PositionalEncoding(D_MODEL, max_len=MAX_LEN+1)
        enc_layer = nn.TransformerEncoderLayer(d_model=D_MODEL, nhead=N_HEADS,
                                               dim_feedforward=D_MODEL*4,
                                               dropout=0.1, batch_first=True)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=N_LAYERS)
        self.classifier = nn.Sequential(nn.LayerNorm(D_MODEL), nn.Linear(D_MODEL,num_classes))

    def forward(self, x):
        x = self.input_proj(x)
        B = x.size(0)
        cls = self.cls_token.expand(B, -1, -1)
        x = torch.cat([cls, x], dim=1)
        x = self.pos_enc(x)
        x = self.encoder(x)
        return self.classifier(x[:,0])

model = SignTransformer().to(DEVICE)

# ==============================
# TRAINING SETUP
# ==============================
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_losses, val_losses = [], []
train_accs, val_accs = [], []

best_val = 0
pat = 0

# ==============================
# TRAIN LOOP
# ==============================
for epoch in range(EPOCHS):
    model.train()
    t_loss, correct, total = 0,0,0

    for x,y in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}"):
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        t_loss += loss.item()
        correct += (out.argmax(1) == y).sum().item()
        total += y.size(0)

    train_loss = t_loss / len(train_loader)
    train_acc = correct / total

    model.eval()
    v_loss, v_correct, v_total = 0,0,0
    with torch.no_grad():
        for x,y in val_loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss = criterion(out, y)
            v_loss += loss.item()
            v_correct += (out.argmax(1) == y).sum().item()
            v_total += y.size(0)

    val_loss = v_loss / len(val_loader)
    val_acc = v_correct / v_total

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs.append(train_acc)
    val_accs.append(val_acc)

    print(f"\nEpoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_val:
        best_val = val_acc
        torch.save(model.state_dict(), "best_model.pth")
        pat = 0
        print("✅ Model Saved")
    else:
        pat += 1
        if pat >= PATIENCE:
            print("⛔ Early stopping triggered")
            break

# ==============================
# TEST
# ==============================
model.load_state_dict(torch.load("best_model.pth"))
model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for x,y in test_loader:
        x = x.to(DEVICE)
        out = model(x)
        preds = out.argmax(1).cpu().numpy()
        y_pred.extend(preds)
        y_true.extend(y.numpy())

test_acc = accuracy_score(y_true, y_pred)
print("\n✅ Test Accuracy:", test_acc)
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# ==============================
# PLOTS
# ==============================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Loss Curve")

plt.subplot(1,2,2)
plt.plot(train_accs, label="Train Acc")
plt.plot(val_accs, label="Val Acc")
plt.legend()
plt.title("Accuracy Curve")
plt.show()
# Out:
# Using device: cuda
# Train samples: 2041
# Val samples: 401
# Test samples: 542
# Padding sequences to length: 120
# Epoch 1/60: 100%|██████████| 64/64 [00:06<00:00, 10.37it/s]
# Epoch 1 | Train Loss: 4.6481 | Train Acc: 0.0122 | Val Loss: 4.7989 | Val Acc: 0.0000
# Epoch 2/60: 100%|██████████| 64/64 [00:06<00:00, 10.54it/s]
# Epoch 2 | Train Loss: 4.2045 | Train Acc: 0.0314 | Val Loss: 4.1834 | Val Acc: 0.0299
# ✅ Model Saved
# Epoch 3/60: 100%|██████████| 64/64 [00:05<00:00, 10.77it/s]
# Epoch 3 | Train Loss: 3.5081 | Train Acc: 0.0911 | Val Loss: 3.8056 | Val Acc: 0.0648
# ✅ Model Saved
# Epoch 4/60: 100%|██████████| 64/64 [00:06<00:00, 10.60it/s]
# Epoch 4 | Train Loss: 3.2392 | Train Acc: 0.1421 | Val Loss: 3.5484 | Val Acc: 0.1397
# ✅ Model Saved
# Epoch 5/60: 100%|██████████| 64/64 [00:05<00:00, 11.07it/s]
# Epoch 5 | Train Loss: 2.8478 | Train Acc: 0.1999 | Val Loss: 3.2243 | Val Acc: 0.1820
# ✅ Model Saved
# Epoch 6/60: 100%|██████████| 64/64 [00:06<00:00, 10.59it/s]
# Epoch 6 | Train Loss: 2.5802 | Train Acc: 0.2817 | Val Loss: 2.9521 | Val Acc: 0.2494
# ✅ Model Saved
# Epoch 7/60: 100%|██████████| 64/64 [00:05<00:00, 10.92it/s]
# Epoch 7 | Train Loss: 2.3972 | Train Acc: 0.3567 | Val Loss: 2.7260 | Val Acc: 0.3017
# ✅ Model Saved
# Epoch 8/60: 100%|██████████| 64/64 [00:05<00:00, 10.77it/s]
# Epoch 8 | Train Loss: 2.1295 | Train Acc: 0.4312 | Val Loss: 2.4537 | Val Acc: 0.3766
# ✅ Model Saved
# Epoch 9/60: 100%|██████████| 64/64 [00:06<00:00, 10.53it/s]
# Epoch 9 | Train Loss: 1.8103 | Train Acc: 0.5194 | Val Loss: 2.2153 | Val Acc: 0.4514
# ✅ Model Saved
# Epoch 10/60: 100%|██████████| 64/64 [00:05<00:00, 10.95it/s]
# Epoch 10 | Train Loss: 1.6468 | Train Acc: 0.5757 | Val Loss: 1.9805 | Val Acc: 0.4988
# ✅ Model Saved
# Epoch 11/60: 100%|██████████| 64/64 [00:05<00:00, 10.77it/s]
# Epoch 11 | Train Loss: 1.3932 | Train Acc: 0.6482 | Val Loss: 1.8452 | Val Acc: 0.5661
# ✅ Model Saved
# Epoch 12/60: 100%|██████████| 64/64 [00:06<00:00, 10.60it/s]
# Epoch 12 | Train Loss: 1.3394 | Train Acc: 0.7188 | Val Loss: 1.6586 | Val Acc: 0.5910
# ✅ Model Saved
# Epoch 13/60: 100%|██████████| 64/64 [00:05<00:00, 10.85it/s]
# Epoch 13 | Train Loss: 1.1101 | Train Acc: 0.7384 | Val Loss: 1.5264 | Val Acc: 0.6309
# ✅ Model Saved
# Epoch 14/60: 100%|██████████| 64/64 [00:05<00:00, 11.12it/s]
# Epoch 14 | Train Loss: 0.9830 | Train Acc: 0.7727 | Val Loss: 1.4068 | Val Acc: 0.6534
# ✅ Model Saved
# Epoch 15/60: 100%|██████████| 64/64 [00:05<00:00, 11.12it/s]
# Epoch 15 | Train Loss: 0.9450 | Train Acc: 0.7923 | Val Loss: 1.3579 | Val Acc: 0.6484
# Epoch 16/60: 100%|██████████| 64/64 [00:06<00:00, 10.29it/s]
# Epoch 16 | Train Loss: 0.8509 | Train Acc: 0.8329 | Val Loss: 1.2435 | Val Acc: 0.6708
# ✅ Model Saved
# Epoch 17/60: 100%|██████████| 64/64 [00:05<00:00, 10.99it/s]
# Epoch 17 | Train Loss: 0.7672 | Train Acc: 0.8324 | Val Loss: 1.2382 | Val Acc: 0.6883
# ✅ Model Saved
# Epoch 18/60: 100%|██████████| 64/64 [00:05<00:00, 10.77it/s]
# Epoch 18 | Train Loss: 0.6828 | Train Acc: 0.8638 | Val Loss: 1.1555 | Val Acc: 0.6683
# Epoch 19/60: 100%|██████████| 64/64 [00:06<00:00, 10.64it/s]
# Epoch 19 | Train Loss: 0.5905 | Train Acc: 0.8780 | Val Loss: 1.1173 | Val Acc: 0.7082
# ✅ Model Saved
# Epoch 20/60: 100%|██████████| 64/64 [00:05<00:00, 10.75it/s]
# Epoch 20 | Train Loss: 0.5144 | Train Acc: 0.9005 | Val Loss: 1.0870 | Val Acc: 0.6983
# Epoch 21/60: 100%|██████████| 64/64 [00:06<00:00, 10.57it/s]
# Epoch 21 | Train Loss: 0.4764 | Train Acc: 0.8976 | Val Loss: 1.0362 | Val Acc: 0.7082
# Epoch 22/60: 100%|██████████| 64/64 [00:05<00:00, 11.27it/s]
# Epoch 22 | Train Loss: 0.4200 | Train Acc: 0.9172 | Val Loss: 0.9827 | Val Acc: 0.7332
# ✅ Model Saved
# Epoch 23/60: 100%|██████████| 64/64 [00:06<00:00, 10.51it/s]
# Epoch 23 | Train Loss: 0.3938 | Train Acc: 0.9221 | Val Loss: 0.9381 | Val Acc: 0.7481
# ✅ Model Saved
# Epoch 24/60: 100%|██████████| 64/64 [00:05<00:00, 11.02it/s]
# Epoch 24 | Train Loss: 0.3719 | Train Acc: 0.9260 | Val Loss: 0.9278 | Val Acc: 0.7406
# Epoch 25/60: 100%|██████████| 64/64 [00:05<00:00, 11.29it/s]
# Epoch 25 | Train Loss: 0.2785 | Train Acc: 0.9456 | Val Loss: 0.8952 | Val Acc: 0.7481
# Epoch 26/60: 100%|██████████| 64/64 [00:05<00:00, 10.88it/s]
# Epoch 26 | Train Loss: 0.2949 | Train Acc: 0.9388 | Val Loss: 0.8573 | Val Acc: 0.7631
# ✅ Model Saved
# Epoch 27/60: 100%|██████████| 64/64 [00:06<00:00, 10.53it/s]
# Epoch 27 | Train Loss: 0.2483 | Train Acc: 0.9559 | Val Loss: 0.8634 | Val Acc: 0.7282
# Epoch 28/60: 100%|██████████| 64/64 [00:05<00:00, 10.81it/s]
# Epoch 28 | Train Loss: 0.2153 | Train Acc: 0.9608 | Val Loss: 0.8113 | Val Acc: 0.7556
# Epoch 29/60: 100%|██████████| 64/64 [00:06<00:00, 10.27it/s]
# Epoch 29 | Train Loss: 0.2241 | Train Acc: 0.9623 | Val Loss: 0.8589 | Val Acc: 0.7332
# Epoch 30/60: 100%|██████████| 64/64 [00:06<00:00, 10.29it/s]
# Epoch 30 | Train Loss: 0.1852 | Train Acc: 0.9691 | Val Loss: 0.7606 | Val Acc: 0.7805
# ✅ Model Saved
# Epoch 31/60: 100%|██████████| 64/64 [00:05<00:00, 11.05it/s]
# Epoch 31 | Train Loss: 0.1656 | Train Acc: 0.9701 | Val Loss: 0.7205 | Val Acc: 0.7880
# ✅ Model Saved
# Epoch 32/60: 100%|██████████| 64/64 [00:05<00:00, 10.83it/s]
# Epoch 32 | Train Loss: 0.1475 | Train Acc: 0.9711 | Val Loss: 0.7947 | Val Acc: 0.7930
# ✅ Model Saved
# Epoch 33/60: 100%|██████████| 64/64 [00:06<00:00, 10.36it/s]
# Epoch 33 | Train Loss: 0.1413 | Train Acc: 0.9731 | Val Loss: 0.7944 | Val Acc: 0.7830
# Epoch 34/60: 100%|██████████| 64/64 [00:06<00:00, 10.66it/s]
# Epoch 34 | Train Loss: 0.1134 | Train Acc: 0.9853 | Val Loss: 0.7646 | Val Acc: 0.7805
# Epoch 35/60: 100%|██████████| 64/64 [00:06<00:00, 10.53it/s]
# Epoch 35 | Train Loss: 0.1158 | Train Acc: 0.9814 | Val Loss: 0.7006 | Val Acc: 0.8030
# ✅ Model Saved
# Epoch 36/60: 100%|██████████| 64/64 [00:05<00:00, 10.91it/s]
# Epoch 36 | Train Loss: 0.0995 | Train Acc: 0.9829 | Val Loss: 0.6994 | Val Acc: 0.8055
# ✅ Model Saved
# Epoch 37/60: 100%|██████████| 64/64 [00:05<00:00, 11.03it/s]
# Epoch 37 | Train Loss: 0.1006 | Train Acc: 0.9804 | Val Loss: 0.7142 | Val Acc: 0.7930
# Epoch 38/60: 100%|██████████| 64/64 [00:05<00:00, 11.04it/s]
# Epoch 38 | Train Loss: 0.0817 | Train Acc: 0.9843 | Val Loss: 0.7072 | Val Acc: 0.7980
# Epoch 39/60: 100%|██████████| 64/64 [00:06<00:00, 10.44it/s]
# Epoch 39 | Train Loss: 0.0846 | Train Acc: 0.9824 | Val Loss: 0.6902 | Val Acc: 0.8155
# ✅ Model Saved
# Epoch 40/60: 100%|██████████| 64/64 [00:06<00:00, 10.41it/s]
# Epoch 40 | Train Loss: 0.0756 | Train Acc: 0.9873 | Val Loss: 0.7423 | Val Acc: 0.8080
# Epoch 41/60: 100%|██████████| 64/64 [00:05<00:00, 10.96it/s]
# Epoch 41 | Train Loss: 0.0667 | Train Acc: 0.9897 | Val Loss: 0.7232 | Val Acc: 0.7830
# Epoch 42/60: 100%|██████████| 64/64 [00:06<00:00, 10.63it/s]
# Epoch 42 | Train Loss: 0.0643 | Train Acc: 0.9853 | Val Loss: 0.6942 | Val Acc: 0.7880
# Epoch 43/60: 100%|██████████| 64/64 [00:05<00:00, 10.93it/s]
# Epoch 43 | Train Loss: 0.0594 | Train Acc: 0.9873 | Val Loss: 0.7540 | Val Acc: 0.8105
# Epoch 44/60: 100%|██████████| 64/64 [00:05<00:00, 10.94it/s]
# Epoch 44 | Train Loss: 0.0568 | Train Acc: 0.9897 | Val Loss: 0.7166 | Val Acc: 0.8055
# Epoch 45/60: 100%|██████████| 64/64 [00:06<00:00, 10.55it/s]
# Epoch 45 | Train Loss: 0.0499 | Train Acc: 0.9951 | Val Loss: 0.7595 | Val Acc: 0.7830
# Epoch 46/60: 100%|██████████| 64/64 [00:05<00:00, 11.01it/s]
# Epoch 46 | Train Loss: 0.0418 | Train Acc: 0.9961 | Val Loss: 0.7647 | Val Acc: 0.8180
# ✅ Model Saved
# Epoch 47/60: 100%|██████████| 64/64 [00:05<00:00, 10.77it/s]
# Epoch 47 | Train Loss: 0.0390 | Train Acc: 0.9907 | Val Loss: 0.7310 | Val Acc: 0.7955
# Epoch 48/60: 100%|██████████| 64/64 [00:06<00:00, 10.52it/s]
# Epoch 48 | Train Loss: 0.0416 | Train Acc: 0.9931 | Val Loss: 0.7474 | Val Acc: 0.7905
# Epoch 49/60: 100%|██████████| 64/64 [00:05<00:00, 10.99it/s]
# Epoch 49 | Train Loss: 0.0317 | Train Acc: 0.9956 | Val Loss: 0.7090 | Val Acc: 0.8080
# Epoch 50/60: 100%|██████████| 64/64 [00:05<00:00, 11.05it/s]
# Epoch 50 | Train Loss: 0.0302 | Train Acc: 0.9956 | Val Loss: 0.7238 | Val Acc: 0.7955
# Epoch 51/60: 100%|██████████| 64/64 [00:05<00:00, 11.00it/s]
# Epoch 51 | Train Loss: 0.0370 | Train Acc: 0.9927 | Val Loss: 0.7166 | Val Acc: 0.7955
# Epoch 52/60: 100%|██████████| 64/64 [00:05<00:00, 10.92it/s]
# Epoch 52 | Train Loss: 0.0289 | Train Acc: 0.9951 | Val Loss: 0.7447 | Val Acc: 0.7930
# Epoch 53/60: 100%|██████████| 64/64 [00:06<00:00, 10.29it/s]
# Epoch 53 | Train Loss: 0.0264 | Train Acc: 0.9961 | Val Loss: 0.6848 | Val Acc: 0.8279
# ✅ Model Saved
# Epoch 54/60: 100%|██████████| 64/64 [00:05<00:00, 10.88it/s]
# Epoch 54 | Train Loss: 0.0245 | Train Acc: 0.9966 | Val Loss: 0.7282 | Val Acc: 0.8030
# Epoch 55/60: 100%|██████████| 64/64 [00:05<00:00, 10.68it/s]
# Epoch 55 | Train Loss: 0.0201 | Train Acc: 0.9985 | Val Loss: 0.7116 | Val Acc: 0.8080
# Epoch 56/60: 100%|██████████| 64/64 [00:05<00:00, 10.99it/s]
# Epoch 56 | Train Loss: 0.0219 | Train Acc: 0.9951 | Val Loss: 0.6917 | Val Acc: 0.8180
# Epoch 57/60: 100%|██████████| 64/64 [00:05<00:00, 10.80it/s]
# Epoch 57 | Train Loss: 0.0341 | Train Acc: 0.9917 | Val Loss: 0.7482 | Val Acc: 0.8055
# Epoch 58/60: 100%|██████████| 64/64 [00:06<00:00, 10.48it/s]
# Epoch 58 | Train Loss: 0.0288 | Train Acc: 0.9931 | Val Loss: 0.7882 | Val Acc: 0.7905
# Epoch 59/60: 100%|██████████| 64/64 [00:06<00:00,  9.92it/s]
# Epoch 59 | Train Loss: 0.0272 | Train Acc: 0.9922 | Val Loss: 0.8004 | Val Acc: 0.7930
# Epoch 60/60: 100%|██████████| 64/64 [00:06<00:00, 10.58it/s]
# Epoch 60 | Train Loss: 0.0158 | Train Acc: 0.9976 | Val Loss: 0.7038 | Val Acc: 0.8105
# ⛔ Early stopping triggered
#
# ✅ Test Accuracy: 0.8118081180811808
#
# Classification Report:
#
#                     precision    recall  f1-score   support
#
#           1 DOLLAR       0.80      0.80      0.80         5
#          5 DOLLARS       1.00      1.00      1.00         5
#             8 HOUR       1.00      0.40      0.57         5
#           9 OCLOCK       1.00      0.80      0.89         5
#       A LITTLE BIT       0.57      0.80      0.67         5
#         A-LINE BOB       1.00      1.00      1.00         5
#         ABBREVIATE       1.00      1.00      1.00         5
#              ABOUT       1.00      1.00      1.00         6
#              ABOVE       1.00      0.80      0.89         5
# ABSOLUTELY NOTHING       0.80      0.80      0.80         5
#             ACCENT       1.00      0.60      0.75         5
#             ACCEPT       1.00      0.80      0.89         5
#             ACCESS       1.00      0.80      0.89         5
#           ACCIDENT       0.62      1.00      0.77         5
#         ACCOMPLISH       0.83      1.00      0.91         5
#          ACCORDION       0.83      1.00      0.91         5
#         ACCOUNTANT       1.00      0.60      0.75         5
#            ACQUIRE       0.75      0.60      0.67         5
#                ACT       1.00      0.60      0.75         5
#             ACTION       1.00      1.00      1.00         5
#              ACTOR       1.00      0.60      0.75         5
#                ADD       0.57      0.80      0.67         5
#             ADDICT       1.00      0.80      0.89         5
#            ADDRESS       0.80      0.80      0.80         5
#             ADMIRE       1.00      1.00      1.00         5
#              ADMIT       1.00      0.80      0.89         5
#              ADOPT       0.75      0.60      0.67         5
#              ADULT       1.00      1.00      1.00         5
#          ADVANTAGE       1.00      0.60      0.75         5
#          ADVERTISE       0.71      1.00      0.83         5
#             AFRICA       0.75      0.60      0.67         5
#              AFTER       0.00      0.00      0.00         5
#          AFTERNOON       0.50      0.40      0.44         5
#              AGAIN       1.00      0.40      0.57         5
#            AGAINST       0.75      0.60      0.67         5
#                AGE       1.00      0.80      0.89         5
#             AGENCY       0.80      0.80      0.80         5
#          AGREEMENT       1.00      1.00      1.00         5
#           AIRPLANE       0.67      0.80      0.73         5
#              ALARM       0.83      1.00      0.91         5
#             ALASKA       1.00      0.80      0.89         5
#            ALCOHOL       1.00      0.60      0.75         5
#              ALIGN       0.83      1.00      0.91         5
#                ALL       0.71      1.00      0.83         5
#            ALL DAY       1.00      0.80      0.89         5
#           ALL GONE       0.71      1.00      0.83         5
#      ALL OF_SUDDEN       1.00      0.80      0.89         5
#           ALL OVER       0.75      0.60      0.67         5
#      ALL OVER_BODY       1.00      0.80      0.89         5
#       ALL TOGETHER       0.83      1.00      0.91         5
#            ALL WAY       1.00      0.80      0.89         5
#              ALONE       0.75      0.60      0.67         5
#           ALPHABET       0.80      0.80      0.80         5
#            ALRIGHT       0.80      0.80      0.80         5
#             ALWAYS       0.83      0.83      0.83         6
#            AMAZING       0.71      1.00      0.83         5
#            AMERICA       1.00      0.83      0.91         6
#            ANALYZE       1.00      1.00      1.00         6
#                AND       1.00      0.67      0.80         6
#              ANGEL       1.00      1.00      1.00         5
#              ANGRY       1.00      1.00      1.00         6
#             ANIMAL       1.00      0.80      0.89         5
#           ANNOUNCE       1.00      0.80      0.89         5
#             ANSWER       0.75      1.00      0.86         6
#            ANTLERS       0.83      1.00      0.91         5
#                ANY       0.80      0.80      0.80         5
#             ANYONE       0.50      0.20      0.29         5
#              APART       1.00      1.00      1.00         5
#             APPEAR       0.57      0.80      0.67         5
#              APPLE       0.62      1.00      0.77         5
#        APPOINTMENT       0.60      0.60      0.60         5
#              APRIL       1.00      1.00      1.00         5
#         ARCHEOLOGY       0.75      0.60      0.67         5
#               AREA       0.57      0.80      0.67         5
#              ARGUE       0.75      1.00      0.86         6
#            ARIZONA       0.80      0.80      0.80         5
#                ARM       1.00      0.90      0.95        10
#               ARMY       0.80      0.80      0.80         5
#            ARREST1       0.57      0.67      0.62         6
#            ARREST2       0.75      0.60      0.67         5
#            ARREST3       0.71      1.00      0.83         5
#             ARRIVE       1.00      0.60      0.75         5
#                ART       0.80      0.80      0.80         5
#            ARTICLE       1.00      0.83      0.91         6
#    ARTICULATE SIGN       1.00      1.00      1.00         5
#               ASIA       0.56      0.83      0.67         6
#                ASK       1.00      1.00      1.00         6
#           ASSEMBLY       0.57      0.80      0.67         5
#             ASSIGN       0.71      1.00      0.83         5
#             ASSIST       0.50      0.40      0.44         5
#          ASSISTANT       0.25      0.20      0.22         5
#          ASTRONAUT       0.67      1.00      0.80         6
#                 AT       0.83      1.00      0.91         5
#            ATHLETE       0.71      1.00      0.83         5
#            ATLANTA       0.67      0.40      0.50         5
#          ATTENTION       0.86      1.00      0.92         6
#           ATTITUDE       0.62      1.00      0.77         5
#           AUDIENCE       0.62      1.00      0.77         5
#         AUDITORIUM       0.83      1.00      0.91         5
#               AUNT       1.00      1.00      1.00         6
#          AUSTRALIA       1.00      0.83      0.91         6
#             AUTISM       0.00      0.00      0.00         1
#            AUTISM1       0.80      0.80      0.80         5
#            AUTISM2       0.83      1.00      0.91         5
#          AUTOMATIC       0.62      1.00      0.77         5
#
#           accuracy                           0.81       542
#          macro avg       0.82      0.80      0.79       542
#       weighted avg       0.83      0.81      0.80       542
