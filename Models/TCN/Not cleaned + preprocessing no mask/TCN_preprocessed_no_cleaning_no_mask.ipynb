# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
import os
import numpy as np
import re
from collections import defaultdict, Counter
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import pickle
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# CONFIGURATION
# ============================================================================
DATASET_PATH = "/kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits"
CACHE_PATH = "./cache"
MIN_FREQUENCY = 1  # Minimum samples per label (set to 1 for all, increase to filter rare labels)

# ============================================================================
# LOAD DATA FROM SPLIT FOLDERS
# ============================================================================
def load_split_data(dataset_path, split_name):
    """
    Load data from a specific split folder (train, val, or test)
    
    Args:
        dataset_path: Path to the main dataset directory
        split_name: Name of the split folder ('train', 'val', 'test')
    
    Returns:
        data: numpy array of sequences
        labels: numpy array of labels
        file_list: list of file paths
    """
    split_path = Path(dataset_path) / split_name
    
    if not split_path.exists():
        print(f"⚠️ Warning: {split_name} folder not found at {split_path}")
        return np.array([]), np.array([]), []
    
    print(f"📂 Loading {split_name} split from: {split_path}")
    
    files = list(split_path.glob("*.npy"))
    print(f"📁 Found {len(files)} files in {split_name}")
    
    data_list = []
    labels_list = []
    file_list = []
    
    for file_path in tqdm(files, desc=f"Loading {split_name}"):
        try:
            # Load data
            data = np.load(file_path)
            data_list.append(data)
            
            # Extract label from filename
            name = file_path.stem
            # Remove trailing numbers (video ID) to get the gloss
            label = re.sub(r'\s+\d+$', '', name)
            labels_list.append(label)
            file_list.append(file_path)
            
        except Exception as e:
            print(f"❌ Error loading {file_path.name}: {e}")
    
    return np.array(data_list, dtype=object), np.array(labels_list), file_list

def load_all_splits(dataset_path):
    """
    Load all splits (train, val, test) from the dataset
    
    Returns:
        Dictionary containing data, labels, and file lists for each split
    """
    print("="*60)
    print("📊 LOADING PRE-SPLIT DATASET")
    print("="*60)
    
    splits = {}
    
    for split_name in ['train', 'val', 'test']:
        data, labels, file_list = load_split_data(dataset_path, split_name)
        
        splits[split_name] = {
            'data': data,
            'labels': labels,
            'file_list': file_list,
            'num_samples': len(data),
            'unique_labels': len(np.unique(labels)) if len(data) > 0 else 0
        }
        
        print(f"  {split_name.capitalize()}: {len(data)} samples, {splits[split_name]['unique_labels']} unique glosses")
    
    return splits

# ============================================================================
# ANALYZE SPLIT STATISTICS
# ============================================================================
def analyze_split_distribution(splits):
    """Analyze label distribution across splits"""
    print("\n" + "="*60)
    print("📊 SPLIT DISTRIBUTION ANALYSIS")
    print("="*60)
    
    # Overall statistics
    total_samples = sum(splits[split]['num_samples'] for split in ['train', 'val', 'test'])
    
    print(f"\n📈 Overall Statistics:")
    print(f"  Total samples: {total_samples}")
    print(f"  Train: {splits['train']['num_samples']} ({splits['train']['num_samples']/total_samples*100:.1f}%)")
    print(f"  Val: {splits['val']['num_samples']} ({splits['val']['num_samples']/total_samples*100:.1f}%)")
    print(f"  Test: {splits['test']['num_samples']} ({splits['test']['num_samples']/total_samples*100:.1f}%)")
    
    # Check label consistency across splits
    train_labels = set(splits['train']['labels'])
    val_labels = set(splits['val']['labels'])
    test_labels = set(splits['test']['labels'])
    
    print(f"\n🏷️ Label Coverage:")
    print(f"  Train unique labels: {len(train_labels)}")
    print(f"  Val unique labels: {len(val_labels)}")
    print(f"  Test unique labels: {len(test_labels)}")
    
    # Labels only in certain splits
    only_train = train_labels - val_labels - test_labels
    only_val = val_labels - train_labels - test_labels
    only_test = test_labels - train_labels - val_labels
    all_splits = train_labels & val_labels & test_labels
    
    if only_train:
        print(f"\n  ⚠️ Labels only in train: {len(only_train)}")
    if only_val:
        print(f"  ⚠️ Labels only in val: {len(only_val)}")
    if only_test:
        print(f"  ⚠️ Labels only in test: {len(only_test)}")
    print(f"  ✅ Labels in all splits: {len(all_splits)}")
    
    return {
        'train_labels': train_labels,
        'val_labels': val_labels,
        'test_labels': test_labels
    }

# ============================================================================
# GET CLASS WEIGHTS FROM TRAIN SPLIT
# ============================================================================
def get_class_weights_from_split(split_data):
    """
    Calculate class weights from training split for imbalanced dataset
    
    Args:
        split_data: Dictionary containing 'data' and 'labels' for a split
    
    Returns:
        Dictionary of class weights
    """
    labels = split_data['labels']
    label_counts = Counter(labels)
    
    total_samples = len(labels)
    n_classes = len(label_counts)
    
    class_weights = {}
    for label, count in label_counts.items():
        # Option 1: Balanced weight
        weight = total_samples / (n_classes * count)
        
        # Option 2: Inverse frequency (alternative)
        # weight = 1.0 / count
        
        class_weights[label] = weight
    
    return class_weights

# ============================================================================
# PRINT DETAILED SUMMARY
# ============================================================================
def print_detailed_summary(splits):
    """Print detailed summary for each split"""
    print("\n" + "="*60)
    print("📊 DETAILED SPLIT SUMMARY")
    print("="*60)
    
    for split_name in ['train', 'val', 'test']:
        split = splits[split_name]
        labels = split['labels']
        
        if len(labels) == 0:
            print(f"\n⚠️ {split_name.upper()} split is empty!")
            continue
        
        label_counts = Counter(labels)
        counts_array = list(label_counts.values())
        
        print(f"\n📌 {split_name.upper()} SPLIT:")
        print(f"  Total samples: {len(labels)}")
        print(f"  Unique glosses: {len(label_counts)}")
        print(f"  Average samples/gloss: {np.mean(counts_array):.2f}")
        print(f"  Median samples/gloss: {np.median(counts_array):.0f}")
        print(f"  Min samples/gloss: {min(counts_array)}")
        print(f"  Max samples/gloss: {max(counts_array)}")
        
        # Show top 5 most frequent
        print(f"\n  Top 5 most frequent glosses:")
        for i, (label, count) in enumerate(label_counts.most_common(5), 1):
            print(f"    {i}. {label[:35]:<35} {count:>5} samples")
        
        # Show bottom 5 least frequent
        print(f"\n  Bottom 5 least frequent glosses:")
        for i, (label, count) in enumerate(label_counts.most_common()[-5:], 1):
            print(f"    {i}. {label[:35]:<35} {count:>5} samples")

# ============================================================================
# VALIDATE SPLIT CONSISTENCY
# ============================================================================
def validate_splits(splits):
    """
    Validate that splits are properly separated (no data leakage)
    """
    print("\n" + "="*60)
    print("🔍 VALIDATING SPLIT INTEGRITY")
    print("="*60)
    
    # Check for overlapping files
    train_files = set(splits['train']['file_list'])
    val_files = set(splits['val']['file_list'])
    test_files = set(splits['test']['file_list'])
    
    train_val_overlap = train_files & val_files
    train_test_overlap = train_files & test_files
    val_test_overlap = val_files & test_files
    
    print(f"\n📁 File Overlap Check:")
    print(f"  Train-Val overlap: {len(train_val_overlap)} files")
    print(f"  Train-Test overlap: {len(train_test_overlap)} files")
    print(f"  Val-Test overlap: {len(val_test_overlap)} files")
    
    if len(train_val_overlap) == 0 and len(train_test_overlap) == 0 and len(val_test_overlap) == 0:
        print("  ✅ No file overlap detected - splits are clean!")
    else:
        print("  ⚠️ Warning: File overlap detected - potential data leakage!")
    
    return {
        'train_val_overlap': len(train_val_overlap),
        'train_test_overlap': len(train_test_overlap),
        'val_test_overlap': len(val_test_overlap)
    }

# ============================================================================
# SAVE PROCESSED SPLITS
# ============================================================================
def save_processed_splits(splits, output_path="./processed_splits"):
    """Save processed splits to disk for faster loading"""
    output_path = Path(output_path)
    output_path.mkdir(parents=True, exist_ok=True)
    
    for split_name in ['train', 'val', 'test']:
        split = splits[split_name]
        
        if len(split['data']) > 0:
            np.save(output_path / f'{split_name}_data.npy', split['data'], allow_pickle=True)
            np.save(output_path / f'{split_name}_labels.npy', split['labels'])
            
            print(f"✅ Saved {split_name} split: {len(split['data'])} samples")
    
    # Save metadata
    metadata = {
        'train_samples': splits['train']['num_samples'],
        'val_samples': splits['val']['num_samples'],
        'test_samples': splits['test']['num_samples'],
        'total_samples': sum(splits[split]['num_samples'] for split in ['train', 'val', 'test']),
        'train_unique_labels': splits['train']['unique_labels'],
        'val_unique_labels': splits['val']['unique_labels'],
        'test_unique_labels': splits['test']['unique_labels']
    }
    
    with open(output_path / 'splits_metadata.pkl', 'wb') as f:
        pickle.dump(metadata, f)
    
    print(f"\n✅ All splits saved to {output_path}")

# ============================================================================
# MAIN EXECUTION
# ============================================================================
if __name__ == "__main__":
    # Load all splits
    splits = load_all_splits(DATASET_PATH)
    
    # Print detailed summary
    print_detailed_summary(splits)
    
    # Analyze split distribution
    label_sets = analyze_split_distribution(splits)
    
    # Validate splits
    overlap_stats = validate_splits(splits)
    
    # Get class weights from training split
    if splits['train']['num_samples'] > 0:
        class_weights = get_class_weights_from_split(splits['train'])
        print(f"\n⚖️ Class Weights (first 10 from train split):")
        for label, weight in list(class_weights.items())[:10]:
            print(f"  {label[:35]:<35} {weight:.4f}")
    
    # Access individual splits easily
    train_data = splits['train']['data']
    train_labels = splits['train']['labels']
    val_data = splits['val']['data']
    val_labels = splits['val']['labels']
    test_data = splits['test']['data']
    test_labels = splits['test']['labels']
    
    print("\n" + "="*60)
    print("✅ DATA LOADING COMPLETE!")
    print("="*60)
    print(f"\n📊 Ready to use:")
    print(f"  X_train: {train_data.shape if len(train_data) > 0 else 'Empty'}")
    print(f"  y_train: {len(train_labels)} samples")
    print(f"  X_val: {val_data.shape if len(val_data) > 0 else 'Empty'}")
    print(f"  y_val: {len(val_labels)} samples")
    print(f"  X_test: {test_data.shape if len(test_data) > 0 else 'Empty'}")
    print(f"  y_test: {len(test_labels)} samples")
    
    # Optionally save processed splits for faster future loading
    # save_processed_splits(splits, "./processed_splits")
    
    print("\n✅ Done!")
# ============================================================
# CPU-OPTIMIZED TCN FOR ASL LANDMARKS (TRAINING)
# Using Pre-split Data
# ============================================================

import numpy as np
from pathlib import Path
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR

# ============================================================
# CONFIG (CPU OPTIMIZED)
# ============================================================

DEVICE = "cpu"  # Force CPU usage

TARGET_FRAMES = 120
FEATURE_DIM = 438

# CPU-optimized batch size (smaller for CPU)
BATCH_SIZE = 4  # Reduced from 8 for CPU
EPOCHS = 90
LR = 3e-4
WEIGHT_DECAY = 1e-4

PATIENCE = 12
GRAD_CLIP = 1.0
LABEL_SMOOTH = 0.1

# Use fewer workers for CPU
NUM_WORKERS = 0  # Set to 0 to avoid multiprocessing issues

MODEL_SAVE_PATH = "tcn_best_model_cpu.pth"
LABEL_ENCODER_PATH = "label_encoder.npy"

# ============================================================
# LOAD YOUR DATA
# ============================================================

train_data = splits['train']['data']
train_labels = splits['train']['labels']
val_data = splits['val']['data']
val_labels = splits['val']['labels']
test_data = splits['test']['data']
test_labels = splits['test']['labels']

print("="*60)
print("📊 DATA INFORMATION (CPU MODE)")
print("="*60)
print(f"Train data type: {type(train_data)}")
print(f"Train data shape: {train_data.shape if hasattr(train_data, 'shape') else len(train_data)}")
print(f"Train labels shape: {train_labels.shape}")
print(f"Val data shape: {val_data.shape if hasattr(val_data, 'shape') else len(val_data)}")
print(f"Val labels shape: {val_labels.shape}")
print(f"Test data shape: {test_data.shape if hasattr(test_data, 'shape') else len(test_data)}")
print(f"Test labels shape: {test_labels.shape}")
print(f"Device: {DEVICE}")
print(f"Batch size: {BATCH_SIZE} (CPU optimized)")

# ============================================================
# CONVERT DATA TO CORRECT FORMAT
# ============================================================

def convert_to_array(data):
    """
    Convert object array to float32 numpy array
    """
    if isinstance(data, np.ndarray) and data.dtype == np.object_:
        # Stack all sequences into a single array
        shapes = [seq.shape for seq in data]
        if len(set(shapes)) > 1:
            print(f"⚠️ Warning: Different shapes found: {set(shapes)}")
            # Filter to keep only sequences with correct shape
            valid_indices = [i for i, seq in enumerate(data) if seq.shape == (TARGET_FRAMES, FEATURE_DIM)]
            print(f"Keeping {len(valid_indices)}/{len(data)} valid sequences")
            data = [data[i] for i in valid_indices]
        return np.stack(data).astype(np.float32)
    return data.astype(np.float32)

# Convert data
print("\n🔄 Converting data to correct format...")
train_data = convert_to_array(train_data)
val_data = convert_to_array(val_data)
test_data = convert_to_array(test_data)

print(f"Train data shape after conversion: {train_data.shape}")
print(f"Val data shape after conversion: {val_data.shape}")
print(f"Test data shape after conversion: {test_data.shape}")

# Also filter labels to match valid indices if needed
if len(train_data) != len(train_labels):
    print(f"⚠️ Adjusting labels to match data: {len(train_labels)} -> {len(train_data)}")
    train_labels = train_labels[:len(train_data)]
    val_labels = val_labels[:len(val_data)]
    test_labels = test_labels[:len(test_data)]

# ============================================================
# ENCODE LABELS
# ============================================================

all_labels = np.concatenate([train_labels, val_labels, test_labels])
le = LabelEncoder()
le.fit(all_labels)
num_classes = len(le.classes_)

y_train_encoded = le.transform(train_labels)
y_val_encoded = le.transform(val_labels)
y_test_encoded = le.transform(test_labels)

np.save(LABEL_ENCODER_PATH, le.classes_)
print(f"\n🏷️ Label encoding complete: {num_classes} unique glosses")

# ============================================================
# DATASET CLASS (NO MASK)
# ============================================================

class ASLDataset(Dataset):
    def __init__(self, data, labels):
        """
        data: numpy array of shape (n_samples, TARGET_FRAMES, FEATURE_DIM)
        labels: numpy array of encoded labels
        """
        self.data = torch.from_numpy(data).float()
        self.labels = torch.from_numpy(labels).long()

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # Transpose to (FEATURE_DIM, TARGET_FRAMES) for Conv1d
        x = self.data[idx].transpose(0, 1)  # (438, 120)
        y = self.labels[idx]
        return x, y

# Create dataloaders (CPU optimized)
train_dataset = ASLDataset(train_data, y_train_encoded)
val_dataset = ASLDataset(val_data, y_val_encoded)
test_dataset = ASLDataset(test_data, y_test_encoded)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

print(f"\n✅ DataLoaders created:")
print(f"  Train batches: {len(train_loader)}")
print(f"  Val batches: {len(val_loader)}")
print(f"  Test batches: {len(test_loader)}")

# ============================================================
# MODEL DEFINITION (CPU OPTIMIZED - Smaller Model)
# ============================================================

class TemporalBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dilation):
        super().__init__()
        padding = dilation
        # Reduced channel sizes for CPU
        self.net = nn.Sequential(
            nn.Conv1d(in_channels, out_channels, 3, padding=padding, dilation=dilation),
            nn.BatchNorm1d(out_channels),
            nn.ReLU(inplace=True),  # inplace=True saves memory
            nn.Conv1d(out_channels, out_channels, 3, padding=padding, dilation=dilation),
            nn.BatchNorm1d(out_channels),
            nn.ReLU(inplace=True),
        )
        self.res = nn.Conv1d(in_channels, out_channels, 1) if in_channels != out_channels else nn.Identity()

    def forward(self, x):
        y = self.net(x)
        y = y[..., :x.size(2)]
        return y + self.res(x)

class TCN(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        # Reduced channel sizes for CPU (from 192 to 128)
        channels = [128, 128, 128, 128]  # Smaller than original 192
        
        layers = []
        for i, c in enumerate(channels):
            in_dim = input_dim if i == 0 else channels[i-1]
            layers.append(TemporalBlock(in_dim, c, dilation=2**i))
        
        self.tcn = nn.Sequential(*layers)
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(channels[-1], num_classes)
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        """
        x: (batch, features, time)
        """
        x = self.tcn(x)                    # (batch, channels, time)
        x = self.global_avg_pool(x)        # (batch, channels, 1)
        x = x.squeeze(-1)                  # (batch, channels)
        x = self.dropout(x)
        return self.fc(x)                  # (batch, num_classes)

model = TCN(input_dim=FEATURE_DIM, num_classes=num_classes).to(DEVICE)

print(f"\n📐 Model Architecture (CPU Optimized):")
print(f"  Input: {FEATURE_DIM} features x {TARGET_FRAMES} frames")
print(f"  Output: {num_classes} classes")
print(f"  Channel size: 128 (reduced from 192)")
print(f"  Total parameters: {sum(p.numel() for p in model.parameters()):,}")

# ============================================================
# LOSS FUNCTION WITH CLASS WEIGHTS
# ============================================================

class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(y_train_encoded),
    y=y_train_encoded
)

# FIX: expand to all classes
full_class_weights = np.ones(num_classes, dtype=np.float32)
train_classes = np.unique(y_train_encoded)

for i, cls in enumerate(train_classes):
    full_class_weights[cls] = class_weights[i]

class_weights = torch.tensor(full_class_weights, dtype=torch.float32).to(DEVICE)

class SmoothCrossEntropy(nn.Module):
    def __init__(self, smoothing=0.1, weight=None):
        super().__init__()
        self.smoothing = smoothing
        self.weight = weight
        
    def forward(self, logits, targets):
        n_classes = logits.size(1)
        with torch.no_grad():
            true_dist = torch.zeros_like(logits)
            true_dist.fill_(self.smoothing / (n_classes - 1))
            true_dist.scatter_(1, targets.unsqueeze(1), 1.0 - self.smoothing)
        
        log_probs = torch.log_softmax(logits, dim=1)
        
        if self.weight is not None:
            weight = self.weight[targets]
            loss = -(true_dist * log_probs).sum(dim=1) * weight
        else:
            loss = -(true_dist * log_probs).sum(dim=1)
            
        return loss.mean()

criterion = SmoothCrossEntropy(smoothing=LABEL_SMOOTH, weight=class_weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = CosineAnnealingLR(optimizer, T_max=EPOCHS)

# ============================================================
# TRAINING FUNCTION
# ============================================================

def train_one_epoch(loader):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        
        optimizer.zero_grad()
        outputs = model(x)
        loss = criterion(outputs, y)
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        optimizer.step()
        
        total_loss += loss.item() * y.size(0)
        _, predicted = outputs.max(1)
        correct += predicted.eq(y).sum().item()
        total += y.size(0)
    
    return total_loss / total, correct / total

def evaluate(loader):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            outputs = model(x)
            loss = criterion(outputs, y)
            
            total_loss += loss.item() * y.size(0)
            _, predicted = outputs.max(1)
            correct += predicted.eq(y).sum().item()
            total += y.size(0)
    
    return total_loss / total, correct / total

# ============================================================
# TRAINING LOOP
# ============================================================

print("\n" + "="*60)
print("🚀 STARTING TRAINING (CPU MODE)")
print("="*60)
print("⚠️ Training on CPU will be slower. Consider using GPU if available.")
print("="*60)

best_val_acc = 0
patience_counter = 0
train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(EPOCHS):
    # Train
    train_loss, train_acc = train_one_epoch(train_loader)
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    
    # Validate
    val_loss, val_acc = evaluate(val_loader)
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    
    # Update scheduler
    scheduler.step()
    
    # Print progress
    print(f"Epoch {epoch+1:03d}/{EPOCHS} | "
          f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
          f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    
    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        patience_counter = 0
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_acc': val_acc,
            'val_loss': val_loss,
        }, MODEL_SAVE_PATH)
        print(f"  ✅ Best model saved! (Val Acc: {val_acc:.4f})")
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            print(f"\n⏹️ Early stopping at epoch {epoch+1}")
            break

# ============================================================
# FINAL EVALUATION
# ============================================================

print("\n" + "="*60)
print("📊 FINAL EVALUATION")
print("="*60)

# Load best model
checkpoint = torch.load(MODEL_SAVE_PATH, map_location=torch.device('cpu'))
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded best model from epoch {checkpoint['epoch']+1} with Val Acc: {checkpoint['val_acc']:.4f}")

# Test evaluation
test_loss, test_acc = evaluate(test_loader)
print(f"\n🎯 Test Set Results:")
print(f"  Test Loss: {test_loss:.4f}")
print(f"  Test Accuracy: {test_acc:.4f}")

# Per-class accuracy
def per_class_accuracy(loader, model, num_classes):
    model.eval()
    class_correct = torch.zeros(num_classes)
    class_total = torch.zeros(num_classes)
    
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            outputs = model(x)
            _, predicted = outputs.max(1)
            
            for i in range(len(y)):
                label = y[i]
                class_correct[label] += (predicted[i] == label).item()
                class_total[label] += 1
    
    return class_correct / (class_total + 1e-6)

per_class_acc = per_class_accuracy(test_loader, model, num_classes)
print(f"\n📈 Per-class accuracy (first 10 classes):")
for i in range(min(10, num_classes)):
    print(f"  Class {le.classes_[i]}: {per_class_acc[i]:.4f}")

# Find worst performing classes
worst_classes = np.argsort(per_class_acc.numpy())[:5]
print(f"\n⚠️ Worst performing classes:")
for i in worst_classes:
    print(f"  Class {le.classes_[i]}: {per_class_acc[i]:.4f}")

# ============================================================
# SAVE TRAINING HISTORY
# ============================================================

import pickle

history = {
    'train_losses': train_losses,
    'val_losses': val_losses,
    'train_accs': train_accs,
    'val_accs': val_accs,
    'best_val_acc': best_val_acc,
    'test_acc': test_acc,
    'num_classes': num_classes,
    'target_frames': TARGET_FRAMES,
    'feature_dim': FEATURE_DIM
}

with open('training_history_cpu.pkl', 'wb') as f:
    pickle.dump(history, f)

print(f"\n💾 Training history saved to 'training_history_cpu.pkl'")
print(f"💾 Best model saved to {MODEL_SAVE_PATH}")
print(f"💾 Label encoder saved to {LABEL_ENCODER_PATH}")

# ============================================================
# PLOT TRAINING CURVES
# ============================================================

try:
    import matplotlib.pyplot as plt
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    # Loss plot
    axes[0].plot(train_losses, label='Train Loss')
    axes[0].plot(val_losses, label='Val Loss')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].set_title('Training and Validation Loss (CPU)')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy plot
    axes[1].plot(train_accs, label='Train Acc')
    axes[1].plot(val_accs, label='Val Acc')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].set_title('Training and Validation Accuracy (CPU)')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('training_curves_cpu.png', dpi=150)
    plt.show()
    print("📊 Training curves saved to 'training_curves_cpu.png'")
    
except Exception as e:
    print(f"⚠️ Could not plot: {e}")

print("\n" + "="*60)
print("✅ TRAINING COMPLETE (CPU MODE)!")
print("="*60)
# Out:
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/splits.txt
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/splits.csv
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APRIL 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSISTANT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A LITTLE BIT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 74.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANIMAL 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTENTION 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADD 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCIDENT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOVE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICULATE SIGN 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 77.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANSWER 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICLE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCEPT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCORDION 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCIDENT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAINST 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIST 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUNT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARCHEOLOGY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTITUDE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A LITTLE BIT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABSOLUTELY NOTHING 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 52.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUSTRALIA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AIRPLANE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALIGN 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMAZING 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSEMBLY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOUNTANT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 69.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCENT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTOR 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALASKA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALPHABET 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 78.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOMPLISH 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOUNTANT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AND 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALIGN 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVERTISE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANSWER 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL GONE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARMY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALARM 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANNOUNCE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASTRONAUT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVANTAGE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATHLETE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCORDION 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDIENCE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARGUE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANTLERS 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUNT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 70.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OF_SUDDEN 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APART 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVERTISE 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALASKA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANIMAL 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCEPT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANNOUNCE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL DAY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGEL 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL DAY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ART 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSISTANT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICULATE SIGN 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALWAYS 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIST 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 69.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL GONE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARIZONA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AREA 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMAZING 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARMY 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTERNOON 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIGN 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPLE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPOINTMENT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSISTANT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDRESS 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANALYZE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 56.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIRE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 50.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ART 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL GONE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AREA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AREA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPOINTMENT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 68.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/8 HOUR 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/8 HOUR 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACQUIRE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OF_SUDDEN 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPEAR 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL DAY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTION 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTITUDE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL TOGETHER 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARCHEOLOGY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARCHEOLOGY 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCESS 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANNOUNCE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OF_SUDDEN 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOVE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APART 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASIA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTER 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 56.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALARM 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCENT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABBREVIATE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATLANTA 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APRIL 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTOR 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASIA 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTERNOON 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL WAY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 72.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 51.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALWAYS 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 73.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTION 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIGN 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOMPLISH 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL TOGETHER 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCESS 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFRICA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICULATE SIGN 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCORDION 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/5 DOLLARS 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTOMATIC 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 74.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANTLERS 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AIRPLANE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 78.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCESS 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANYONE 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALARM 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATLANTA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANSWER 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 51.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALONE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASTRONAUT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDICT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCENT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTERNOON 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALCOHOL 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDITORIUM 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMERICA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTER 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/1 DOLLAR 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANYONE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUSTRALIA 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUSTRALIA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGENCY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALCOHOL 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTOMATIC 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGENCY 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALRIGHT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL WAY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGEL 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTERNOON 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL DAY 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANALYZE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGREEMENT 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 72.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 54.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 55.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGREEMENT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADOPT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATLANTA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/1 DOLLAR 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ART 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 55.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL TOGETHER 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDICT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADD 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASK 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFRICA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCEPT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A-LINE BOB 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADULT 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTITUDE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTER 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGREEMENT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 79.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AND 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANIMAL 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALARM 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDRESS 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARMY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDITORIUM 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDRESS 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIRE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCENT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/9 OCLOCK 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APART 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIGN 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICLE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 57.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTION 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/5 DOLLARS 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGEL 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARIZONA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALWAYS 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARRIVE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALPHABET 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AREA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARGUE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ART 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/8 HOUR 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADD 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDICT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALCOHOL 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANTLERS 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAIN 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARIZONA 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATHLETE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGRY 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPOINTMENT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/9 OCLOCK 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPLE 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUNT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASK 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 52.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDITORIUM 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGRY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABBREVIATE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARRIVE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTOMATIC 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADOPT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTENTION 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCIDENT 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAIN 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASTRONAUT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOVE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/8 HOUR 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALIGN 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A LITTLE BIT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/9 OCLOCK 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 71.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALASKA 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDRESS 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOMPLISH 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASIA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAINST 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A-LINE BOB 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALCOHOL 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALRIGHT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICLE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 76.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER_BODY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANNOUNCE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 77.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASK 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPEAR 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 75.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCEPT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAIN 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIST 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANSWER 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSISTANT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPLE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASIA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAINST 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/1 DOLLAR 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPLE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 70.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADDICT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABBREVIATE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 75.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOVE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 73.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTENTION 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 53.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCESS 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGENCY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL WAY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADULT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPEAR 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALPHABET 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AND 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSEMBLY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUNT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTOR 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICLE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL WAY 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADD 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AND 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACQUIRE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARGUE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMERICA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL TOGETHER 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIT 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/5 DOLLARS 32.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 50.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALONE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AIRPLANE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSEMBLY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGREEMENT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALRIGHT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADULT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADOPT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALRIGHT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A-LINE BOB 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTISM 58.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANTLERS 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASK 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARCHEOLOGY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUSTRALIA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 57.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A LITTLE BIT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APART 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVANTAGE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARGUE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIRE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARMY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASTRONAUT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPOINTMENT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/9 OCLOCK 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOMPLISH 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER_BODY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDIENCE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIGN 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDIENCE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALIGN 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACT 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGEL 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVERTISE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCIDENT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTENTION 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALWAYS 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/1 DOLLAR 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFTER 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANY 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARIZONA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANYONE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTION 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFRICA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APRIL 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVANTAGE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANIMAL 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATLANTA 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANALYZE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/A-LINE BOB 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABSOLUTELY NOTHING 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AIRPLANE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER_BODY 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMAZING 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADULT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/5 DOLLARS 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALONE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVERTISE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAINST 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACTOR 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOUNTANT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARRIVE 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGRY 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMERICA 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGENCY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARRIVE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACQUIRE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALASKA 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABSOLUTELY NOTHING 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANALYZE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIRE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUTOMATIC 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 54.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALPHABET 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATHLETE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADMIT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADVANTAGE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABSOLUTELY NOTHING 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AFRICA 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCOUNTANT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AT 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDIENCE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATHLETE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OVER_BODY 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABBREVIATE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANY 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 7.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 79.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACQUIRE 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 7.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARM 71.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL GONE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMAZING 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARREST 76.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AMERICA 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANYONE 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALL OF_SUDDEN 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AUDITORIUM 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ALONE 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APRIL 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSEMBLY 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/AGAIN 3.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ADOPT 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/APPEAR 30.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ARTICULATE SIGN 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ASSIST 31.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ACCORDION 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ATTITUDE 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ABOUT 53.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val/ANGRY 4.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ALRIGHT 7.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/APPOINTMENT 9.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/8 HOUR.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ARRIVE 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/8 HOUR 9.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/AUTISM.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/APPEAR 6.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/APPLE 7.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ASSISTANT 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ACCESS.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ADMIT.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ASIA 6.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ALASKA 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ALL OF_SUDDEN.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/AUSTRALIA 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/AUSTRALIA 7.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ABSOLUTELY NOTHING 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ARREST 82.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ALL DAY 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ACQUIRE 7.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/AUDITORIUM.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/APART 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/ARGUE 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/AND 8.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/APPLE 5.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test/AMERICA 7.npy
# ...
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/ACCESS 24.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/AUTISM 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/ACTOR 2.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/ATHLETE 2.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/ALASKA 29.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/ARCHEOLOGY 19.npy
# /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train/ACCEPT 26.npy
# ============================================================
# 📊 LOADING PRE-SPLIT DATASET
# ============================================================
# 📂 Loading train split from: /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/train
# 📁 Found 2256 files in train
# Loading train: 100%|██████████| 2256/2256 [00:01<00:00, 1262.84it/s]
#   Train: 2256 samples, 101 unique glosses
# 📂 Loading val split from: /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/val
# 📁 Found 432 files in val
# Loading val: 100%|██████████| 432/432 [00:00<00:00, 1247.53it/s]
#   Val: 432 samples, 101 unique glosses
# 📂 Loading test split from: /kaggle/input/datasets/mariamhany44/100-words-preprocessed-not-cleaned-no-mask/splits/test
# 📁 Found 595 files in test
# Loading test: 100%|██████████| 595/595 [00:00<00:00, 1281.39it/s]
#   Test: 595 samples, 102 unique glosses
#
# ============================================================
# 📊 DETAILED SPLIT SUMMARY
# ============================================================
#
# 📌 TRAIN SPLIT:
#   Total samples: 2256
#   Unique glosses: 101
#   Average samples/gloss: 22.34
#   Median samples/gloss: 21
#   Min samples/gloss: 20
#   Max samples/gloss: 64
#
#   Top 5 most frequent glosses:
#     1. ARREST                                 64 samples
#     2. ARM                                    63 samples
#     3. AUTISM                                 44 samples
#     4. ABOUT                                  43 samples
#     5. ADVERTISE                              22 samples
#
#   Bottom 5 least frequent glosses:
#     1. AGREEMENT                              20 samples
#     2. ADULT                                  20 samples
#     3. ARRIVE                                 20 samples
#     4. AGAIN                                  20 samples
#     5. ACCOMPLISH                             20 samples
#
# 📌 VAL SPLIT:
#   Total samples: 432
#   Unique glosses: 101
#   Average samples/gloss: 4.28
#   Median samples/gloss: 4
#   Min samples/gloss: 4
#   Max samples/gloss: 13
#
#   Top 5 most frequent glosses:
#     1. ARM                                    13 samples
#     2. ARREST                                 13 samples
#     3. ABOUT                                   9 samples
#     4. AUTISM                                  9 samples
#     5. APRIL                                   4 samples
#
#   Bottom 5 least frequent glosses:
#     1. ANY                                     4 samples
#     2. ARRIVE                                  4 samples
#     3. AGAIN                                   4 samples
#     4. ANGRY                                   4 samples
#     5. ALL OVER_BODY                           4 samples
#
# 📌 TEST SPLIT:
#   Total samples: 595
#   Unique glosses: 102
#   Average samples/gloss: 5.83
#   Median samples/gloss: 6
#   Min samples/gloss: 1
#   Max samples/gloss: 15
#
#   Top 5 most frequent glosses:
#     1. ARREST                                 15 samples
#     2. ARM                                    15 samples
#     3. AUTISM                                 10 samples
#     4. ABOUT                                  10 samples
#     5. ALRIGHT                                 6 samples
#
#   Bottom 5 least frequent glosses:
#     1. AGE                                     5 samples
#     2. AGAINST                                 5 samples
#     3. ACCENT                                  5 samples
#     4. A-LINE BOB                              5 samples
#     5. 7-SEEDSOUR                              1 samples
#
# ============================================================
# 📊 SPLIT DISTRIBUTION ANALYSIS
# ============================================================
#
# 📈 Overall Statistics:
#   Total samples: 3283
#   Train: 2256 (68.7%)
#   Val: 432 (13.2%)
#   Test: 595 (18.1%)
#
# 🏷️ Label Coverage:
#   Train unique labels: 101
#   Val unique labels: 101
#   Test unique labels: 102
#   ⚠️ Labels only in test: 1
#   ✅ Labels in all splits: 101
#
# ============================================================
# 🔍 VALIDATING SPLIT INTEGRITY
# ============================================================
#
# 📁 File Overlap Check:
#   Train-Val overlap: 0 files
#   Train-Test overlap: 0 files
#   Val-Test overlap: 0 files
#   ✅ No file overlap detected - splits are clean!
#
# ⚖️ Class Weights (first 10 from train split):
#   ASSEMBLY                            1.0636
#   ABOUT                               0.5195
#   ALL DAY                             1.0636
#   ACCEPT                              1.0636
#   ARREST                              0.3490
#   ATHLETE                             1.0636
#   ATLANTA                             1.0636
#   AGAINST                             1.0636
#   AMAZING                             1.1168
#   ACQUIRE                             1.0636
#
# ============================================================
# ✅ DATA LOADING COMPLETE!
# ============================================================
#
# 📊 Ready to use:
#   X_train: (2256, 127, 438)
#   y_train: 2256 samples
#   X_val: (432, 127, 438)
#   y_val: 432 samples
#   X_test: (595, 127, 438)
#   y_test: 595 samples
#
# ✅ Done!
# ============================================================
# 📊 DATA INFORMATION (CPU MODE)
# ============================================================
# Train data type: <class 'numpy.ndarray'>
# Train data shape: (2256, 127, 438)
# Train labels shape: (2256,)
# Val data shape: (432, 127, 438)
# Val labels shape: (432,)
# Test data shape: (595, 127, 438)
# Test labels shape: (595,)
# Device: cpu
# Batch size: 4 (CPU optimized)
#
# 🔄 Converting data to correct format...
# Train data shape after conversion: (2256, 127, 438)
# Val data shape after conversion: (432, 127, 438)
# Test data shape after conversion: (595, 127, 438)
#
# 🏷️ Label encoding complete: 102 unique glosses
#
# ✅ DataLoaders created:
#   Train batches: 564
#   Val batches: 108
#   Test batches: 149
#
# 📐 Model Architecture (CPU Optimized):
#   Input: 438 features x 120 frames
#   Output: 102 classes
#   Channel size: 128 (reduced from 192)
#   Total parameters: 584,678
#
# ============================================================
# 🚀 STARTING TRAINING (CPU MODE)
# ============================================================
# ⚠️ Training on CPU will be slower. Consider using GPU if available.
# ============================================================
# Epoch 001/90 | Train Loss: 4.6420 | Train Acc: 0.0257 | Val Loss: 4.0895 | Val Acc: 0.0856
#   ✅ Best model saved! (Val Acc: 0.0856)
# Epoch 002/90 | Train Loss: 4.1576 | Train Acc: 0.0607 | Val Loss: 3.8816 | Val Acc: 0.1273
#   ✅ Best model saved! (Val Acc: 0.1273)
# Epoch 003/90 | Train Loss: 3.8525 | Train Acc: 0.1161 | Val Loss: 3.6174 | Val Acc: 0.2014
#   ✅ Best model saved! (Val Acc: 0.2014)
# Epoch 004/90 | Train Loss: 3.6219 | Train Acc: 0.1649 | Val Loss: 3.4631 | Val Acc: 0.2407
#   ✅ Best model saved! (Val Acc: 0.2407)
# Epoch 005/90 | Train Loss: 3.4142 | Train Acc: 0.2088 | Val Loss: 3.1650 | Val Acc: 0.3125
#   ✅ Best model saved! (Val Acc: 0.3125)
# Epoch 006/90 | Train Loss: 3.2243 | Train Acc: 0.2651 | Val Loss: 3.0651 | Val Acc: 0.3588
#   ✅ Best model saved! (Val Acc: 0.3588)
# Epoch 007/90 | Train Loss: 3.0260 | Train Acc: 0.3183 | Val Loss: 2.7700 | Val Acc: 0.4931
#   ✅ Best model saved! (Val Acc: 0.4931)
# Epoch 008/90 | Train Loss: 2.8722 | Train Acc: 0.3732 | Val Loss: 2.6051 | Val Acc: 0.5255
#   ✅ Best model saved! (Val Acc: 0.5255)
# Epoch 009/90 | Train Loss: 2.6924 | Train Acc: 0.4410 | Val Loss: 2.5525 | Val Acc: 0.5139
# Epoch 010/90 | Train Loss: 2.5666 | Train Acc: 0.4849 | Val Loss: 2.4322 | Val Acc: 0.5370
#   ✅ Best model saved! (Val Acc: 0.5370)
# Epoch 011/90 | Train Loss: 2.4224 | Train Acc: 0.5363 | Val Loss: 2.3735 | Val Acc: 0.5648
#   ✅ Best model saved! (Val Acc: 0.5648)
# Epoch 012/90 | Train Loss: 2.3085 | Train Acc: 0.5669 | Val Loss: 2.3288 | Val Acc: 0.5787
#   ✅ Best model saved! (Val Acc: 0.5787)
# Epoch 013/90 | Train Loss: 2.2170 | Train Acc: 0.5944 | Val Loss: 2.1501 | Val Acc: 0.6250
#   ✅ Best model saved! (Val Acc: 0.6250)
# Epoch 014/90 | Train Loss: 2.1136 | Train Acc: 0.6175 | Val Loss: 2.0739 | Val Acc: 0.6782
#   ✅ Best model saved! (Val Acc: 0.6782)
# Epoch 015/90 | Train Loss: 2.0201 | Train Acc: 0.6507 | Val Loss: 2.0370 | Val Acc: 0.6597
# Epoch 016/90 | Train Loss: 1.9603 | Train Acc: 0.6760 | Val Loss: 1.9910 | Val Acc: 0.6736
# Epoch 017/90 | Train Loss: 1.8802 | Train Acc: 0.6964 | Val Loss: 1.9646 | Val Acc: 0.6852
#   ✅ Best model saved! (Val Acc: 0.6852)
# Epoch 018/90 | Train Loss: 1.8283 | Train Acc: 0.7221 | Val Loss: 1.9541 | Val Acc: 0.6921
#   ✅ Best model saved! (Val Acc: 0.6921)
# Epoch 019/90 | Train Loss: 1.7707 | Train Acc: 0.7402 | Val Loss: 1.9134 | Val Acc: 0.7106
#   ✅ Best model saved! (Val Acc: 0.7106)
# Epoch 020/90 | Train Loss: 1.7075 | Train Acc: 0.7695 | Val Loss: 1.8673 | Val Acc: 0.7361
#   ✅ Best model saved! (Val Acc: 0.7361)
# Epoch 021/90 | Train Loss: 1.6934 | Train Acc: 0.7673 | Val Loss: 1.8209 | Val Acc: 0.7384
#   ✅ Best model saved! (Val Acc: 0.7384)
# Epoch 022/90 | Train Loss: 1.6160 | Train Acc: 0.7988 | Val Loss: 1.8562 | Val Acc: 0.7477
#   ✅ Best model saved! (Val Acc: 0.7477)
# Epoch 023/90 | Train Loss: 1.5679 | Train Acc: 0.8156 | Val Loss: 1.7482 | Val Acc: 0.7639
#   ✅ Best model saved! (Val Acc: 0.7639)
# Epoch 024/90 | Train Loss: 1.5577 | Train Acc: 0.8209 | Val Loss: 1.7817 | Val Acc: 0.7477
# Epoch 025/90 | Train Loss: 1.5049 | Train Acc: 0.8355 | Val Loss: 1.6821 | Val Acc: 0.7917
#   ✅ Best model saved! (Val Acc: 0.7917)
# Epoch 026/90 | Train Loss: 1.4715 | Train Acc: 0.8422 | Val Loss: 1.6751 | Val Acc: 0.7685
# Epoch 027/90 | Train Loss: 1.4290 | Train Acc: 0.8639 | Val Loss: 1.6971 | Val Acc: 0.7685
# Epoch 028/90 | Train Loss: 1.4012 | Train Acc: 0.8839 | Val Loss: 1.6748 | Val Acc: 0.7593
# Epoch 029/90 | Train Loss: 1.3903 | Train Acc: 0.8785 | Val Loss: 1.6804 | Val Acc: 0.7894
# Epoch 030/90 | Train Loss: 1.3547 | Train Acc: 0.8941 | Val Loss: 1.6395 | Val Acc: 0.7917
# Epoch 031/90 | Train Loss: 1.3131 | Train Acc: 0.9078 | Val Loss: 1.6095 | Val Acc: 0.7986
#   ✅ Best model saved! (Val Acc: 0.7986)
# Epoch 032/90 | Train Loss: 1.2950 | Train Acc: 0.9162 | Val Loss: 1.5731 | Val Acc: 0.8056
#   ✅ Best model saved! (Val Acc: 0.8056)
# Epoch 033/90 | Train Loss: 1.2851 | Train Acc: 0.9153 | Val Loss: 1.6336 | Val Acc: 0.7986
# Epoch 034/90 | Train Loss: 1.2594 | Train Acc: 0.9215 | Val Loss: 1.5857 | Val Acc: 0.7986
# Epoch 035/90 | Train Loss: 1.2449 | Train Acc: 0.9242 | Val Loss: 1.5625 | Val Acc: 0.8009
# Epoch 036/90 | Train Loss: 1.2411 | Train Acc: 0.9273 | Val Loss: 1.5785 | Val Acc: 0.8148
#   ✅ Best model saved! (Val Acc: 0.8148)
# Epoch 037/90 | Train Loss: 1.2058 | Train Acc: 0.9371 | Val Loss: 1.6127 | Val Acc: 0.8241
#   ✅ Best model saved! (Val Acc: 0.8241)
# Epoch 038/90 | Train Loss: 1.2036 | Train Acc: 0.9393 | Val Loss: 1.5258 | Val Acc: 0.8125
# Epoch 039/90 | Train Loss: 1.1819 | Train Acc: 0.9419 | Val Loss: 1.5439 | Val Acc: 0.8102
# Epoch 040/90 | Train Loss: 1.1669 | Train Acc: 0.9464 | Val Loss: 1.5132 | Val Acc: 0.8241
# Epoch 041/90 | Train Loss: 1.1563 | Train Acc: 0.9539 | Val Loss: 1.5510 | Val Acc: 0.8148
# Epoch 042/90 | Train Loss: 1.1498 | Train Acc: 0.9517 | Val Loss: 1.5204 | Val Acc: 0.8171
# Epoch 043/90 | Train Loss: 1.1219 | Train Acc: 0.9645 | Val Loss: 1.4762 | Val Acc: 0.8403
#   ✅ Best model saved! (Val Acc: 0.8403)
# Epoch 044/90 | Train Loss: 1.1187 | Train Acc: 0.9588 | Val Loss: 1.4867 | Val Acc: 0.8218
# Epoch 045/90 | Train Loss: 1.1054 | Train Acc: 0.9601 | Val Loss: 1.4893 | Val Acc: 0.8241
# Epoch 046/90 | Train Loss: 1.0953 | Train Acc: 0.9645 | Val Loss: 1.4881 | Val Acc: 0.8310
# Epoch 047/90 | Train Loss: 1.0941 | Train Acc: 0.9628 | Val Loss: 1.4694 | Val Acc: 0.8310
# Epoch 048/90 | Train Loss: 1.0752 | Train Acc: 0.9730 | Val Loss: 1.4961 | Val Acc: 0.8102
# Epoch 049/90 | Train Loss: 1.0713 | Train Acc: 0.9752 | Val Loss: 1.4828 | Val Acc: 0.8356
# Epoch 050/90 | Train Loss: 1.0533 | Train Acc: 0.9783 | Val Loss: 1.4690 | Val Acc: 0.8287
# Epoch 051/90 | Train Loss: 1.0611 | Train Acc: 0.9747 | Val Loss: 1.4538 | Val Acc: 0.8356
# Epoch 052/90 | Train Loss: 1.0529 | Train Acc: 0.9787 | Val Loss: 1.4758 | Val Acc: 0.8333
# Epoch 053/90 | Train Loss: 1.0334 | Train Acc: 0.9845 | Val Loss: 1.4393 | Val Acc: 0.8310
# Epoch 054/90 | Train Loss: 1.0289 | Train Acc: 0.9818 | Val Loss: 1.4561 | Val Acc: 0.8264
# Epoch 055/90 | Train Loss: 1.0228 | Train Acc: 0.9809 | Val Loss: 1.4354 | Val Acc: 0.8472
#   ✅ Best model saved! (Val Acc: 0.8472)
# Epoch 056/90 | Train Loss: 1.0211 | Train Acc: 0.9823 | Val Loss: 1.4369 | Val Acc: 0.8426
# Epoch 057/90 | Train Loss: 1.0128 | Train Acc: 0.9871 | Val Loss: 1.4447 | Val Acc: 0.8380
# Epoch 058/90 | Train Loss: 1.0047 | Train Acc: 0.9867 | Val Loss: 1.4373 | Val Acc: 0.8287
# Epoch 059/90 | Train Loss: 1.0026 | Train Acc: 0.9894 | Val Loss: 1.4464 | Val Acc: 0.8403
# Epoch 060/90 | Train Loss: 0.9976 | Train Acc: 0.9907 | Val Loss: 1.4593 | Val Acc: 0.8380
# Epoch 061/90 | Train Loss: 0.9896 | Train Acc: 0.9902 | Val Loss: 1.4412 | Val Acc: 0.8264
# Epoch 062/90 | Train Loss: 0.9788 | Train Acc: 0.9889 | Val Loss: 1.4652 | Val Acc: 0.8287
# Epoch 063/90 | Train Loss: 0.9790 | Train Acc: 0.9929 | Val Loss: 1.4139 | Val Acc: 0.8495
#   ✅ Best model saved! (Val Acc: 0.8495)
# Epoch 064/90 | Train Loss: 0.9740 | Train Acc: 0.9907 | Val Loss: 1.4395 | Val Acc: 0.8495
# Epoch 065/90 | Train Loss: 0.9701 | Train Acc: 0.9929 | Val Loss: 1.4560 | Val Acc: 0.8449
# Epoch 066/90 | Train Loss: 0.9678 | Train Acc: 0.9938 | Val Loss: 1.4144 | Val Acc: 0.8449
# Epoch 067/90 | Train Loss: 0.9635 | Train Acc: 0.9947 | Val Loss: 1.4331 | Val Acc: 0.8310
# Epoch 068/90 | Train Loss: 0.9623 | Train Acc: 0.9938 | Val Loss: 1.4326 | Val Acc: 0.8472
# Epoch 069/90 | Train Loss: 0.9617 | Train Acc: 0.9925 | Val Loss: 1.4255 | Val Acc: 0.8403
# Epoch 070/90 | Train Loss: 0.9626 | Train Acc: 0.9925 | Val Loss: 1.4368 | Val Acc: 0.8356
# Epoch 071/90 | Train Loss: 0.9550 | Train Acc: 0.9947 | Val Loss: 1.4156 | Val Acc: 0.8472
# Epoch 072/90 | Train Loss: 0.9549 | Train Acc: 0.9947 | Val Loss: 1.4111 | Val Acc: 0.8426
# Epoch 073/90 | Train Loss: 0.9576 | Train Acc: 0.9911 | Val Loss: 1.4217 | Val Acc: 0.8356
# Epoch 074/90 | Train Loss: 0.9540 | Train Acc: 0.9947 | Val Loss: 1.4239 | Val Acc: 0.8356
# Epoch 075/90 | Train Loss: 0.9497 | Train Acc: 0.9960 | Val Loss: 1.4146 | Val Acc: 0.8426
#
# ⏹️ Early stopping at epoch 75
#
# ============================================================
# 📊 FINAL EVALUATION
# ============================================================
# Loaded best model from epoch 63 with Val Acc: 0.8495
#
# 🎯 Test Set Results:
#   Test Loss: 1.4330
#   Test Accuracy: 0.8471
#
# 📈 Per-class accuracy (first 10 classes):
#   Class 1 DOLLAR: 0.8333
#   Class 5 DOLLARS: 1.0000
#   Class 7-SEEDSOUR: 0.0000
#   Class 8 HOUR: 0.5000
#   Class 9 OCLOCK: 0.8333
#   Class A LITTLE BIT: 0.6667
#   Class A-LINE BOB: 1.0000
#   Class ABBREVIATE: 0.8333
#   Class ABOUT: 1.0000
#   Class ABOVE: 1.0000
#
# ⚠️ Worst performing classes:
#   Class 7-SEEDSOUR: 0.0000
#   Class AFTERNOON: 0.2000
#   Class ATLANTA: 0.2000
#   Class APPOINTMENT: 0.2000
#   Class ASSIST: 0.3333
#
# 💾 Training history saved to 'training_history_cpu.pkl'
# 💾 Best model saved to tcn_best_model_cpu.pth
# 💾 Label encoder saved to label_encoder.npy
# 📊 Training curves saved to 'training_curves_cpu.png'
#
# ============================================================
# ✅ TRAINING COMPLETE (CPU MODE)!
# ============================================================
