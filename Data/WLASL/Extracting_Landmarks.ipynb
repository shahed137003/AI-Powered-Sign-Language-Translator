# %%
import os
import cv2
import numpy as np
import itertools
import mediapipe as mp

# %%
videos_folder = "videos"
output_folder = "landmarks2"
os.makedirs(output_folder, exist_ok=True)

# %%
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# %%
FACEMESH_LIPS = set(itertools.chain(*mp_face_mesh.FACEMESH_LIPS))
FACEMESH_LEFT_EYEBROW = set(itertools.chain(*mp_face_mesh.FACEMESH_LEFT_EYEBROW))
FACEMESH_RIGHT_EYEBROW = set(itertools.chain(*mp_face_mesh.FACEMESH_RIGHT_EYEBROW))

RELEVANT_FACE_INDICES = list(FACEMESH_LIPS | FACEMESH_LEFT_EYEBROW | FACEMESH_RIGHT_EYEBROW)
RELEVANT_FACE_INDICES.sort()

# Initialize holistic model
holistic = mp_holistic.Holistic(
    static_image_mode=False,
    model_complexity=1,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

# %%
for video_file in os.listdir(videos_folder):
    if not video_file.lower().endswith(('.mp4', '.mov', '.avi', '.mkv')):
        continue

    video_path = os.path.join(videos_folder, video_file)
    cap = cv2.VideoCapture(video_path)

    base_name = os.path.splitext(video_file)[0]
    all_keypoints = []

    print(f"Processing {video_file}...")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = holistic.process(image)

        # 1) POSE (33 × 4)
        if results.pose_landmarks:
            pose = np.array([[lm.x, lm.y, lm.z, lm.visibility]
                             for lm in results.pose_landmarks.landmark]).flatten()
        else:
            pose = np.zeros(33 * 4)
        # 2) HANDS (21 × 3 each)
        if results.left_hand_landmarks:
            lh = np.array([[lm.x, lm.y, lm.z]
                           for lm in results.left_hand_landmarks.landmark]).flatten()
        else:
            lh = np.zeros(21 * 3)

        if results.right_hand_landmarks:
            rh = np.array([[lm.x, lm.y, lm.z]
                           for lm in results.right_hand_landmarks.landmark]).flatten()
        else:
            rh = np.zeros(21 * 3)
        # 3) FACE (LIPS + EYEBROWS ONLY)
        if results.face_landmarks:
            relevant = [results.face_landmarks.landmark[i] for i in RELEVANT_FACE_INDICES]
            face = np.array([[lm.x, lm.y, lm.z] for lm in relevant]).flatten()
        else:
            face = np.zeros(len(RELEVANT_FACE_INDICES) * 3)
        # FINAL CONCATENATION
        final_kp = np.concatenate([pose, face, lh, rh])
        all_keypoints.append(final_kp)

    cap.release()

    # Convert to array and save
    all_keypoints = np.array(all_keypoints)
    save_path = os.path.join(output_folder, f"{base_name}.npy")
    np.save(save_path, all_keypoints)

    print(f"Saved {save_path} with shape {all_keypoints.shape}")

print("All videos processed and converted successfully!")
# Out:
# Processing 00335.mp4...
# Saved landmarks2\00335.npy with shape (58, 438)
# Processing 00336.mp4...
# Saved landmarks2\00336.npy with shape (65, 438)
# Processing 00338.mp4...
# Saved landmarks2\00338.npy with shape (71, 438)
# Processing 00339.mp4...
# Saved landmarks2\00339.npy with shape (60, 438)
# Processing 00341.mp4...
# Saved landmarks2\00341.npy with shape (84, 438)
# Processing 00376.mp4...
# Saved landmarks2\00376.npy with shape (56, 438)
# Processing 00377.mp4...
# Saved landmarks2\00377.npy with shape (89, 438)
# Processing 00381.mp4...
# Saved landmarks2\00381.npy with shape (36, 438)
# Processing 00382.mp4...
# Saved landmarks2\00382.npy with shape (44, 438)
# Processing 00384.mp4...
# Saved landmarks2\00384.npy with shape (85, 438)
# Processing 00414.mp4...
# Saved landmarks2\00414.npy with shape (105, 438)
# Processing 00415.mp4...
# Saved landmarks2\00415.npy with shape (38, 438)
# Processing 00416.mp4...
# Saved landmarks2\00416.npy with shape (116, 438)
# Processing 00421.mp4...
# Saved landmarks2\00421.npy with shape (33, 438)
# Processing 00426.mp4...
# Saved landmarks2\00426.npy with shape (98, 438)
# Processing 00430.mp4...
# Saved landmarks2\00430.npy with shape (52, 438)
# Processing 00431.mp4...
# Saved landmarks2\00431.npy with shape (122, 438)
# Processing 00433.mp4...
# Saved landmarks2\00433.npy with shape (79, 438)
# Processing 00435.mp4...
# Saved landmarks2\00435.npy with shape (103, 438)
# Processing 00583.mp4...
# Saved landmarks2\00583.npy with shape (38, 438)
# Processing 00584.mp4...
# Saved landmarks2\00584.npy with shape (42, 438)
# Processing 00585.mp4...
# Saved landmarks2\00585.npy with shape (38, 438)
# Processing 00586.mp4...
# Saved landmarks2\00586.npy with shape (39, 438)
# Processing 00592.mp4...
# Saved landmarks2\00592.npy with shape (125, 438)
# Processing 00593.mp4...
# Saved landmarks2\00593.npy with shape (28, 438)
# Processing 00594.mp4...
# Saved landmarks2\00594.npy with shape (36, 438)
# Processing 00597.mp4...
# Saved landmarks2\00597.npy with shape (128, 438)
# Processing 00599.mp4...
# Saved landmarks2\00599.npy with shape (39, 438)
# Processing 00600.mp4...
# Saved landmarks2\00600.npy with shape (29, 438)
# Processing 00603.mp4...
# Saved landmarks2\00603.npy with shape (85, 438)
# Processing 00623.mp4...
# Saved landmarks2\00623.npy with shape (104, 438)
# Processing 00624.mp4...
# Saved landmarks2\00624.npy with shape (109, 438)
# Processing 00625.mp4...
# Saved landmarks2\00625.npy with shape (34, 438)
# Processing 00626.mp4...
# Saved landmarks2\00626.npy with shape (44, 438)
# Processing 00627.mp4...
# Saved landmarks2\00627.npy with shape (31, 438)
# Processing 00628.mp4...
# Saved landmarks2\00628.npy with shape (35, 438)
# Processing 00629.mp4...
# Saved landmarks2\00629.npy with shape (149, 438)
# Processing 00631.mp4...
# Saved landmarks2\00631.npy with shape (75, 438)
# Processing 00632.mp4...
# Saved landmarks2\00632.npy with shape (55, 438)
# Processing 00633.mp4...
# Saved landmarks2\00633.npy with shape (25, 438)
# Processing 00634.mp4...
# Saved landmarks2\00634.npy with shape (40, 438)
# Processing 00639.mp4...
# Saved landmarks2\00639.npy with shape (105, 438)
# Processing 00663.mp4...
# Saved landmarks2\00663.npy with shape (117, 438)
# Processing 00664.mp4...
# Saved landmarks2\00664.npy with shape (119, 438)
# Processing 00666.mp4...
# Saved landmarks2\00666.npy with shape (36, 438)
# Processing 00668.mp4...
# Saved landmarks2\00668.npy with shape (79, 438)
# Processing 00689.mp4...
# Saved landmarks2\00689.npy with shape (88, 438)
# Processing 00690.mp4...
# Saved landmarks2\00690.npy with shape (134, 438)
# Processing 00692.mp4...
# Saved landmarks2\00692.npy with shape (66, 438)
# Processing 00694.mp4...
# Saved landmarks2\00694.npy with shape (105, 438)
# Processing 00832.mp4...
# Saved landmarks2\00832.npy with shape (141, 438)
# Processing 00834.mp4...
# Saved landmarks2\00834.npy with shape (89, 438)
# Processing 00835.mp4...
# Saved landmarks2\00835.npy with shape (44, 438)
# Processing 00836.mp4...
# Saved landmarks2\00836.npy with shape (42, 438)
# Processing 00839.mp4...
# Saved landmarks2\00839.npy with shape (51, 438)
# Processing 00842.mp4...
# Saved landmarks2\00842.npy with shape (89, 438)
# Processing 00846.mp4...
# Saved landmarks2\00846.npy with shape (40, 438)
# Processing 00847.mp4...
# Saved landmarks2\00847.npy with shape (114, 438)
# Processing 00849.mp4...
# Saved landmarks2\00849.npy with shape (87, 438)
# Processing 00851.mp4...
# Saved landmarks2\00851.npy with shape (78, 438)
# Processing 00853.mp4...
# Saved landmarks2\00853.npy with shape (84, 438)
# Processing 00854.mp4...
# Saved landmarks2\00854.npy with shape (108, 438)
# Processing 00855.mp4...
# Saved landmarks2\00855.npy with shape (65, 438)
# Processing 00856.mp4...
# Saved landmarks2\00856.npy with shape (48, 438)
# Processing 00858.mp4...
# Saved landmarks2\00858.npy with shape (100, 438)
# Processing 00868.mp4...
# Saved landmarks2\00868.npy with shape (70, 438)
# Processing 00869.mp4...
# Saved landmarks2\00869.npy with shape (121, 438)
# Processing 00871.mp4...
# Saved landmarks2\00871.npy with shape (56, 438)
# Processing 00872.mp4...
# Saved landmarks2\00872.npy with shape (65, 438)
# Processing 00874.mp4...
# Saved landmarks2\00874.npy with shape (93, 438)
# Processing 00890.mp4...
# Saved landmarks2\00890.npy with shape (32, 438)
# Processing 00891.mp4...
# Saved landmarks2\00891.npy with shape (108, 438)
# Processing 00892.mp4...
# Saved landmarks2\00892.npy with shape (65, 438)
# Processing 00894.mp4...
# Saved landmarks2\00894.npy with shape (65, 438)
# Processing 00898.mp4...
# Saved landmarks2\00898.npy with shape (69, 438)
# Processing 00899.mp4...
# Saved landmarks2\00899.npy with shape (90, 438)
# Processing 00900.mp4...
# Saved landmarks2\00900.npy with shape (143, 438)
# Processing 00901.mp4...
# Saved landmarks2\00901.npy with shape (65, 438)
# Processing 00904.mp4...
# Saved landmarks2\00904.npy with shape (113, 438)
# Processing 00943.mp4...
# Saved landmarks2\00943.npy with shape (133, 438)
# Processing 00944.mp4...
# Saved landmarks2\00944.npy with shape (114, 438)
# Processing 00946.mp4...
# Saved landmarks2\00946.npy with shape (29, 438)
# Processing 00947.mp4...
# Saved landmarks2\00947.npy with shape (81, 438)
# Processing 00949.mp4...
# Saved landmarks2\00949.npy with shape (51, 438)
# Processing 00951.mp4...
# Saved landmarks2\00951.npy with shape (93, 438)
# Processing 00961.mp4...
# Saved landmarks2\00961.npy with shape (114, 438)
# Processing 00962.mp4...
# Saved landmarks2\00962.npy with shape (43, 438)
# Processing 00963.mp4...
# Saved landmarks2\00963.npy with shape (37, 438)
# Processing 00964.mp4...
# Saved landmarks2\00964.npy with shape (47, 438)
# Processing 00965.mp4...
# Saved landmarks2\00965.npy with shape (124, 438)
# Processing 00967.mp4...
# Saved landmarks2\00967.npy with shape (27, 438)
# Processing 00973.mp4...
# Saved landmarks2\00973.npy with shape (101, 438)
# Processing 01011.mp4...
# Saved landmarks2\01011.npy with shape (88, 438)
# Processing 01012.mp4...
# Saved landmarks2\01012.npy with shape (35, 438)
# Processing 01018.mp4...
# Saved landmarks2\01018.npy with shape (42, 438)
# Processing 01024.mp4...
# Saved landmarks2\01024.npy with shape (91, 438)
# Processing 01064.mp4...
# Saved landmarks2\01064.npy with shape (82, 438)
# Processing 01065.mp4...
# Saved landmarks2\01065.npy with shape (34, 438)
# Processing 01066.mp4...
# Saved landmarks2\01066.npy with shape (181, 438)
# Processing 01068.mp4...
# Saved landmarks2\01068.npy with shape (49, 438)
# Processing 01073.mp4...
# Saved landmarks2\01073.npy with shape (94, 438)
# Processing 01074.mp4...
# Saved landmarks2\01074.npy with shape (99, 438)
# Processing 01076.mp4...
# Saved landmarks2\01076.npy with shape (51, 438)
# Processing 01079.mp4...
# Saved landmarks2\01079.npy with shape (103, 438)
# Processing 01100.mp4...
# Saved landmarks2\01100.npy with shape (95, 438)
# Processing 01101.mp4...
# Saved landmarks2\01101.npy with shape (140, 438)
# Processing 01103.mp4...
# Saved landmarks2\01103.npy with shape (47, 438)
# Processing 01107.mp4...
# Saved landmarks2\01107.npy with shape (101, 438)
# Processing 01118.mp4...
# Saved landmarks2\01118.npy with shape (34, 438)
# Processing 01120.mp4...
# Saved landmarks2\01120.npy with shape (139, 438)
# Processing 01122.mp4...
# Saved landmarks2\01122.npy with shape (38, 438)
# Processing 01127.mp4...
# Saved landmarks2\01127.npy with shape (90, 438)
# Processing 01157.mp4...
# Saved landmarks2\01157.npy with shape (107, 438)
# Processing 01158.mp4...
# Saved landmarks2\01158.npy with shape (39, 438)
# Processing 01159.mp4...
# Saved landmarks2\01159.npy with shape (29, 438)
# Processing 01160.mp4...
# Saved landmarks2\01160.npy with shape (36, 438)
# Processing 01162.mp4...
# Saved landmarks2\01162.npy with shape (91, 438)
# Processing 01206.mp4...
# Saved landmarks2\01206.npy with shape (87, 438)
# Processing 01207.mp4...
# Saved landmarks2\01207.npy with shape (85, 438)
# Processing 01208.mp4...
# Saved landmarks2\01208.npy with shape (103, 438)
# Processing 01209.mp4...
# Saved landmarks2\01209.npy with shape (39, 438)
# Processing 01214.mp4...
# Saved landmarks2\01214.npy with shape (41, 438)
# Processing 01217.mp4...
# Saved landmarks2\01217.npy with shape (101, 438)
# Processing 01226.mp4...
# Saved landmarks2\01226.npy with shape (107, 438)
# Processing 01227.mp4...
# Saved landmarks2\01227.npy with shape (57, 438)
# Processing 01229.mp4...
# Saved landmarks2\01229.npy with shape (68, 438)
# Processing 01231.mp4...
# Saved landmarks2\01231.npy with shape (96, 438)
# Processing 01244.mp4...
# Saved landmarks2\01244.npy with shape (106, 438)
# Processing 01245.mp4...
# Saved landmarks2\01245.npy with shape (32, 438)
# Processing 01252.mp4...
# Saved landmarks2\01252.npy with shape (93, 438)
# Processing 01264.mp4...
# Saved landmarks2\01264.npy with shape (71, 438)
# Processing 01265.mp4...
# Saved landmarks2\01265.npy with shape (97, 438)
# Processing 01266.mp4...
# Saved landmarks2\01266.npy with shape (152, 438)
# Processing 01268.mp4...
# Saved landmarks2\01268.npy with shape (42, 438)
# Processing 01318.mp4...
# Saved landmarks2\01318.npy with shape (121, 438)
# Processing 01319.mp4...
# Saved landmarks2\01319.npy with shape (89, 438)
# Processing 01320.mp4...
# Saved landmarks2\01320.npy with shape (133, 438)
# Processing 01321.mp4...
# Saved landmarks2\01321.npy with shape (69, 438)
# Processing 01323.mp4...
# Saved landmarks2\01323.npy with shape (34, 438)
# Processing 01327.mp4...
# Saved landmarks2\01327.npy with shape (99, 438)
# Processing 01373.mp4...
# Saved landmarks2\01373.npy with shape (69, 438)
# Processing 01374.mp4...
# Saved landmarks2\01374.npy with shape (93, 438)
# Processing 01376.mp4...
# Saved landmarks2\01376.npy with shape (35, 438)
# Processing 01377.mp4...
# Saved landmarks2\01377.npy with shape (22, 438)
# Processing 01381.mp4...
# Saved landmarks2\01381.npy with shape (100, 438)
# Processing 01383.mp4...
# Saved landmarks2\01383.npy with shape (146, 438)
# Processing 01384.mp4...
# Saved landmarks2\01384.npy with shape (65, 438)
# Processing 01385.mp4...
# Saved landmarks2\01385.npy with shape (48, 438)
# Processing 01386.mp4...
# Saved landmarks2\01386.npy with shape (41, 438)
# Processing 01387.mp4...
# Saved landmarks2\01387.npy with shape (40, 438)
# Processing 01388.mp4...
# Saved landmarks2\01388.npy with shape (123, 438)
# Processing 01391.mp4...
# Saved landmarks2\01391.npy with shape (47, 438)
# Processing 01398.mp4...
# Saved landmarks2\01398.npy with shape (78, 438)
# Processing 01418.mp4...
# Saved landmarks2\01418.npy with shape (106, 438)
# Processing 01419.mp4...
# Saved landmarks2\01419.npy with shape (76, 438)
# Processing 01420.mp4...
# Saved landmarks2\01420.npy with shape (44, 438)
# Processing 01421.mp4...
# Saved landmarks2\01421.npy with shape (26, 438)
# Processing 01422.mp4...
# Saved landmarks2\01422.npy with shape (114, 438)
# Processing 01428.mp4...
# Saved landmarks2\01428.npy with shape (77, 438)
# Processing 01433.mp4...
# Saved landmarks2\01433.npy with shape (70, 438)
# Processing 01434.mp4...
# Saved landmarks2\01434.npy with shape (88, 438)
# Processing 01435.mp4...
# Saved landmarks2\01435.npy with shape (62, 438)
# Processing 01436.mp4...
# Saved landmarks2\01436.npy with shape (130, 438)
# Processing 01438.mp4...
# Saved landmarks2\01438.npy with shape (37, 438)
# Processing 01442.mp4...
# Saved landmarks2\01442.npy with shape (78, 438)
# Processing 01460.mp4...
# Saved landmarks2\01460.npy with shape (71, 438)
# Processing 01461.mp4...
# Saved landmarks2\01461.npy with shape (82, 438)
# Processing 01462.mp4...
# Saved landmarks2\01462.npy with shape (42, 438)
# Processing 01463.mp4...
# Saved landmarks2\01463.npy with shape (106, 438)
# Processing 01464.mp4...
# Saved landmarks2\01464.npy with shape (75, 438)
# Processing 01466.mp4...
# Saved landmarks2\01466.npy with shape (49, 438)
# Processing 01471.mp4...
# Saved landmarks2\01471.npy with shape (75, 438)
# Processing 01473.mp4...
# Saved landmarks2\01473.npy with shape (94, 438)
# Processing 01474.mp4...
# Saved landmarks2\01474.npy with shape (101, 438)
# Processing 01477.mp4...
# Saved landmarks2\01477.npy with shape (44, 438)
# Processing 01479.mp4...
# Saved landmarks2\01479.npy with shape (93, 438)
# Processing 01485.mp4...
# Saved landmarks2\01485.npy with shape (72, 438)
# Processing 01486.mp4...
# Saved landmarks2\01486.npy with shape (37, 438)
# Processing 01487.mp4...
# Saved landmarks2\01487.npy with shape (88, 438)
# Processing 01489.mp4...
# Saved landmarks2\01489.npy with shape (50, 438)
# Processing 01490.mp4...
# Saved landmarks2\01490.npy with shape (32, 438)
# Processing 01495.mp4...
# Saved landmarks2\01495.npy with shape (75, 438)
# Processing 01505.mp4...
# Saved landmarks2\01505.npy with shape (81, 438)
# Processing 01506.mp4...
# Saved landmarks2\01506.npy with shape (42, 438)
# Processing 01507.mp4...
# Saved landmarks2\01507.npy with shape (43, 438)
# Processing 01515.mp4...
# Saved landmarks2\01515.npy with shape (79, 438)
# Processing 01552.mp4...
# Saved landmarks2\01552.npy with shape (134, 438)
# Processing 01553.mp4...
# Saved landmarks2\01553.npy with shape (45, 438)
# Processing 01554.mp4...
# Saved landmarks2\01554.npy with shape (98, 438)
# Processing 01556.mp4...
# Saved landmarks2\01556.npy with shape (31, 438)
# Processing 01557.mp4...
# Saved landmarks2\01557.npy with shape (28, 438)
# Processing 01558.mp4...
# Saved landmarks2\01558.npy with shape (34, 438)
# Processing 01560.mp4...
# Saved landmarks2\01560.npy with shape (47, 438)
# Processing 01561.mp4...
# Saved landmarks2\01561.npy with shape (38, 438)
# Processing 01564.mp4...
# Saved landmarks2\01564.npy with shape (81, 438)
# Processing 01575.mp4...
# Saved landmarks2\01575.npy with shape (95, 438)
# Processing 01576.mp4...
# Saved landmarks2\01576.npy with shape (36, 438)
# Processing 01577.mp4...
# Saved landmarks2\01577.npy with shape (124, 438)
# Processing 01579.mp4...
# Saved landmarks2\01579.npy with shape (43, 438)
# Processing 01582.mp4...
# Saved landmarks2\01582.npy with shape (69, 438)
# Processing 01583.mp4...
# Saved landmarks2\01583.npy with shape (95, 438)
# Processing 01584.mp4...
# Saved landmarks2\01584.npy with shape (36, 438)
# Processing 01585.mp4...
# Saved landmarks2\01585.npy with shape (82, 438)
# Processing 01586.mp4...
# Saved landmarks2\01586.npy with shape (43, 438)
# Processing 01587.mp4...
# Saved landmarks2\01587.npy with shape (69, 438)
# Processing 01598.mp4...
# Saved landmarks2\01598.npy with shape (49, 438)
# Processing 01599.mp4...
# Saved landmarks2\01599.npy with shape (119, 438)
# Processing 01602.mp4...
# Saved landmarks2\01602.npy with shape (49, 438)
# Processing 01605.mp4...
# Saved landmarks2\01605.npy with shape (74, 438)
# Processing 01610.mp4...
# Saved landmarks2\01610.npy with shape (125, 438)
# Processing 01612.mp4...
# Saved landmarks2\01612.npy with shape (30, 438)
# Processing 01615.mp4...
# Saved landmarks2\01615.npy with shape (84, 438)
# Processing 01621.mp4...
# Saved landmarks2\01621.npy with shape (75, 438)
# Processing 01622.mp4...
# Saved landmarks2\01622.npy with shape (50, 438)
# Processing 01624.mp4...
# Saved landmarks2\01624.npy with shape (113, 438)
# Processing 01626.mp4...
# Saved landmarks2\01626.npy with shape (49, 438)
# Processing 01627.mp4...
# Saved landmarks2\01627.npy with shape (30, 438)
# Processing 01642.mp4...
# Saved landmarks2\01642.npy with shape (106, 438)
# Processing 01643.mp4...
# Saved landmarks2\01643.npy with shape (136, 438)
# Processing 01646.mp4...
# Saved landmarks2\01646.npy with shape (47, 438)
# Processing 01652.mp4...
# Saved landmarks2\01652.npy with shape (91, 438)
# Processing 01653.mp4...
# Saved landmarks2\01653.npy with shape (76, 438)
# Processing 01724.mp4...
# Saved landmarks2\01724.npy with shape (101, 438)
# Processing 01726.mp4...
# Saved landmarks2\01726.npy with shape (48, 438)
# Processing 01727.mp4...
# Saved landmarks2\01727.npy with shape (117, 438)
# Processing 01729.mp4...
# Saved landmarks2\01729.npy with shape (38, 438)
# Processing 01730.mp4...
# Saved landmarks2\01730.npy with shape (97, 438)
# Processing 01734.mp4...
# Saved landmarks2\01734.npy with shape (96, 438)
# Processing 01801.mp4...
# Saved landmarks2\01801.npy with shape (98, 438)
# Processing 01802.mp4...
# Saved landmarks2\01802.npy with shape (78, 438)
# Processing 01804.mp4...
# Saved landmarks2\01804.npy with shape (47, 438)
# Processing 01808.mp4...
# Saved landmarks2\01808.npy with shape (91, 438)
# Processing 01831.mp4...
# Saved landmarks2\01831.npy with shape (104, 438)
# Processing 01832.mp4...
# Saved landmarks2\01832.npy with shape (99, 438)
# Processing 01836.mp4...
# Saved landmarks2\01836.npy with shape (29, 438)
# Processing 01839.mp4...
# Saved landmarks2\01839.npy with shape (87, 438)
# Processing 01874.mp4...
# Saved landmarks2\01874.npy with shape (74, 438)
# Processing 01875.mp4...
# Saved landmarks2\01875.npy with shape (49, 438)
# Processing 01876.mp4...
# Saved landmarks2\01876.npy with shape (155, 438)
# Processing 01878.mp4...
# Saved landmarks2\01878.npy with shape (36, 438)
# Processing 01880.mp4...
# Saved landmarks2\01880.npy with shape (83, 438)
# Processing 01922.mp4...
# Saved landmarks2\01922.npy with shape (48, 438)
# Processing 01923.mp4...
# Saved landmarks2\01923.npy with shape (53, 438)
# Processing 01924.mp4...
# Saved landmarks2\01924.npy with shape (73, 438)
# Processing 01926.mp4...
# Saved landmarks2\01926.npy with shape (44, 438)
# Processing 01927.mp4...
# Saved landmarks2\01927.npy with shape (87, 438)
# Processing 01955.mp4...
# Saved landmarks2\01955.npy with shape (119, 438)
# Processing 01956.mp4...
# Saved landmarks2\01956.npy with shape (40, 438)
# Processing 01957.mp4...
# Saved landmarks2\01957.npy with shape (108, 438)
# Processing 01960.mp4...
# Saved landmarks2\01960.npy with shape (60, 438)
# Processing 01962.mp4...
# Saved landmarks2\01962.npy with shape (54, 438)
# Processing 01965.mp4...
# Saved landmarks2\01965.npy with shape (106, 438)
# Processing 01986.mp4...
# Saved landmarks2\01986.npy with shape (83, 438)
# Processing 01987.mp4...
# Saved landmarks2\01987.npy with shape (75, 438)
# Processing 01988.mp4...
# Saved landmarks2\01988.npy with shape (144, 438)
# Processing 01991.mp4...
# Saved landmarks2\01991.npy with shape (49, 438)
# Processing 01992.mp4...
# Saved landmarks2\01992.npy with shape (59, 438)
# Processing 02003.mp4...
# Saved landmarks2\02003.npy with shape (76, 438)
# Processing 02008.mp4...
# Saved landmarks2\02008.npy with shape (83, 438)
# Processing 02009.mp4...
# Saved landmarks2\02009.npy with shape (37, 438)
# Processing 02010.mp4...
# Saved landmarks2\02010.npy with shape (126, 438)
# Processing 02012.mp4...
# Saved landmarks2\02012.npy with shape (54, 438)
# Processing 02014.mp4...
# Saved landmarks2\02014.npy with shape (109, 438)
# Processing 02045.mp4...
# Saved landmarks2\02045.npy with shape (67, 438)
# Processing 02046.mp4...
# Saved landmarks2\02046.npy with shape (91, 438)
# Processing 02048.mp4...
# Saved landmarks2\02048.npy with shape (53, 438)
# Processing 02049.mp4...
# Saved landmarks2\02049.npy with shape (43, 438)
# Processing 02052.mp4...
# Saved landmarks2\02052.npy with shape (94, 438)
# Processing 02091.mp4...
# Saved landmarks2\02091.npy with shape (110, 438)
# Processing 02092.mp4...
# Saved landmarks2\02092.npy with shape (27, 438)
# Processing 02093.mp4...
# Saved landmarks2\02093.npy with shape (109, 438)
# Processing 02095.mp4...
# Saved landmarks2\02095.npy with shape (71, 438)
# Processing 02103.mp4...
# Saved landmarks2\02103.npy with shape (76, 438)
# Processing 02104.mp4...
# Saved landmarks2\02104.npy with shape (56, 438)
# Processing 02105.mp4...
# Saved landmarks2\02105.npy with shape (51, 438)
# Processing 02106.mp4...
# Saved landmarks2\02106.npy with shape (118, 438)
# Processing 02108.mp4...
# Saved landmarks2\02108.npy with shape (50, 438)
# Processing 02109.mp4...
# Saved landmarks2\02109.npy with shape (47, 438)
# Processing 02110.mp4...
# Saved landmarks2\02110.npy with shape (46, 438)
# Processing 02112.mp4...
# Saved landmarks2\02112.npy with shape (108, 438)
# Processing 02124.mp4...
# Saved landmarks2\02124.npy with shape (74, 438)
# Processing 02125.mp4...
# Saved landmarks2\02125.npy with shape (38, 438)
# Processing 02126.mp4...
# Saved landmarks2\02126.npy with shape (96, 438)
# Processing 02128.mp4...
# Saved landmarks2\02128.npy with shape (53, 438)
# Processing 02129.mp4...
# Saved landmarks2\02129.npy with shape (29, 438)
# Processing 02130.mp4...
# Saved landmarks2\02130.npy with shape (41, 438)
# Processing 02131.mp4...
# Saved landmarks2\02131.npy with shape (86, 438)
# Processing 02145.mp4...
# Saved landmarks2\02145.npy with shape (133, 438)
# Processing 02149.mp4...
# Saved landmarks2\02149.npy with shape (35, 438)
# Processing 02151.mp4...
# Saved landmarks2\02151.npy with shape (128, 438)
# Processing 02159.mp4...
# Saved landmarks2\02159.npy with shape (72, 438)
# Processing 02160.mp4...
# Saved landmarks2\02160.npy with shape (108, 438)
# Processing 02161.mp4...
# Saved landmarks2\02161.npy with shape (36, 438)
# Processing 02162.mp4...
# Saved landmarks2\02162.npy with shape (35, 438)
# Processing 02163.mp4...
# Saved landmarks2\02163.npy with shape (99, 438)
# Processing 02165.mp4...
# Saved landmarks2\02165.npy with shape (63, 438)
# Processing 02166.mp4...
# Saved landmarks2\02166.npy with shape (29, 438)
# Processing 02168.mp4...
# Saved landmarks2\02168.npy with shape (107, 438)
# Processing 02174.mp4...
# Saved landmarks2\02174.npy with shape (67, 438)
# Processing 02175.mp4...
# Saved landmarks2\02175.npy with shape (114, 438)
# Processing 02177.mp4...
# Saved landmarks2\02177.npy with shape (36, 438)
# Processing 02178.mp4...
# Saved landmarks2\02178.npy with shape (51, 438)
# Processing 02181.mp4...
# Saved landmarks2\02181.npy with shape (94, 438)
# Processing 02228.mp4...
# Saved landmarks2\02228.npy with shape (71, 438)
# Processing 02229.mp4...
# Saved landmarks2\02229.npy with shape (79, 438)
# Processing 02230.mp4...
# Saved landmarks2\02230.npy with shape (57, 438)
# Processing 02231.mp4...
# Saved landmarks2\02231.npy with shape (113, 438)
# Processing 02233.mp4...
# Saved landmarks2\02233.npy with shape (66, 438)
# Processing 02238.mp4...
# Saved landmarks2\02238.npy with shape (80, 438)
# Processing 02269.mp4...
# Saved landmarks2\02269.npy with shape (32, 438)
# Processing 02273.mp4...
# Saved landmarks2\02273.npy with shape (99, 438)
# Processing 02276.mp4...
# Saved landmarks2\02276.npy with shape (61, 438)
# Processing 02285.mp4...
# Saved landmarks2\02285.npy with shape (88, 438)
# Processing 02349.mp4...
# Saved landmarks2\02349.npy with shape (167, 438)
# Processing 02350.mp4...
# Saved landmarks2\02350.npy with shape (38, 438)
# Processing 02351.mp4...
# Saved landmarks2\02351.npy with shape (154, 438)
# Processing 02353.mp4...
# Saved landmarks2\02353.npy with shape (65, 438)
# Processing 02356.mp4...
# Saved landmarks2\02356.npy with shape (97, 438)
# Processing 02429.mp4...
# Saved landmarks2\02429.npy with shape (141, 438)
# Processing 02430.mp4...
# Saved landmarks2\02430.npy with shape (31, 438)
# Processing 02431.mp4...
# Saved landmarks2\02431.npy with shape (81, 438)
# Processing 02434.mp4...
# Saved landmarks2\02434.npy with shape (56, 438)
# Processing 02435.mp4...
# Saved landmarks2\02435.npy with shape (89, 438)
# Processing 02474.mp4...
# Saved landmarks2\02474.npy with shape (92, 438)
# Processing 02475.mp4...
# Saved landmarks2\02475.npy with shape (77, 438)
# Processing 02476.mp4...
# Saved landmarks2\02476.npy with shape (86, 438)
# Processing 02477.mp4...
# Saved landmarks2\02477.npy with shape (55, 438)
# Processing 02478.mp4...
# Saved landmarks2\02478.npy with shape (115, 438)
# Processing 02480.mp4...
# Saved landmarks2\02480.npy with shape (53, 438)
# Processing 02483.mp4...
# Saved landmarks2\02483.npy with shape (86, 438)
# Processing 02485.mp4...
# Saved landmarks2\02485.npy with shape (99, 438)
# Processing 02487.mp4...
# Saved landmarks2\02487.npy with shape (91, 438)
# Processing 02490.mp4...
# Saved landmarks2\02490.npy with shape (107, 438)
# Processing 02492.mp4...
# Saved landmarks2\02492.npy with shape (95, 438)
# Processing 02518.mp4...
# Saved landmarks2\02518.npy with shape (69, 438)
# Processing 02519.mp4...
# Saved landmarks2\02519.npy with shape (87, 438)
# Processing 02521.mp4...
# Saved landmarks2\02521.npy with shape (57, 438)
# Processing 02525.mp4...
# Saved landmarks2\02525.npy with shape (73, 438)
# Processing 02540.mp4...
# Saved landmarks2\02540.npy with shape (71, 438)
# Processing 02541.mp4...
# Saved landmarks2\02541.npy with shape (47, 438)
# Processing 02542.mp4...
# Saved landmarks2\02542.npy with shape (63, 438)
# Processing 02544.mp4...
# Saved landmarks2\02544.npy with shape (35, 438)
# Processing 02545.mp4...
# Saved landmarks2\02545.npy with shape (51, 438)
# Processing 02548.mp4...
# Saved landmarks2\02548.npy with shape (85, 438)
# Processing 02558.mp4...
# Saved landmarks2\02558.npy with shape (119, 438)
# Processing 02559.mp4...
# Saved landmarks2\02559.npy with shape (57, 438)
# Processing 02560.mp4...
# Saved landmarks2\02560.npy with shape (55, 438)
# Processing 02561.mp4...
# Saved landmarks2\02561.npy with shape (44, 438)
# Processing 02563.mp4...
# Saved landmarks2\02563.npy with shape (92, 438)
# Processing 02565.mp4...
# Saved landmarks2\02565.npy with shape (68, 438)
# Processing 02566.mp4...
# Saved landmarks2\02566.npy with shape (39, 438)
# Processing 02567.mp4...
# Saved landmarks2\02567.npy with shape (58, 438)
# Processing 02568.mp4...
# Saved landmarks2\02568.npy with shape (48, 438)
# Processing 02569.mp4...
# Saved landmarks2\02569.npy with shape (104, 438)
# Processing 02572.mp4...
# Saved landmarks2\02572.npy with shape (30, 438)
# Processing 02583.mp4...
# Saved landmarks2\02583.npy with shape (127, 438)
# Processing 02584.mp4...
# Saved landmarks2\02584.npy with shape (73, 438)
# Processing 02585.mp4...
# Saved landmarks2\02585.npy with shape (78, 438)
# Processing 02586.mp4...
# Saved landmarks2\02586.npy with shape (68, 438)
# Processing 02587.mp4...
# Saved landmarks2\02587.npy with shape (111, 438)
# Processing 02589.mp4...
# Saved landmarks2\02589.npy with shape (54, 438)
# Processing 02592.mp4...
# Saved landmarks2\02592.npy with shape (90, 438)
# Processing 02609.mp4...
# Saved landmarks2\02609.npy with shape (95, 438)
# Processing 02610.mp4...
# Saved landmarks2\02610.npy with shape (62, 438)
# Processing 02611.mp4...
# Saved landmarks2\02611.npy with shape (117, 438)
# Processing 02614.mp4...
# Saved landmarks2\02614.npy with shape (74, 438)
# Processing 02616.mp4...
# Saved landmarks2\02616.npy with shape (95, 438)
# Processing 02619.mp4...
# Saved landmarks2\02619.npy with shape (88, 438)
# Processing 02620.mp4...
# Saved landmarks2\02620.npy with shape (116, 438)
# Processing 02622.mp4...
# Saved landmarks2\02622.npy with shape (57, 438)
# Processing 02625.mp4...
# Saved landmarks2\02625.npy with shape (83, 438)
# Processing 02643.mp4...
# Saved landmarks2\02643.npy with shape (89, 438)
# Processing 02644.mp4...
# Saved landmarks2\02644.npy with shape (37, 438)
# Processing 02645.mp4...
# Saved landmarks2\02645.npy with shape (136, 438)
# Processing 02653.mp4...
# Saved landmarks2\02653.npy with shape (85, 438)
# Processing 02697.mp4...
# Saved landmarks2\02697.npy with shape (69, 438)
# Processing 02698.mp4...
# Saved landmarks2\02698.npy with shape (39, 438)
# Processing 02699.mp4...
# Saved landmarks2\02699.npy with shape (99, 438)
# Processing 02701.mp4...
# Saved landmarks2\02701.npy with shape (36, 438)
# Processing 02706.mp4...
# Saved landmarks2\02706.npy with shape (82, 438)
# Processing 02710.mp4...
# Saved landmarks2\02710.npy with shape (103, 438)
# Processing 02711.mp4...
# Saved landmarks2\02711.npy with shape (77, 438)
# Processing 02712.mp4...
# Saved landmarks2\02712.npy with shape (29, 438)
# Processing 02713.mp4...
# Saved landmarks2\02713.npy with shape (103, 438)
# Processing 02715.mp4...
# Saved landmarks2\02715.npy with shape (35, 438)
# Processing 02718.mp4...
# Saved landmarks2\02718.npy with shape (94, 438)
# Processing 02826.mp4...
# Saved landmarks2\02826.npy with shape (76, 438)
# Processing 02828.mp4...
# Saved landmarks2\02828.npy with shape (75, 438)
# Processing 02833.mp4...
# Saved landmarks2\02833.npy with shape (79, 438)
# Processing 02851.mp4...
# Saved landmarks2\02851.npy with shape (140, 438)
# Processing 02852.mp4...
# Saved landmarks2\02852.npy with shape (107, 438)
# Processing 02854.mp4...
# Saved landmarks2\02854.npy with shape (54, 438)
# Processing 02856.mp4...
# Saved landmarks2\02856.npy with shape (83, 438)
# Processing 02864.mp4...
# Saved landmarks2\02864.npy with shape (92, 438)
# Processing 02865.mp4...
# Saved landmarks2\02865.npy with shape (83, 438)
# Processing 02867.mp4...
# Saved landmarks2\02867.npy with shape (49, 438)
# Processing 02870.mp4...
# Saved landmarks2\02870.npy with shape (76, 438)
# Processing 02872.mp4...
# Saved landmarks2\02872.npy with shape (110, 438)
# Processing 02873.mp4...
# Saved landmarks2\02873.npy with shape (69, 438)
# Processing 02874.mp4...
# Saved landmarks2\02874.npy with shape (25, 438)
# Processing 02875.mp4...
# Saved landmarks2\02875.npy with shape (145, 438)
# Processing 02877.mp4...
# Saved landmarks2\02877.npy with shape (35, 438)
# Processing 02880.mp4...
# Saved landmarks2\02880.npy with shape (93, 438)
# Processing 02910.mp4...
# Saved landmarks2\02910.npy with shape (135, 438)
# Processing 02911.mp4...
# Saved landmarks2\02911.npy with shape (34, 438)
# Processing 02912.mp4...
# Saved landmarks2\02912.npy with shape (33, 438)
# Processing 02913.mp4...
# Saved landmarks2\02913.npy with shape (61, 438)
# Processing 02915.mp4...
# Saved landmarks2\02915.npy with shape (32, 438)
# Processing 02951.mp4...
# Saved landmarks2\02951.npy with shape (108, 438)
# Processing 02952.mp4...
# Saved landmarks2\02952.npy with shape (99, 438)
# Processing 02953.mp4...
# Saved landmarks2\02953.npy with shape (33, 438)
# Processing 02954.mp4...
# Saved landmarks2\02954.npy with shape (114, 438)
# Processing 02956.mp4...
# Saved landmarks2\02956.npy with shape (27, 438)
# Processing 02961.mp4...
# Saved landmarks2\02961.npy with shape (79, 438)
# Processing 02969.mp4...
# Saved landmarks2\02969.npy with shape (85, 438)
# Processing 02970.mp4...
# Saved landmarks2\02970.npy with shape (131, 438)
# Processing 02971.mp4...
# Saved landmarks2\02971.npy with shape (146, 438)
# Processing 02973.mp4...
# Saved landmarks2\02973.npy with shape (29, 438)
# Processing 02975.mp4...
# Saved landmarks2\02975.npy with shape (72, 438)
# Processing 02999.mp4...
# Saved landmarks2\02999.npy with shape (72, 438)
# Processing 03000.mp4...
# Saved landmarks2\03000.npy with shape (104, 438)
# Processing 03001.mp4...
# Saved landmarks2\03001.npy with shape (91, 438)
# Processing 03002.mp4...
# Saved landmarks2\03002.npy with shape (66, 438)
# Processing 03003.mp4...
# Saved landmarks2\03003.npy with shape (128, 438)
# Processing 03005.mp4...
# Saved landmarks2\03005.npy with shape (44, 438)
# Processing 03008.mp4...
# Saved landmarks2\03008.npy with shape (88, 438)
# Processing 03055.mp4...
# Saved landmarks2\03055.npy with shape (185, 438)
# Processing 03056.mp4...
# Saved landmarks2\03056.npy with shape (114, 438)
# Processing 03057.mp4...
# Saved landmarks2\03057.npy with shape (96, 438)
# Processing 03058.mp4...
# Saved landmarks2\03058.npy with shape (56, 438)
# Processing 03059.mp4...
# Saved landmarks2\03059.npy with shape (101, 438)
# Processing 03060.mp4...
# Saved landmarks2\03060.npy with shape (123, 438)
# Processing 03061.mp4...
# Saved landmarks2\03061.npy with shape (48, 438)
# Processing 03062.mp4...
# Saved landmarks2\03062.npy with shape (42, 438)
# Processing 03063.mp4...
# Saved landmarks2\03063.npy with shape (93, 438)
# Processing 03068.mp4...
# Saved landmarks2\03068.npy with shape (109, 438)
# Processing 03069.mp4...
# Saved landmarks2\03069.npy with shape (47, 438)
# Processing 03070.mp4...
# Saved landmarks2\03070.npy with shape (88, 438)
# Processing 03073.mp4...
# Saved landmarks2\03073.npy with shape (65, 438)
# Processing 03074.mp4...
# Saved landmarks2\03074.npy with shape (87, 438)
# Processing 03090.mp4...
# Saved landmarks2\03090.npy with shape (78, 438)
# Processing 03092.mp4...
# Saved landmarks2\03092.npy with shape (38, 438)
# Processing 03093.mp4...
# Saved landmarks2\03093.npy with shape (125, 438)
# Processing 03096.mp4...
# Saved landmarks2\03096.npy with shape (38, 438)
# Processing 03101.mp4...
# Saved landmarks2\03101.npy with shape (93, 438)
# Processing 03102.mp4...
# Saved landmarks2\03102.npy with shape (44, 438)
# Processing 03103.mp4...
# Saved landmarks2\03103.npy with shape (114, 438)
# Processing 03105.mp4...
# Saved landmarks2\03105.npy with shape (60, 438)
# Processing 03108.mp4...
# Saved landmarks2\03108.npy with shape (89, 438)
# Processing 03118.mp4...
# Saved landmarks2\03118.npy with shape (135, 438)
# Processing 03119.mp4...
# Saved landmarks2\03119.npy with shape (88, 438)
# Processing 03120.mp4...
# Saved landmarks2\03120.npy with shape (122, 438)
# Processing 03121.mp4...
# Saved landmarks2\03121.npy with shape (30, 438)
# Processing 03122.mp4...
# Saved landmarks2\03122.npy with shape (111, 438)
# Processing 03124.mp4...
# Saved landmarks2\03124.npy with shape (39, 438)
# Processing 03125.mp4...
# Saved landmarks2\03125.npy with shape (29, 438)
# Processing 03131.mp4...
# Saved landmarks2\03131.npy with shape (74, 438)
# Processing 03154.mp4...
# Saved landmarks2\03154.npy with shape (129, 438)
# Processing 03155.mp4...
# Saved landmarks2\03155.npy with shape (63, 438)
# Processing 03156.mp4...
# Saved landmarks2\03156.npy with shape (233, 438)
# Processing 03158.mp4...
# Saved landmarks2\03158.npy with shape (69, 438)
# Processing 03161.mp4...
# Saved landmarks2\03161.npy with shape (101, 438)
# Processing 03201.mp4...
# Saved landmarks2\03201.npy with shape (73, 438)
# Processing 03202.mp4...
# Saved landmarks2\03202.npy with shape (70, 438)
# Processing 03204.mp4...
# Saved landmarks2\03204.npy with shape (48, 438)
# Processing 03205.mp4...
# Saved landmarks2\03205.npy with shape (52, 438)
# Processing 03207.mp4...
# Saved landmarks2\03207.npy with shape (84, 438)
# Processing 03234.mp4...
# Saved landmarks2\03234.npy with shape (85, 438)
# Processing 03235.mp4...
# Saved landmarks2\03235.npy with shape (33, 438)
# Processing 03237.mp4...
# Saved landmarks2\03237.npy with shape (43, 438)
# Processing 03238.mp4...
# Saved landmarks2\03238.npy with shape (113, 438)
# Processing 03240.mp4...
# Saved landmarks2\03240.npy with shape (62, 438)
# Processing 03246.mp4...
# Saved landmarks2\03246.npy with shape (92, 438)
# Processing 03267.mp4...
# Saved landmarks2\03267.npy with shape (87, 438)
# Processing 03268.mp4...
# Saved landmarks2\03268.npy with shape (110, 438)
# Processing 03270.mp4...
# Saved landmarks2\03270.npy with shape (77, 438)
# Processing 03272.mp4...
# Saved landmarks2\03272.npy with shape (33, 438)
# Processing 03273.mp4...
# Saved landmarks2\03273.npy with shape (38, 438)
# Processing 03274.mp4...
# Saved landmarks2\03274.npy with shape (120, 438)
# Processing 03277.mp4...
# Saved landmarks2\03277.npy with shape (52, 438)
# Processing 03278.mp4...
# Saved landmarks2\03278.npy with shape (56, 438)
# Processing 03282.mp4...
# Saved landmarks2\03282.npy with shape (81, 438)
# Processing 03315.mp4...
# Saved landmarks2\03315.npy with shape (42, 438)
# Processing 03316.mp4...
# Saved landmarks2\03316.npy with shape (116, 438)
# Processing 03318.mp4...
# Saved landmarks2\03318.npy with shape (56, 438)
# Processing 03337.mp4...
# Saved landmarks2\03337.npy with shape (78, 438)
# Processing 03338.mp4...
# Saved landmarks2\03338.npy with shape (36, 438)
# Processing 03339.mp4...
# Saved landmarks2\03339.npy with shape (114, 438)
# Processing 03342.mp4...
# Saved landmarks2\03342.npy with shape (35, 438)
# Processing 03344.mp4...
# Saved landmarks2\03344.npy with shape (83, 438)
# Processing 03361.mp4...
# Saved landmarks2\03361.npy with shape (71, 438)
# Processing 03362.mp4...
# Saved landmarks2\03362.npy with shape (106, 438)
# Processing 03364.mp4...
# Saved landmarks2\03364.npy with shape (41, 438)
# Processing 03368.mp4...
# Saved landmarks2\03368.npy with shape (100, 438)
# Processing 03376.mp4...
# Saved landmarks2\03376.npy with shape (101, 438)
# Processing 03377.mp4...
# Saved landmarks2\03377.npy with shape (53, 438)
# Processing 03378.mp4...
# Saved landmarks2\03378.npy with shape (114, 438)
# Processing 03382.mp4...
# Saved landmarks2\03382.npy with shape (66, 438)
# Processing 03389.mp4...
# Saved landmarks2\03389.npy with shape (112, 438)
# Processing 03417.mp4...
# Saved landmarks2\03417.npy with shape (21, 438)
# Processing 03418.mp4...
# Saved landmarks2\03418.npy with shape (24, 438)
# Processing 03419.mp4...
# Saved landmarks2\03419.npy with shape (20, 438)
# Processing 03420.mp4...
# Saved landmarks2\03420.npy with shape (25, 438)
# Processing 03425.mp4...
# Saved landmarks2\03425.npy with shape (36, 438)
# Processing 03430.mp4...
# Saved landmarks2\03430.npy with shape (87, 438)
# Processing 03435.mp4...
# Saved landmarks2\03435.npy with shape (108, 438)
# Processing 03436.mp4...
# Saved landmarks2\03436.npy with shape (66, 438)
# Processing 03437.mp4...
# Saved landmarks2\03437.npy with shape (37, 438)
# Processing 03438.mp4...
# Saved landmarks2\03438.npy with shape (34, 438)
# Processing 03439.mp4...
# Saved landmarks2\03439.npy with shape (117, 438)
# Processing 03441.mp4...
# Saved landmarks2\03441.npy with shape (47, 438)
# Processing 03445.mp4...
# Saved landmarks2\03445.npy with shape (93, 438)
# Processing 03448.mp4...
# Saved landmarks2\03448.npy with shape (121, 438)
# Processing 03449.mp4...
# Saved landmarks2\03449.npy with shape (122, 438)
# Processing 03450.mp4...
# Saved landmarks2\03450.npy with shape (36, 438)
# Processing 03451.mp4...
# Saved landmarks2\03451.npy with shape (102, 438)
# Processing 03454.mp4...
# Saved landmarks2\03454.npy with shape (49, 438)
# Processing 03457.mp4...
# Saved landmarks2\03457.npy with shape (99, 438)
# Processing 03478.mp4...
# Saved landmarks2\03478.npy with shape (80, 438)
# Processing 03479.mp4...
# Saved landmarks2\03479.npy with shape (87, 438)
# Processing 03480.mp4...
# Saved landmarks2\03480.npy with shape (40, 438)
# Processing 03481.mp4...
# Saved landmarks2\03481.npy with shape (129, 438)
# Processing 03484.mp4...
# Saved landmarks2\03484.npy with shape (38, 438)
# Processing 03486.mp4...
# Saved landmarks2\03486.npy with shape (95, 438)
# Processing 03490.mp4...
# Saved landmarks2\03490.npy with shape (160, 438)
# Processing 03491.mp4...
# Saved landmarks2\03491.npy with shape (127, 438)
# Processing 03493.mp4...
# Saved landmarks2\03493.npy with shape (37, 438)
# Processing 03515.mp4...
# Saved landmarks2\03515.npy with shape (101, 438)
# Processing 03516.mp4...
# Saved landmarks2\03516.npy with shape (88, 438)
# Processing 03517.mp4...
# Saved landmarks2\03517.npy with shape (108, 438)
# Processing 03519.mp4...
# Saved landmarks2\03519.npy with shape (60, 438)
# Processing 03522.mp4...
# Saved landmarks2\03522.npy with shape (111, 438)
# Processing 03562.mp4...
# Saved landmarks2\03562.npy with shape (65, 438)
# Processing 03563.mp4...
# Saved landmarks2\03563.npy with shape (72, 438)
# Processing 03564.mp4...
# Saved landmarks2\03564.npy with shape (41, 438)
# Processing 03565.mp4...
# Saved landmarks2\03565.npy with shape (79, 438)
# Processing 03568.mp4...
# Saved landmarks2\03568.npy with shape (45, 438)
# Processing 03571.mp4...
# Saved landmarks2\03571.npy with shape (116, 438)
# Processing 03595.mp4...
# Saved landmarks2\03595.npy with shape (56, 438)
# Processing 03597.mp4...
# Saved landmarks2\03597.npy with shape (39, 438)
# Processing 03598.mp4...
# Saved landmarks2\03598.npy with shape (98, 438)
# Processing 03603.mp4...
# Saved landmarks2\03603.npy with shape (42, 438)
# Processing 03605.mp4...
# Saved landmarks2\03605.npy with shape (50, 438)
# Processing 03607.mp4...
# Saved landmarks2\03607.npy with shape (32, 438)
# Processing 03634.mp4...
# Saved landmarks2\03634.npy with shape (62, 438)
# Processing 03635.mp4...
# Saved landmarks2\03635.npy with shape (77, 438)
# Processing 03638.mp4...
# Saved landmarks2\03638.npy with shape (53, 438)
# Processing 03642.mp4...
# Saved landmarks2\03642.npy with shape (101, 438)
# Processing 03756.mp4...
# Saved landmarks2\03756.npy with shape (102, 438)
# Processing 03757.mp4...
# Saved landmarks2\03757.npy with shape (62, 438)
# Processing 03758.mp4...
# Saved landmarks2\03758.npy with shape (39, 438)
# Processing 03761.mp4...
# Saved landmarks2\03761.npy with shape (68, 438)
# Processing 03763.mp4...
# Saved landmarks2\03763.npy with shape (85, 438)
# Processing 03765.mp4...
# Saved landmarks2\03765.npy with shape (66, 438)
# Processing 03766.mp4...
# Saved landmarks2\03766.npy with shape (68, 438)
# Processing 03768.mp4...
# Saved landmarks2\03768.npy with shape (49, 438)
# Processing 03769.mp4...
# Saved landmarks2\03769.npy with shape (30, 438)
# Processing 03771.mp4...
# Saved landmarks2\03771.npy with shape (76, 438)
# Processing 03799.mp4...
# Saved landmarks2\03799.npy with shape (133, 438)
# Processing 03800.mp4...
# Saved landmarks2\03800.npy with shape (89, 438)
# Processing 03802.mp4...
# Saved landmarks2\03802.npy with shape (34, 438)
# Processing 03805.mp4...
# Saved landmarks2\03805.npy with shape (85, 438)
# Processing 03999.mp4...
# Saved landmarks2\03999.npy with shape (93, 438)
# Processing 04000.mp4...
# Saved landmarks2\04000.npy with shape (97, 438)
# Processing 04002.mp4...
# Saved landmarks2\04002.npy with shape (60, 438)
# Processing 04003.mp4...
# Saved landmarks2\04003.npy with shape (45, 438)
# Processing 04007.mp4...
# Saved landmarks2\04007.npy with shape (105, 438)
# Processing 04011.mp4...
# Saved landmarks2\04011.npy with shape (93, 438)
# Processing 04012.mp4...
# Saved landmarks2\04012.npy with shape (36, 438)
# Processing 04013.mp4...
# Saved landmarks2\04013.npy with shape (116, 438)
# Processing 04015.mp4...
# Saved landmarks2\04015.npy with shape (43, 438)
# Processing 04017.mp4...
# Saved landmarks2\04017.npy with shape (113, 438)
# Processing 04040.mp4...
# Saved landmarks2\04040.npy with shape (81, 438)
# Processing 04041.mp4...
# Saved landmarks2\04041.npy with shape (41, 438)
# Processing 04042.mp4...
# Saved landmarks2\04042.npy with shape (105, 438)
# Processing 04044.mp4...
# Saved landmarks2\04044.npy with shape (39, 438)
# Processing 04045.mp4...
# Saved landmarks2\04045.npy with shape (44, 438)
# Processing 04048.mp4...
# Saved landmarks2\04048.npy with shape (108, 438)
# Processing 04050.mp4...
# Saved landmarks2\04050.npy with shape (86, 438)
# Processing 04051.mp4...
# Saved landmarks2\04051.npy with shape (120, 438)
# Processing 04053.mp4...
# Saved landmarks2\04053.npy with shape (53, 438)
# Processing 04055.mp4...
# Saved landmarks2\04055.npy with shape (110, 438)
# Processing 04062.mp4...
# Saved landmarks2\04062.npy with shape (85, 438)
# Processing 04063.mp4...
# Saved landmarks2\04063.npy with shape (29, 438)
# Processing 04064.mp4...
# Saved landmarks2\04064.npy with shape (96, 438)
# Processing 04072.mp4...
# Saved landmarks2\04072.npy with shape (35, 438)
# Processing 04073.mp4...
# Saved landmarks2\04073.npy with shape (35, 438)
# Processing 04076.mp4...
# Saved landmarks2\04076.npy with shape (87, 438)
# Processing 04099.mp4...
# Saved landmarks2\04099.npy with shape (88, 438)
# Processing 04101.mp4...
# Saved landmarks2\04101.npy with shape (52, 438)
# Processing 04102.mp4...
# Saved landmarks2\04102.npy with shape (162, 438)
# Processing 04104.mp4...
# Saved landmarks2\04104.npy with shape (55, 438)
# Processing 04106.mp4...
# Saved landmarks2\04106.npy with shape (71, 438)
# Processing 04115.mp4...
# Saved landmarks2\04115.npy with shape (34, 438)
# Processing 04116.mp4...
# Saved landmarks2\04116.npy with shape (108, 438)
# Processing 04118.mp4...
# Saved landmarks2\04118.npy with shape (31, 438)
# Processing 04119.mp4...
# Saved landmarks2\04119.npy with shape (34, 438)
# Processing 04120.mp4...
# Saved landmarks2\04120.npy with shape (28, 438)
# Processing 04123.mp4...
# Saved landmarks2\04123.npy with shape (88, 438)
# Processing 04129.mp4...
# Saved landmarks2\04129.npy with shape (113, 438)
# Processing 04130.mp4...
# Saved landmarks2\04130.npy with shape (122, 438)
# Processing 04132.mp4...
# Saved landmarks2\04132.npy with shape (82, 438)
# Processing 04134.mp4...
# Saved landmarks2\04134.npy with shape (88, 438)
# Processing 04136.mp4...
# Saved landmarks2\04136.npy with shape (77, 438)
# Processing 04137.mp4...
# Saved landmarks2\04137.npy with shape (54, 438)
# Processing 04139.mp4...
# Saved landmarks2\04139.npy with shape (65, 438)
# Processing 04141.mp4...
# Saved landmarks2\04141.npy with shape (101, 438)
# Processing 04155.mp4...
# Saved landmarks2\04155.npy with shape (93, 438)
# Processing 04156.mp4...
# Saved landmarks2\04156.npy with shape (64, 438)
# Processing 04157.mp4...
# Saved landmarks2\04157.npy with shape (146, 438)
# Processing 04159.mp4...
# Saved landmarks2\04159.npy with shape (56, 438)
# Processing 04163.mp4...
# Saved landmarks2\04163.npy with shape (84, 438)
# Processing 04164.mp4...
# Saved landmarks2\04164.npy with shape (84, 438)
# Processing 04168.mp4...
# Saved landmarks2\04168.npy with shape (75, 438)
# Processing 04169.mp4...
# Saved landmarks2\04169.npy with shape (98, 438)
# Processing 04170.mp4...
# Saved landmarks2\04170.npy with shape (96, 438)
# Processing 04171.mp4...
# Saved landmarks2\04171.npy with shape (114, 438)
# Processing 04173.mp4...
# Saved landmarks2\04173.npy with shape (64, 438)
# Processing 04176.mp4...
# Saved landmarks2\04176.npy with shape (83, 438)
# Processing 04184.mp4...
# Saved landmarks2\04184.npy with shape (65, 438)
# Processing 04186.mp4...
# Saved landmarks2\04186.npy with shape (69, 438)
# Processing 04187.mp4...
# Saved landmarks2\04187.npy with shape (45, 438)
# Processing 04188.mp4...
# Saved landmarks2\04188.npy with shape (43, 438)
# Processing 04189.mp4...
# Saved landmarks2\04189.npy with shape (31, 438)
# Processing 04190.mp4...
# Saved landmarks2\04190.npy with shape (117, 438)
# Processing 04193.mp4...
# Saved landmarks2\04193.npy with shape (34, 438)
# Processing 04198.mp4...
# Saved landmarks2\04198.npy with shape (83, 438)
# Processing 04200.mp4...
# Saved landmarks2\04200.npy with shape (108, 438)
# Processing 04201.mp4...
# Saved landmarks2\04201.npy with shape (88, 438)
# Processing 04202.mp4...
# Saved landmarks2\04202.npy with shape (40, 438)
# Processing 04203.mp4...
# Saved landmarks2\04203.npy with shape (131, 438)
# Processing 04218.mp4...
# Saved landmarks2\04218.npy with shape (95, 438)
# Processing 04219.mp4...
# Saved landmarks2\04219.npy with shape (136, 438)
# Processing 04221.mp4...
# Saved landmarks2\04221.npy with shape (72, 438)
# Processing 04223.mp4...
# Saved landmarks2\04223.npy with shape (81, 438)
# Processing 04226.mp4...
# Saved landmarks2\04226.npy with shape (90, 438)
# Processing 04227.mp4...
# Saved landmarks2\04227.npy with shape (49, 438)
# Processing 04228.mp4...
# Saved landmarks2\04228.npy with shape (89, 438)
# Processing 04230.mp4...
# Saved landmarks2\04230.npy with shape (44, 438)
# Processing 04232.mp4...
# Saved landmarks2\04232.npy with shape (73, 438)
# Processing 04289.mp4...
# Saved landmarks2\04289.npy with shape (94, 438)
# Processing 04290.mp4...
# Saved landmarks2\04290.npy with shape (55, 438)
# Processing 04291.mp4...
# Saved landmarks2\04291.npy with shape (50, 438)
# Processing 04292.mp4...
# Saved landmarks2\04292.npy with shape (99, 438)
# Processing 04294.mp4...
# Saved landmarks2\04294.npy with shape (52, 438)
# Processing 04296.mp4...
# Saved landmarks2\04296.npy with shape (75, 438)
# Processing 04301.mp4...
# Saved landmarks2\04301.npy with shape (94, 438)
# Processing 04302.mp4...
# Saved landmarks2\04302.npy with shape (87, 438)
# Processing 04304.mp4...
# Saved landmarks2\04304.npy with shape (31, 438)
# Processing 04307.mp4...
# Saved landmarks2\04307.npy with shape (92, 438)
# Processing 04324.mp4...
# Saved landmarks2\04324.npy with shape (107, 438)
# Processing 04325.mp4...
# Saved landmarks2\04325.npy with shape (91, 438)
# Processing 04326.mp4...
# Saved landmarks2\04326.npy with shape (44, 438)
# Processing 04330.mp4...
# Saved landmarks2\04330.npy with shape (44, 438)
# Processing 04332.mp4...
# Saved landmarks2\04332.npy with shape (98, 438)
# Processing 04343.mp4...
# Saved landmarks2\04343.npy with shape (85, 438)
# Processing 04344.mp4...
# Saved landmarks2\04344.npy with shape (34, 438)
# Processing 04345.mp4...
# Saved landmarks2\04345.npy with shape (115, 438)
# Processing 04347.mp4...
# Saved landmarks2\04347.npy with shape (34, 438)
# Processing 04348.mp4...
# Saved landmarks2\04348.npy with shape (38, 438)
# Processing 04352.mp4...
# Saved landmarks2\04352.npy with shape (89, 438)
# Processing 04355.mp4...
# Saved landmarks2\04355.npy with shape (85, 438)
# Processing 04356.mp4...
# Saved landmarks2\04356.npy with shape (101, 438)
# Processing 04358.mp4...
# Saved landmarks2\04358.npy with shape (26, 438)
# Processing 04361.mp4...
# ...
# Processing 66821.mp4...
# Saved landmarks2\66821.npy with shape (64, 438)
# Processing 66822.mp4...
# Saved landmarks2\66822.npy with shape (62, 438)
# Processing 66825.mp4...
# Saved landmarks2\66825.npy with shape (57, 438)
# Processing 69205.mp4...
# Saved landmarks2\69205.npy with shape (83, 438)
# Processing 69206.mp4...
# Saved landmarks2\69206.npy with shape (89, 438)
# Processing 69207.mp4...
# Saved landmarks2\69207.npy with shape (73, 438)
# Processing 69210.mp4...
# Saved landmarks2\69210.npy with shape (85, 438)
# Processing 69211.mp4...
# Saved landmarks2\69211.npy with shape (69, 438)
# Processing 69212.mp4...
# Saved landmarks2\69212.npy with shape (87, 438)
# Processing 69213.mp4...
# Saved landmarks2\69213.npy with shape (91, 438)
# Processing 69215.mp4...
# Saved landmarks2\69215.npy with shape (61, 438)
# Processing 69216.mp4...
# Saved landmarks2\69216.npy with shape (88, 438)
# Processing 69217.mp4...
# Saved landmarks2\69217.npy with shape (72, 438)
# Processing 69218.mp4...
# Saved landmarks2\69218.npy with shape (90, 438)
# Processing 69219.mp4...
# Saved landmarks2\69219.npy with shape (54, 438)
# Processing 69221.mp4...
# Saved landmarks2\69221.npy with shape (94, 438)
# Processing 69225.mp4...
# Saved landmarks2\69225.npy with shape (92, 438)
# Processing 69226.mp4...
# Saved landmarks2\69226.npy with shape (90, 438)
# Processing 69230.mp4...
# Saved landmarks2\69230.npy with shape (88, 438)
# Processing 69231.mp4...
# Saved landmarks2\69231.npy with shape (77, 438)
# Processing 69233.mp4...
# Saved landmarks2\69233.npy with shape (84, 438)
# Processing 69236.mp4...
# Saved landmarks2\69236.npy with shape (63, 438)
# Processing 69238.mp4...
# Saved landmarks2\69238.npy with shape (62, 438)
# Processing 69239.mp4...
# Saved landmarks2\69239.npy with shape (88, 438)
# Processing 69240.mp4...
# Saved landmarks2\69240.npy with shape (52, 438)
# Processing 69241.mp4...
# Saved landmarks2\69241.npy with shape (75, 438)
# Processing 69242.mp4...
# Saved landmarks2\69242.npy with shape (91, 438)
# Processing 69243.mp4...
# Saved landmarks2\69243.npy with shape (92, 438)
# Processing 69244.mp4...
# Saved landmarks2\69244.npy with shape (88, 438)
# Processing 69245.mp4...
# Saved landmarks2\69245.npy with shape (72, 438)
# Processing 69250.mp4...
# Saved landmarks2\69250.npy with shape (83, 438)
# Processing 69251.mp4...
# Saved landmarks2\69251.npy with shape (77, 438)
# Processing 69252.mp4...
# Saved landmarks2\69252.npy with shape (72, 438)
# Processing 69255.mp4...
# Saved landmarks2\69255.npy with shape (90, 438)
# Processing 69256.mp4...
# Saved landmarks2\69256.npy with shape (106, 438)
# Processing 69257.mp4...
# Saved landmarks2\69257.npy with shape (56, 438)
# Processing 69258.mp4...
# Saved landmarks2\69258.npy with shape (74, 438)
# Processing 69259.mp4...
# Saved landmarks2\69259.npy with shape (94, 438)
# Processing 69260.mp4...
# Saved landmarks2\69260.npy with shape (101, 438)
# Processing 69261.mp4...
# Saved landmarks2\69261.npy with shape (67, 438)
# Processing 69262.mp4...
# Saved landmarks2\69262.npy with shape (80, 438)
# Processing 69264.mp4...
# Saved landmarks2\69264.npy with shape (87, 438)
# Processing 69266.mp4...
# Saved landmarks2\69266.npy with shape (77, 438)
# Processing 69269.mp4...
# Saved landmarks2\69269.npy with shape (91, 438)
# Processing 69270.mp4...
# Saved landmarks2\69270.npy with shape (63, 438)
# Processing 69271.mp4...
# Saved landmarks2\69271.npy with shape (91, 438)
# Processing 69274.mp4...
# Saved landmarks2\69274.npy with shape (107, 438)
# Processing 69275.mp4...
# Saved landmarks2\69275.npy with shape (86, 438)
# Processing 69276.mp4...
# Saved landmarks2\69276.npy with shape (87, 438)
# Processing 69280.mp4...
# Saved landmarks2\69280.npy with shape (81, 438)
# Processing 69281.mp4...
# Saved landmarks2\69281.npy with shape (77, 438)
# Processing 69282.mp4...
# Saved landmarks2\69282.npy with shape (86, 438)
# Processing 69283.mp4...
# Saved landmarks2\69283.npy with shape (80, 438)
# Processing 69284.mp4...
# Saved landmarks2\69284.npy with shape (90, 438)
# Processing 69286.mp4...
# Saved landmarks2\69286.npy with shape (90, 438)
# Processing 69289.mp4...
# Saved landmarks2\69289.npy with shape (86, 438)
# Processing 69290.mp4...
# Saved landmarks2\69290.npy with shape (69, 438)
# Processing 69291.mp4...
# Saved landmarks2\69291.npy with shape (63, 438)
# Processing 69292.mp4...
# Saved landmarks2\69292.npy with shape (91, 438)
# Processing 69294.mp4...
# Saved landmarks2\69294.npy with shape (70, 438)
# Processing 69296.mp4...
# Saved landmarks2\69296.npy with shape (92, 438)
# Processing 69298.mp4...
# Saved landmarks2\69298.npy with shape (81, 438)
# Processing 69299.mp4...
# Saved landmarks2\69299.npy with shape (86, 438)
# Processing 69300.mp4...
# Saved landmarks2\69300.npy with shape (78, 438)
# Processing 69301.mp4...
# Saved landmarks2\69301.npy with shape (65, 438)
# Processing 69302.mp4...
# Saved landmarks2\69302.npy with shape (77, 438)
# Processing 69303.mp4...
# Saved landmarks2\69303.npy with shape (92, 438)
# Processing 69304.mp4...
# Saved landmarks2\69304.npy with shape (63, 438)
# Processing 69305.mp4...
# Saved landmarks2\69305.npy with shape (77, 438)
# Processing 69306.mp4...
# Saved landmarks2\69306.npy with shape (68, 438)
# Processing 69307.mp4...
# Saved landmarks2\69307.npy with shape (61, 438)
# Processing 69309.mp4...
# Saved landmarks2\69309.npy with shape (56, 438)
# Processing 69311.mp4...
# Saved landmarks2\69311.npy with shape (88, 438)
# Processing 69314.mp4...
# Saved landmarks2\69314.npy with shape (53, 438)
# Processing 69315.mp4...
# Saved landmarks2\69315.npy with shape (84, 438)
# Processing 69316.mp4...
# Saved landmarks2\69316.npy with shape (85, 438)
# Processing 69317.mp4...
# Saved landmarks2\69317.npy with shape (84, 438)
# Processing 69318.mp4...
# Saved landmarks2\69318.npy with shape (89, 438)
# Processing 69319.mp4...
# Saved landmarks2\69319.npy with shape (93, 438)
# Processing 69323.mp4...
# Saved landmarks2\69323.npy with shape (90, 438)
# Processing 69325.mp4...
# Saved landmarks2\69325.npy with shape (94, 438)
# Processing 69326.mp4...
# Saved landmarks2\69326.npy with shape (54, 438)
# Processing 69327.mp4...
# Saved landmarks2\69327.npy with shape (104, 438)
# Processing 69330.mp4...
# Saved landmarks2\69330.npy with shape (81, 438)
# Processing 69331.mp4...
# Saved landmarks2\69331.npy with shape (81, 438)
# Processing 69333.mp4...
# Saved landmarks2\69333.npy with shape (66, 438)
# Processing 69337.mp4...
# Saved landmarks2\69337.npy with shape (89, 438)
# Processing 69338.mp4...
# Saved landmarks2\69338.npy with shape (66, 438)
# Processing 69341.mp4...
# Saved landmarks2\69341.npy with shape (93, 438)
# Processing 69342.mp4...
# Saved landmarks2\69342.npy with shape (74, 438)
# Processing 69343.mp4...
# Saved landmarks2\69343.npy with shape (92, 438)
# Processing 69344.mp4...
# Saved landmarks2\69344.npy with shape (67, 438)
# Processing 69345.mp4...
# Saved landmarks2\69345.npy with shape (67, 438)
# Processing 69347.mp4...
# Saved landmarks2\69347.npy with shape (50, 438)
# Processing 69349.mp4...
# Saved landmarks2\69349.npy with shape (90, 438)
# Processing 69352.mp4...
# Saved landmarks2\69352.npy with shape (91, 438)
# Processing 69353.mp4...
# Saved landmarks2\69353.npy with shape (63, 438)
# Processing 69354.mp4...
# Saved landmarks2\69354.npy with shape (109, 438)
# Processing 69358.mp4...
# Saved landmarks2\69358.npy with shape (94, 438)
# Processing 69359.mp4...
# Saved landmarks2\69359.npy with shape (98, 438)
# Processing 69360.mp4...
# Saved landmarks2\69360.npy with shape (65, 438)
# Processing 69362.mp4...
# Saved landmarks2\69362.npy with shape (56, 438)
# Processing 69364.mp4...
# Saved landmarks2\69364.npy with shape (75, 438)
# Processing 69365.mp4...
# Saved landmarks2\69365.npy with shape (90, 438)
# Processing 69366.mp4...
# Saved landmarks2\69366.npy with shape (65, 438)
# Processing 69368.mp4...
# Saved landmarks2\69368.npy with shape (57, 438)
# Processing 69369.mp4...
# Saved landmarks2\69369.npy with shape (65, 438)
# Processing 69370.mp4...
# Saved landmarks2\69370.npy with shape (90, 438)
# Processing 69375.mp4...
# Saved landmarks2\69375.npy with shape (85, 438)
# Processing 69376.mp4...
# Saved landmarks2\69376.npy with shape (89, 438)
# Processing 69377.mp4...
# Saved landmarks2\69377.npy with shape (67, 438)
# Processing 69380.mp4...
# Saved landmarks2\69380.npy with shape (88, 438)
# Processing 69382.mp4...
# Saved landmarks2\69382.npy with shape (91, 438)
# Processing 69384.mp4...
# Saved landmarks2\69384.npy with shape (92, 438)
# Processing 69386.mp4...
# Saved landmarks2\69386.npy with shape (90, 438)
# Processing 69387.mp4...
# Saved landmarks2\69387.npy with shape (95, 438)
# Processing 69388.mp4...
# Saved landmarks2\69388.npy with shape (87, 438)
# Processing 69389.mp4...
# Saved landmarks2\69389.npy with shape (59, 438)
# Processing 69390.mp4...
# Saved landmarks2\69390.npy with shape (85, 438)
# Processing 69395.mp4...
# Saved landmarks2\69395.npy with shape (76, 438)
# Processing 69396.mp4...
# Saved landmarks2\69396.npy with shape (89, 438)
# Processing 69397.mp4...
# Saved landmarks2\69397.npy with shape (93, 438)
# Processing 69399.mp4...
# Saved landmarks2\69399.npy with shape (76, 438)
# Processing 69401.mp4...
# Saved landmarks2\69401.npy with shape (82, 438)
# Processing 69402.mp4...
# Saved landmarks2\69402.npy with shape (82, 438)
# Processing 69403.mp4...
# Saved landmarks2\69403.npy with shape (96, 438)
# Processing 69404.mp4...
# Saved landmarks2\69404.npy with shape (74, 438)
# Processing 69405.mp4...
# Saved landmarks2\69405.npy with shape (74, 438)
# Processing 69406.mp4...
# Saved landmarks2\69406.npy with shape (80, 438)
# Processing 69407.mp4...
# Saved landmarks2\69407.npy with shape (63, 438)
# Processing 69411.mp4...
# Saved landmarks2\69411.npy with shape (67, 438)
# Processing 69412.mp4...
# Saved landmarks2\69412.npy with shape (90, 438)
# Processing 69413.mp4...
# Saved landmarks2\69413.npy with shape (60, 438)
# Processing 69416.mp4...
# Saved landmarks2\69416.npy with shape (98, 438)
# Processing 69417.mp4...
# Saved landmarks2\69417.npy with shape (103, 438)
# Processing 69418.mp4...
# Saved landmarks2\69418.npy with shape (66, 438)
# Processing 69419.mp4...
# Saved landmarks2\69419.npy with shape (70, 438)
# Processing 69420.mp4...
# Saved landmarks2\69420.npy with shape (61, 438)
# Processing 69421.mp4...
# Saved landmarks2\69421.npy with shape (66, 438)
# Processing 69422.mp4...
# Saved landmarks2\69422.npy with shape (59, 438)
# Processing 69426.mp4...
# Saved landmarks2\69426.npy with shape (73, 438)
# Processing 69429.mp4...
# Saved landmarks2\69429.npy with shape (70, 438)
# Processing 69430.mp4...
# Saved landmarks2\69430.npy with shape (68, 438)
# Processing 69431.mp4...
# Saved landmarks2\69431.npy with shape (75, 438)
# Processing 69432.mp4...
# Saved landmarks2\69432.npy with shape (65, 438)
# Processing 69433.mp4...
# Saved landmarks2\69433.npy with shape (73, 438)
# Processing 69434.mp4...
# Saved landmarks2\69434.npy with shape (86, 438)
# Processing 69437.mp4...
# Saved landmarks2\69437.npy with shape (70, 438)
# Processing 69438.mp4...
# Saved landmarks2\69438.npy with shape (83, 438)
# Processing 69439.mp4...
# Saved landmarks2\69439.npy with shape (119, 438)
# Processing 69440.mp4...
# Saved landmarks2\69440.npy with shape (60, 438)
# Processing 69441.mp4...
# Saved landmarks2\69441.npy with shape (64, 438)
# Processing 69442.mp4...
# Saved landmarks2\69442.npy with shape (60, 438)
# Processing 69445.mp4...
# Saved landmarks2\69445.npy with shape (78, 438)
# Processing 69446.mp4...
# Saved landmarks2\69446.npy with shape (54, 438)
# Processing 69450.mp4...
# Saved landmarks2\69450.npy with shape (76, 438)
# Processing 69451.mp4...
# Saved landmarks2\69451.npy with shape (81, 438)
# Processing 69454.mp4...
# Saved landmarks2\69454.npy with shape (82, 438)
# Processing 69455.mp4...
# Saved landmarks2\69455.npy with shape (69, 438)
# Processing 69459.mp4...
# Saved landmarks2\69459.npy with shape (103, 438)
# Processing 69460.mp4...
# Saved landmarks2\69460.npy with shape (68, 438)
# Processing 69461.mp4...
# Saved landmarks2\69461.npy with shape (85, 438)
# Processing 69463.mp4...
# Saved landmarks2\69463.npy with shape (64, 438)
# Processing 69465.mp4...
# Saved landmarks2\69465.npy with shape (91, 438)
# Processing 69466.mp4...
# Saved landmarks2\69466.npy with shape (74, 438)
# Processing 69467.mp4...
# Saved landmarks2\69467.npy with shape (80, 438)
# Processing 69470.mp4...
# Saved landmarks2\69470.npy with shape (73, 438)
# Processing 69472.mp4...
# Saved landmarks2\69472.npy with shape (90, 438)
# Processing 69474.mp4...
# Saved landmarks2\69474.npy with shape (61, 438)
# Processing 69475.mp4...
# Saved landmarks2\69475.npy with shape (70, 438)
# Processing 69476.mp4...
# Saved landmarks2\69476.npy with shape (117, 438)
# Processing 69477.mp4...
# Saved landmarks2\69477.npy with shape (75, 438)
# Processing 69479.mp4...
# Saved landmarks2\69479.npy with shape (97, 438)
# Processing 69481.mp4...
# Saved landmarks2\69481.npy with shape (105, 438)
# Processing 69482.mp4...
# Saved landmarks2\69482.npy with shape (83, 438)
# Processing 69483.mp4...
# Saved landmarks2\69483.npy with shape (85, 438)
# Processing 69484.mp4...
# Saved landmarks2\69484.npy with shape (85, 438)
# Processing 69485.mp4...
# Saved landmarks2\69485.npy with shape (93, 438)
# Processing 69486.mp4...
# Saved landmarks2\69486.npy with shape (86, 438)
# Processing 69487.mp4...
# Saved landmarks2\69487.npy with shape (79, 438)
# Processing 69489.mp4...
# Saved landmarks2\69489.npy with shape (66, 438)
# Processing 69491.mp4...
# Saved landmarks2\69491.npy with shape (91, 438)
# Processing 69492.mp4...
# Saved landmarks2\69492.npy with shape (74, 438)
# Processing 69493.mp4...
# Saved landmarks2\69493.npy with shape (83, 438)
# Processing 69494.mp4...
# Saved landmarks2\69494.npy with shape (93, 438)
# Processing 69495.mp4...
# Saved landmarks2\69495.npy with shape (77, 438)
# Processing 69497.mp4...
# Saved landmarks2\69497.npy with shape (89, 438)
# Processing 69499.mp4...
# Saved landmarks2\69499.npy with shape (92, 438)
# Processing 69500.mp4...
# Saved landmarks2\69500.npy with shape (91, 438)
# Processing 69501.mp4...
# Saved landmarks2\69501.npy with shape (103, 438)
# Processing 69502.mp4...
# Saved landmarks2\69502.npy with shape (82, 438)
# Processing 69503.mp4...
# Saved landmarks2\69503.npy with shape (100, 438)
# Processing 69504.mp4...
# Saved landmarks2\69504.npy with shape (63, 438)
# Processing 69505.mp4...
# Saved landmarks2\69505.npy with shape (82, 438)
# Processing 69506.mp4...
# Saved landmarks2\69506.npy with shape (89, 438)
# Processing 69507.mp4...
# Saved landmarks2\69507.npy with shape (61, 438)
# Processing 69508.mp4...
# Saved landmarks2\69508.npy with shape (62, 438)
# Processing 69510.mp4...
# Saved landmarks2\69510.npy with shape (84, 438)
# Processing 69511.mp4...
# Saved landmarks2\69511.npy with shape (61, 438)
# Processing 69512.mp4...
# Saved landmarks2\69512.npy with shape (73, 438)
# Processing 69520.mp4...
# Saved landmarks2\69520.npy with shape (61, 438)
# Processing 69521.mp4...
# Saved landmarks2\69521.npy with shape (67, 438)
# Processing 69522.mp4...
# Saved landmarks2\69522.npy with shape (58, 438)
# Processing 69523.mp4...
# Saved landmarks2\69523.npy with shape (75, 438)
# Processing 69524.mp4...
# Saved landmarks2\69524.npy with shape (69, 438)
# Processing 69527.mp4...
# Saved landmarks2\69527.npy with shape (76, 438)
# Processing 69529.mp4...
# Saved landmarks2\69529.npy with shape (60, 438)
# Processing 69530.mp4...
# Saved landmarks2\69530.npy with shape (91, 438)
# Processing 69531.mp4...
# Saved landmarks2\69531.npy with shape (63, 438)
# Processing 69532.mp4...
# Saved landmarks2\69532.npy with shape (80, 438)
# Processing 69533.mp4...
# Saved landmarks2\69533.npy with shape (75, 438)
# Processing 69534.mp4...
# Saved landmarks2\69534.npy with shape (63, 438)
# Processing 69536.mp4...
# Saved landmarks2\69536.npy with shape (86, 438)
# Processing 69538.mp4...
# Saved landmarks2\69538.npy with shape (73, 438)
# Processing 69539.mp4...
# Saved landmarks2\69539.npy with shape (89, 438)
# Processing 69541.mp4...
# Saved landmarks2\69541.npy with shape (93, 438)
# Processing 69542.mp4...
# Saved landmarks2\69542.npy with shape (76, 438)
# Processing 69544.mp4...
# Saved landmarks2\69544.npy with shape (83, 438)
# Processing 69545.mp4...
# Saved landmarks2\69545.npy with shape (65, 438)
# Processing 69546.mp4...
# Saved landmarks2\69546.npy with shape (72, 438)
# Processing 69547.mp4...
# Saved landmarks2\69547.npy with shape (67, 438)
# All videos processed and converted successfully!
