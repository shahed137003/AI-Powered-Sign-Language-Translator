# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# =========================
# CONFIG
# =========================
DATA_DIR = Path(r"E:\ASL_Citizen\NEW\Top_Classes_Landmarks_Preprocessed")
BATCH_SIZE = 32
EPOCHS = 350
LR = 2e-4
PATIENCE = 40              # increased
MIN_DELTA = 0.001          # require meaningful improvement
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
MIXUP_ALPHA = 0.3

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# =========================
# LOAD METADATA
# =========================
metadata = pd.read_csv(DATA_DIR / "metadata.csv")

counts = metadata['word'].value_counts()
valid = counts[counts >= 2].index
metadata = metadata[metadata['word'].isin(valid)]

le = LabelEncoder()
metadata["label"] = le.fit_transform(metadata["word"])
num_classes = len(le.classes_)

print("Samples:", len(metadata))
print("Classes:", num_classes)

# =========================
# SPLITS
# =========================
train_df, test_df = train_test_split(
    metadata, test_size=0.15,
    stratify=metadata["label"],
    random_state=SEED
)

train_df, val_df = train_test_split(
    train_df, test_size=0.15,
    stratify=train_df["label"],
    random_state=SEED
)

# =========================
# DATASET
# =========================
class ASLDataset(Dataset):
    def __init__(self, df, train=True):
        self.df = df.reset_index(drop=True)
        self.train = train

    def augment(self, x):

        if random.random() < 0.5:
            shift = random.randint(-5,5)
            x = np.roll(x, shift, axis=0)

        if random.random() < 0.5:
            mask = np.random.rand(x.shape[0]) > 0.1
            x = x * mask[:,None]

        if random.random() < 0.5:
            x += np.random.normal(0,0.015,x.shape)

        return x

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        x = np.load(row["processed_file"])
        y = row["label"]

        if self.train:
            x = self.augment(x)

        return torch.tensor(x,dtype=torch.float32), torch.tensor(y)

train_loader = DataLoader(ASLDataset(train_df,True), batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(ASLDataset(val_df,False), batch_size=BATCH_SIZE)
test_loader  = DataLoader(ASLDataset(test_df,False), batch_size=BATCH_SIZE)

# =========================
# CLASS WEIGHTS
# =========================
class_counts = train_df["label"].value_counts().sort_index().values
weights = torch.tensor(1.0/class_counts,dtype=torch.float32).to(DEVICE)

criterion = nn.CrossEntropyLoss(weight=weights,label_smoothing=0.1)

# =========================
# MODEL
# =========================
class ASLModel(nn.Module):
    def __init__(self,input_dim=438,num_classes=147):
        super().__init__()

        self.conv1 = nn.Conv1d(input_dim,192,5,padding=2)
        self.conv2 = nn.Conv1d(192,192,3,padding=1)
        self.bn1 = nn.BatchNorm1d(192)
        self.bn2 = nn.BatchNorm1d(192)

        self.dropout = nn.Dropout(0.5)

        self.lstm = nn.LSTM(
            192,192,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        self.attention = nn.Sequential(
            nn.Linear(384,128),
            nn.Tanh(),
            nn.Linear(128,1)
        )

        self.fc = nn.Sequential(
            nn.Linear(384,192),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(192,num_classes)
        )

    def forward(self,x):

        x = x.transpose(1,2)
        x = self.dropout(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout(F.relu(self.bn2(self.conv2(x))))
        x = x.transpose(1,2)

        lstm_out,_ = self.lstm(x)

        attn = self.attention(lstm_out)
        weights = torch.softmax(attn,dim=1)
        pooled = torch.sum(weights*lstm_out,dim=1)

        return self.fc(pooled)

model = ASLModel(num_classes=num_classes).to(DEVICE)

# =========================
# OPTIMIZER & SCHEDULER
# =========================
optimizer = torch.optim.AdamW(model.parameters(),lr=LR,weight_decay=1e-3)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=25,
    T_mult=2,
    eta_min=1e-6
)

# =========================
# TRAIN LOOP
# =========================
best_val_acc = 0
patience_counter = 0

for epoch in range(EPOCHS):

    model.train()
    train_loss=0
    train_correct=0
    total=0

    for x,y in train_loader:

        x,y=x.to(DEVICE),y.to(DEVICE)

        lam = np.random.beta(MIXUP_ALPHA,MIXUP_ALPHA)
        perm = torch.randperm(x.size(0)).to(DEVICE)
        x_mix = lam*x + (1-lam)*x[perm]
        y_a,y_b=y,y[perm]

        optimizer.zero_grad()
        outputs=model(x_mix)

        loss = lam*criterion(outputs,y_a)+(1-lam)*criterion(outputs,y_b)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(),1.0)
        optimizer.step()

        train_loss+=loss.item()*y.size(0)
        preds = outputs.argmax(1)

        train_correct += (
            lam * (preds == y_a).sum().item() +
            (1 - lam) * (preds == y_b).sum().item()
        )

        total+=y.size(0)

    train_loss/=total
    train_acc=train_correct/total

    # VALIDATION
    model.eval()
    val_loss=0
    val_correct=0
    total_val=0

    with torch.no_grad():
        for x,y in val_loader:
            x,y=x.to(DEVICE),y.to(DEVICE)
            outputs=model(x)
            loss=criterion(outputs,y)

            val_loss+=loss.item()*y.size(0)
            preds=outputs.argmax(1)
            val_correct+=(preds==y).sum().item()
            total_val+=y.size(0)

    val_loss/=total_val
    val_acc=val_correct/total_val

    scheduler.step(epoch + val_loss)

    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    print(f"Train Loss {train_loss:.4f} | Acc {train_acc:.4f}")
    print(f"Val   Loss {val_loss:.4f} | Acc {val_acc:.4f}")

    if val_acc > best_val_acc + MIN_DELTA:
        best_val_acc = val_acc
        patience_counter = 0

        torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
        }, "best_asl_model.pth")

        print("Saved best model")
    else:
        patience_counter+=1
        if patience_counter>=PATIENCE:
            print("Early stopping")
            break

# =========================
# TEST
# =========================
checkpoint = torch.load("best_asl_model.pth")
model.load_state_dict(checkpoint['model_state_dict'])

model.eval()
correct=0
total=0

with torch.no_grad():
    for x,y in test_loader:
        x,y=x.to(DEVICE),y.to(DEVICE)
        preds=model(x).argmax(1)
        correct+=(preds==y).sum().item()
        total+=y.size(0)

print("\nFINAL TEST ACC:",correct/total)
# Out:
# Samples: 5844
# Classes: 146
#
# Epoch 1/350
# Train Loss 5.0428 | Acc 0.0074
# Val   Loss 4.9434 | Acc 0.0161
# Saved best model
#
# Epoch 2/350
# Train Loss 4.8120 | Acc 0.0258
# Val   Loss 4.4160 | Acc 0.0590
# Saved best model
#
# Epoch 3/350
# Train Loss 4.5291 | Acc 0.0465
# Val   Loss 4.1186 | Acc 0.0898
# Saved best model
#
# Epoch 4/350
# Train Loss 4.3436 | Acc 0.0606
# Val   Loss 3.9826 | Acc 0.1032
# Saved best model
#
# Epoch 5/350
# Train Loss 4.2697 | Acc 0.0777
# Val   Loss 3.8651 | Acc 0.1367
# Saved best model
#
# Epoch 6/350
# Train Loss 4.1983 | Acc 0.0888
# Val   Loss 3.7266 | Acc 0.1930
# Saved best model
#
# Epoch 7/350
# Train Loss 4.1154 | Acc 0.1146
# Val   Loss 3.6173 | Acc 0.2306
# Saved best model
#
# Epoch 8/350
# Train Loss 4.0494 | Acc 0.1249
# Val   Loss 3.5445 | Acc 0.2359
# Saved best model
#
# Epoch 9/350
# Train Loss 3.9392 | Acc 0.1467
# Val   Loss 3.4746 | Acc 0.2520
# Saved best model
#
# Epoch 10/350
# Train Loss 3.8810 | Acc 0.1590
# Val   Loss 3.3728 | Acc 0.2748
# Saved best model
#
# Epoch 11/350
# Train Loss 3.8742 | Acc 0.1738
# Val   Loss 3.3424 | Acc 0.2976
# Saved best model
#
# Epoch 12/350
# Train Loss 3.7803 | Acc 0.1901
# Val   Loss 3.2267 | Acc 0.3338
# Saved best model
#
# Epoch 13/350
# Train Loss 3.7341 | Acc 0.2111
# Val   Loss 3.1674 | Acc 0.3592
# Saved best model
#
# Epoch 14/350
# Train Loss 3.6219 | Acc 0.2358
# Val   Loss 3.1214 | Acc 0.3767
# Saved best model
#
# Epoch 15/350
# Train Loss 3.5921 | Acc 0.2483
# Val   Loss 3.0553 | Acc 0.4008
# Saved best model
#
# Epoch 16/350
# Train Loss 3.5322 | Acc 0.2686
# Val   Loss 3.0273 | Acc 0.4129
# Saved best model
#
# Epoch 17/350
# Train Loss 3.4936 | Acc 0.2753
# Val   Loss 3.0038 | Acc 0.4236
# Saved best model
#
# Epoch 18/350
# Train Loss 3.5683 | Acc 0.2710
# Val   Loss 2.9798 | Acc 0.4196
#
# Epoch 19/350
# Train Loss 3.4844 | Acc 0.2778
# Val   Loss 2.9664 | Acc 0.4263
# Saved best model
#
# Epoch 20/350
# Train Loss 3.4703 | Acc 0.2820
# Val   Loss 2.9543 | Acc 0.4357
# Saved best model
#
# Epoch 21/350
# Train Loss 3.4738 | Acc 0.2893
# Val   Loss 2.9395 | Acc 0.4424
# Saved best model
#
# Epoch 22/350
# Train Loss 3.4005 | Acc 0.2978
# Val   Loss 2.9386 | Acc 0.4383
#
# Epoch 23/350
# Train Loss 3.5105 | Acc 0.2826
# Val   Loss 2.9358 | Acc 0.4477
# Saved best model
#
# Epoch 24/350
# Train Loss 3.4969 | Acc 0.2890
# Val   Loss 2.9390 | Acc 0.4383
#
# Epoch 25/350
# Train Loss 3.5598 | Acc 0.2629
# Val   Loss 2.9742 | Acc 0.4102
#
# Epoch 26/350
# Train Loss 3.4539 | Acc 0.2860
# Val   Loss 2.8875 | Acc 0.4249
#
# Epoch 27/350
# Train Loss 3.4097 | Acc 0.3078
# Val   Loss 2.8526 | Acc 0.4303
#
# Epoch 28/350
# Train Loss 3.2743 | Acc 0.3401
# Val   Loss 2.7049 | Acc 0.4692
# Saved best model
#
# Epoch 29/350
# Train Loss 3.3336 | Acc 0.3354
# Val   Loss 2.7209 | Acc 0.4531
#
# Epoch 30/350
# Train Loss 3.3138 | Acc 0.3458
# Val   Loss 2.5616 | Acc 0.5013
# Saved best model
#
# Epoch 31/350
# Train Loss 3.1588 | Acc 0.3944
# Val   Loss 2.5297 | Acc 0.5268
# Saved best model
#
# Epoch 32/350
# Train Loss 3.0660 | Acc 0.4239
# Val   Loss 2.5351 | Acc 0.5013
#
# Epoch 33/350
# Train Loss 3.0845 | Acc 0.4187
# Val   Loss 2.4567 | Acc 0.5536
# Saved best model
#
# Epoch 34/350
# Train Loss 3.0691 | Acc 0.4268
# Val   Loss 2.3769 | Acc 0.5590
# Saved best model
#
# Epoch 35/350
# Train Loss 2.9658 | Acc 0.4580
# Val   Loss 2.3286 | Acc 0.5523
#
# Epoch 36/350
# Train Loss 3.0005 | Acc 0.4537
# Val   Loss 2.3554 | Acc 0.5697
# Saved best model
#
# Epoch 37/350
# Train Loss 2.9006 | Acc 0.4962
# Val   Loss 2.2600 | Acc 0.5643
#
# Epoch 38/350
# Train Loss 2.7571 | Acc 0.5252
# Val   Loss 2.2778 | Acc 0.5550
#
# Epoch 39/350
# Train Loss 2.8482 | Acc 0.5105
# Val   Loss 2.1907 | Acc 0.6019
# Saved best model
#
# Epoch 40/350
# Train Loss 2.6594 | Acc 0.5541
# Val   Loss 2.1966 | Acc 0.5845
#
# Epoch 41/350
# Train Loss 2.7731 | Acc 0.5270
# Val   Loss 2.1708 | Acc 0.5979
#
# Epoch 42/350
# Train Loss 2.7923 | Acc 0.5283
# Val   Loss 2.0758 | Acc 0.6488
# Saved best model
#
# Epoch 43/350
# Train Loss 2.7580 | Acc 0.5457
# Val   Loss 2.0773 | Acc 0.6461
#
# Epoch 44/350
# Train Loss 2.6038 | Acc 0.5779
# Val   Loss 2.0279 | Acc 0.6568
# Saved best model
#
# Epoch 45/350
# Train Loss 2.6048 | Acc 0.5737
# Val   Loss 2.1519 | Acc 0.5804
#
# Epoch 46/350
# Train Loss 2.6431 | Acc 0.5793
# Val   Loss 1.9810 | Acc 0.6542
#
# Epoch 47/350
# Train Loss 2.5862 | Acc 0.5858
# Val   Loss 1.9560 | Acc 0.6769
# Saved best model
#
# Epoch 48/350
# Train Loss 2.4955 | Acc 0.6171
# Val   Loss 1.9419 | Acc 0.6769
#
# Epoch 49/350
# Train Loss 2.6838 | Acc 0.5780
# Val   Loss 1.9057 | Acc 0.6890
# Saved best model
#
# Epoch 50/350
# Train Loss 2.4728 | Acc 0.6323
# Val   Loss 1.8859 | Acc 0.6877
#
# Epoch 51/350
# Train Loss 2.5373 | Acc 0.6153
# Val   Loss 1.8712 | Acc 0.7011
# Saved best model
#
# Epoch 52/350
# Train Loss 2.4597 | Acc 0.6248
# Val   Loss 1.8732 | Acc 0.6997
#
# Epoch 53/350
# Train Loss 2.4294 | Acc 0.6469
# Val   Loss 1.8598 | Acc 0.7051
# Saved best model
#
# Epoch 54/350
# Train Loss 2.5362 | Acc 0.6296
# Val   Loss 1.8591 | Acc 0.6917
#
# Epoch 55/350
# Train Loss 2.3719 | Acc 0.6637
# Val   Loss 1.8246 | Acc 0.7185
# Saved best model
#
# Epoch 56/350
# Train Loss 2.5050 | Acc 0.6455
# Val   Loss 1.8347 | Acc 0.7091
#
# Epoch 57/350
# Train Loss 2.2791 | Acc 0.6840
# Val   Loss 1.7922 | Acc 0.7332
# Saved best model
#
# Epoch 58/350
# Train Loss 2.4059 | Acc 0.6668
# Val   Loss 1.7998 | Acc 0.7172
#
# Epoch 59/350
# Train Loss 2.3873 | Acc 0.6645
# Val   Loss 1.7886 | Acc 0.7265
#
# Epoch 60/350
# Train Loss 2.4436 | Acc 0.6575
# Val   Loss 1.7780 | Acc 0.7332
#
# Epoch 61/350
# Train Loss 2.4284 | Acc 0.6527
# Val   Loss 1.7760 | Acc 0.7319
#
# Epoch 62/350
# Train Loss 2.4225 | Acc 0.6593
# Val   Loss 1.7664 | Acc 0.7386
# Saved best model
#
# Epoch 63/350
# Train Loss 2.2692 | Acc 0.7059
# Val   Loss 1.7605 | Acc 0.7413
# Saved best model
#
# Epoch 64/350
# Train Loss 2.4045 | Acc 0.6715
# Val   Loss 1.7556 | Acc 0.7332
#
# Epoch 65/350
# Train Loss 2.4187 | Acc 0.6652
# Val   Loss 1.7510 | Acc 0.7413
#
# Epoch 66/350
# Train Loss 2.4034 | Acc 0.6608
# Val   Loss 1.7514 | Acc 0.7306
#
# Epoch 67/350
# Train Loss 2.4148 | Acc 0.6693
# Val   Loss 1.7554 | Acc 0.7413
#
# Epoch 68/350
# Train Loss 2.3937 | Acc 0.6792
# Val   Loss 1.7470 | Acc 0.7413
#
# Epoch 69/350
# Train Loss 2.4940 | Acc 0.6590
# Val   Loss 1.7449 | Acc 0.7426
# Saved best model
#
# Epoch 70/350
# Train Loss 2.3621 | Acc 0.6805
# Val   Loss 1.7442 | Acc 0.7373
#
# Epoch 71/350
# Train Loss 2.4517 | Acc 0.6610
# Val   Loss 1.7469 | Acc 0.7373
#
# Epoch 72/350
# Train Loss 2.3706 | Acc 0.6765
# Val   Loss 1.7489 | Acc 0.7373
#
# Epoch 73/350
# Train Loss 2.2644 | Acc 0.7059
# Val   Loss 1.7468 | Acc 0.7413
#
# Epoch 74/350
# Train Loss 2.2667 | Acc 0.7032
# Val   Loss 1.7382 | Acc 0.7453
# Saved best model
#
# Epoch 75/350
# Train Loss 2.3265 | Acc 0.6911
# Val   Loss 1.7449 | Acc 0.7426
#
# Epoch 76/350
# Train Loss 2.5176 | Acc 0.6274
# Val   Loss 1.8509 | Acc 0.7024
#
# Epoch 77/350
# Train Loss 2.5268 | Acc 0.6281
# Val   Loss 1.9117 | Acc 0.6877
#
# Epoch 78/350
# Train Loss 2.3915 | Acc 0.6591
# Val   Loss 1.8633 | Acc 0.7051
#
# Epoch 79/350
# Train Loss 2.4494 | Acc 0.6512
# Val   Loss 1.8407 | Acc 0.7118
#
# Epoch 80/350
# Train Loss 2.3662 | Acc 0.6636
# Val   Loss 1.8751 | Acc 0.6756
#
# Epoch 81/350
# Train Loss 2.4436 | Acc 0.6497
# Val   Loss 1.8609 | Acc 0.7051
#
# Epoch 82/350
# Train Loss 2.2940 | Acc 0.6871
# Val   Loss 1.8119 | Acc 0.7011
#
# Epoch 83/350
# Train Loss 2.4962 | Acc 0.6337
# Val   Loss 1.8706 | Acc 0.6810
#
# Epoch 84/350
# Train Loss 2.3135 | Acc 0.6717
# Val   Loss 1.8179 | Acc 0.7212
#
# Epoch 85/350
# Train Loss 2.2753 | Acc 0.6917
# Val   Loss 1.8029 | Acc 0.7172
#
# Epoch 86/350
# Train Loss 2.4519 | Acc 0.6507
# Val   Loss 1.7530 | Acc 0.7440
#
# Epoch 87/350
# Train Loss 2.2579 | Acc 0.6997
# Val   Loss 1.7084 | Acc 0.7440
#
# Epoch 88/350
# Train Loss 2.2735 | Acc 0.7045
# Val   Loss 1.7725 | Acc 0.7426
#
# Epoch 89/350
# Train Loss 2.3310 | Acc 0.6854
# Val   Loss 1.7169 | Acc 0.7373
#
# Epoch 90/350
# Train Loss 2.2715 | Acc 0.6908
# Val   Loss 1.6738 | Acc 0.7493
# Saved best model
#
# Epoch 91/350
# Train Loss 2.2484 | Acc 0.7109
# Val   Loss 1.6928 | Acc 0.7694
# Saved best model
#
# Epoch 92/350
# Train Loss 2.2062 | Acc 0.7183
# Val   Loss 1.7242 | Acc 0.7399
#
# Epoch 93/350
# Train Loss 2.1721 | Acc 0.7271
# Val   Loss 1.6872 | Acc 0.7694
#
# Epoch 94/350
# Train Loss 2.2093 | Acc 0.7192
# Val   Loss 1.7486 | Acc 0.7359
#
# Epoch 95/350
# Train Loss 2.2222 | Acc 0.7185
# Val   Loss 1.6883 | Acc 0.7466
#
# Epoch 96/350
# Train Loss 2.2007 | Acc 0.7251
# Val   Loss 1.7359 | Acc 0.7493
#
# Epoch 97/350
# Train Loss 2.1860 | Acc 0.7323
# Val   Loss 1.6638 | Acc 0.7694
#
# Epoch 98/350
# Train Loss 2.3349 | Acc 0.6981
# Val   Loss 1.7120 | Acc 0.7534
#
# Epoch 99/350
# Train Loss 2.1508 | Acc 0.7334
# Val   Loss 1.7357 | Acc 0.7466
#
# Epoch 100/350
# Train Loss 2.1695 | Acc 0.7406
# Val   Loss 1.6355 | Acc 0.7694
#
# Epoch 101/350
# Train Loss 2.0747 | Acc 0.7535
# Val   Loss 1.6454 | Acc 0.7735
# Saved best model
#
# Epoch 102/350
# Train Loss 2.2514 | Acc 0.7212
# Val   Loss 1.6333 | Acc 0.7614
#
# Epoch 103/350
# Train Loss 2.1839 | Acc 0.7328
# Val   Loss 1.6500 | Acc 0.7614
#
# Epoch 104/350
# Train Loss 2.1567 | Acc 0.7450
# Val   Loss 1.6187 | Acc 0.7855
# Saved best model
#
# Epoch 105/350
# Train Loss 2.0813 | Acc 0.7629
# Val   Loss 1.6214 | Acc 0.7976
# Saved best model
#
# Epoch 106/350
# Train Loss 2.0905 | Acc 0.7651
# Val   Loss 1.6199 | Acc 0.7855
#
# Epoch 107/350
# Train Loss 1.9718 | Acc 0.7909
# Val   Loss 1.5843 | Acc 0.8056
# Saved best model
#
# Epoch 108/350
# Train Loss 2.0657 | Acc 0.7711
# Val   Loss 1.5851 | Acc 0.8097
# Saved best model
#
# Epoch 109/350
# Train Loss 2.1257 | Acc 0.7486
# Val   Loss 1.5958 | Acc 0.7936
#
# Epoch 110/350
# Train Loss 2.1792 | Acc 0.7393
# Val   Loss 1.6432 | Acc 0.7788
#
# Epoch 111/350
# Train Loss 2.2325 | Acc 0.7276
# Val   Loss 1.6317 | Acc 0.7654
#
# Epoch 112/350
# Train Loss 2.1428 | Acc 0.7511
# Val   Loss 1.6442 | Acc 0.7681
#
# Epoch 113/350
# Train Loss 2.0229 | Acc 0.7811
# Val   Loss 1.5793 | Acc 0.7962
#
# Epoch 114/350
# Train Loss 2.0652 | Acc 0.7675
# Val   Loss 1.6237 | Acc 0.7828
#
# Epoch 115/350
# Train Loss 2.1064 | Acc 0.7649
# Val   Loss 1.5877 | Acc 0.8003
#
# Epoch 116/350
# Train Loss 2.1108 | Acc 0.7630
# Val   Loss 1.5932 | Acc 0.8016
#
# Epoch 117/350
# Train Loss 1.9715 | Acc 0.7926
# Val   Loss 1.5424 | Acc 0.8056
#
# Epoch 118/350
# Train Loss 2.0267 | Acc 0.7786
# Val   Loss 1.5661 | Acc 0.8083
#
# Epoch 119/350
# Train Loss 2.0713 | Acc 0.7759
# Val   Loss 1.5731 | Acc 0.7936
#
# Epoch 120/350
# Train Loss 2.0725 | Acc 0.7702
# Val   Loss 1.5363 | Acc 0.8097
#
# Epoch 121/350
# Train Loss 2.0569 | Acc 0.7764
# Val   Loss 1.5478 | Acc 0.8083
#
# Epoch 122/350
# Train Loss 2.1113 | Acc 0.7605
# Val   Loss 1.5707 | Acc 0.8003
#
# Epoch 123/350
# Train Loss 1.9971 | Acc 0.7957
# Val   Loss 1.5735 | Acc 0.7882
#
# Epoch 124/350
# Train Loss 2.0229 | Acc 0.7912
# Val   Loss 1.5396 | Acc 0.8150
# Saved best model
#
# Epoch 125/350
# Train Loss 2.0503 | Acc 0.7830
# Val   Loss 1.5393 | Acc 0.8150
#
# Epoch 126/350
# Train Loss 1.9771 | Acc 0.7960
# Val   Loss 1.5165 | Acc 0.8324
# Saved best model
#
# Epoch 127/350
# Train Loss 1.9603 | Acc 0.8037
# Val   Loss 1.5424 | Acc 0.8150
#
# Epoch 128/350
# Train Loss 2.2253 | Acc 0.7367
# Val   Loss 1.5521 | Acc 0.8070
#
# Epoch 129/350
# Train Loss 2.0258 | Acc 0.7863
# Val   Loss 1.5386 | Acc 0.8137
#
# Epoch 130/350
# Train Loss 2.0470 | Acc 0.7793
# Val   Loss 1.5242 | Acc 0.8177
#
# Epoch 131/350
# Train Loss 2.0129 | Acc 0.7864
# Val   Loss 1.5479 | Acc 0.8164
#
# Epoch 132/350
# Train Loss 1.9868 | Acc 0.7989
# Val   Loss 1.5249 | Acc 0.8204
#
# Epoch 133/350
# Train Loss 1.9366 | Acc 0.8083
# Val   Loss 1.5223 | Acc 0.8070
#
# Epoch 134/350
# Train Loss 1.9172 | Acc 0.8239
# Val   Loss 1.5258 | Acc 0.8164
#
# Epoch 135/350
# Train Loss 1.8709 | Acc 0.8350
# Val   Loss 1.5057 | Acc 0.8244
#
# Epoch 136/350
# Train Loss 2.0953 | Acc 0.7666
# Val   Loss 1.5260 | Acc 0.8083
#
# Epoch 137/350
# Train Loss 1.9901 | Acc 0.7976
# Val   Loss 1.4962 | Acc 0.8324
#
# Epoch 138/350
# Train Loss 2.0890 | Acc 0.7711
# Val   Loss 1.5170 | Acc 0.8123
#
# Epoch 139/350
# Train Loss 1.9843 | Acc 0.8040
# Val   Loss 1.5210 | Acc 0.8271
#
# Epoch 140/350
# Train Loss 2.0284 | Acc 0.7801
# Val   Loss 1.5014 | Acc 0.8284
#
# Epoch 141/350
# Train Loss 1.9709 | Acc 0.8094
# Val   Loss 1.5023 | Acc 0.8298
#
# Epoch 142/350
# Train Loss 1.9792 | Acc 0.7959
# Val   Loss 1.5108 | Acc 0.8231
#
# Epoch 143/350
# Train Loss 2.0612 | Acc 0.7768
# Val   Loss 1.5095 | Acc 0.8271
#
# Epoch 144/350
# Train Loss 1.9600 | Acc 0.8100
# Val   Loss 1.5014 | Acc 0.8164
#
# Epoch 145/350
# Train Loss 1.9500 | Acc 0.8149
# Val   Loss 1.5142 | Acc 0.8190
#
# Epoch 146/350
# Train Loss 1.8178 | Acc 0.8414
# Val   Loss 1.4991 | Acc 0.8271
#
# Epoch 147/350
# Train Loss 2.0076 | Acc 0.7910
# Val   Loss 1.4896 | Acc 0.8271
#
# Epoch 148/350
# Train Loss 1.8318 | Acc 0.8395
# Val   Loss 1.4972 | Acc 0.8271
#
# Epoch 149/350
# Train Loss 2.0954 | Acc 0.7776
# Val   Loss 1.4951 | Acc 0.8257
#
# Epoch 150/350
# Train Loss 1.9485 | Acc 0.8113
# Val   Loss 1.4945 | Acc 0.8257
#
# Epoch 151/350
# Train Loss 2.0192 | Acc 0.7982
# Val   Loss 1.4913 | Acc 0.8257
#
# Epoch 152/350
# Train Loss 1.8858 | Acc 0.8210
# Val   Loss 1.4864 | Acc 0.8351
# Saved best model
#
# Epoch 153/350
# Train Loss 2.0112 | Acc 0.7986
# Val   Loss 1.4917 | Acc 0.8298
#
# Epoch 154/350
# Train Loss 1.9167 | Acc 0.8185
# Val   Loss 1.4957 | Acc 0.8284
#
# Epoch 155/350
# Train Loss 1.9686 | Acc 0.8024
# Val   Loss 1.4889 | Acc 0.8324
#
# Epoch 156/350
# Train Loss 1.8855 | Acc 0.8243
# Val   Loss 1.4891 | Acc 0.8311
#
# Epoch 157/350
# Train Loss 1.9531 | Acc 0.8021
# Val   Loss 1.4939 | Acc 0.8204
#
# Epoch 158/350
# Train Loss 1.9347 | Acc 0.8086
# Val   Loss 1.4978 | Acc 0.8257
#
# Epoch 159/350
# Train Loss 2.0241 | Acc 0.7849
# Val   Loss 1.4861 | Acc 0.8257
#
# Epoch 160/350
# Train Loss 2.0339 | Acc 0.7936
# Val   Loss 1.4955 | Acc 0.8217
#
# Epoch 161/350
# Train Loss 1.9639 | Acc 0.8077
# Val   Loss 1.4886 | Acc 0.8298
#
# Epoch 162/350
# Train Loss 1.7854 | Acc 0.8516
# Val   Loss 1.4854 | Acc 0.8338
#
# Epoch 163/350
# Train Loss 1.8877 | Acc 0.8234
# Val   Loss 1.4880 | Acc 0.8271
#
# Epoch 164/350
# Train Loss 1.7550 | Acc 0.8581
# Val   Loss 1.4844 | Acc 0.8298
#
# Epoch 165/350
# Train Loss 1.9475 | Acc 0.8158
# Val   Loss 1.4874 | Acc 0.8271
#
# Epoch 166/350
# Train Loss 1.8414 | Acc 0.8373
# Val   Loss 1.4857 | Acc 0.8257
#
# Epoch 167/350
# Train Loss 1.9856 | Acc 0.7959
# Val   Loss 1.4840 | Acc 0.8338
#
# Epoch 168/350
# Train Loss 1.8438 | Acc 0.8340
# Val   Loss 1.4865 | Acc 0.8284
#
# Epoch 169/350
# Train Loss 1.7893 | Acc 0.8512
# Val   Loss 1.4812 | Acc 0.8324
#
# Epoch 170/350
# Train Loss 1.8687 | Acc 0.8188
# Val   Loss 1.4852 | Acc 0.8284
#
# Epoch 171/350
# Train Loss 1.8171 | Acc 0.8316
# Val   Loss 1.4843 | Acc 0.8284
#
# Epoch 172/350
# Train Loss 1.9550 | Acc 0.8186
# Val   Loss 1.4851 | Acc 0.8284
#
# Epoch 173/350
# Train Loss 1.8982 | Acc 0.8198
# Val   Loss 1.4867 | Acc 0.8284
#
# Epoch 174/350
# Train Loss 1.9384 | Acc 0.8151
# Val   Loss 1.4902 | Acc 0.8284
#
# Epoch 175/350
# Train Loss 2.0356 | Acc 0.7923
# Val   Loss 1.4876 | Acc 0.8257
#
# Epoch 176/350
# Train Loss 2.0816 | Acc 0.7734
# Val   Loss 1.6244 | Acc 0.7936
#
# Epoch 177/350
# Train Loss 1.9710 | Acc 0.7994
# Val   Loss 1.5890 | Acc 0.7962
#
# Epoch 178/350
# Train Loss 2.0598 | Acc 0.7698
# Val   Loss 1.6275 | Acc 0.7802
#
# Epoch 179/350
# Train Loss 2.0096 | Acc 0.7894
# Val   Loss 1.5939 | Acc 0.8056
#
# Epoch 180/350
# Train Loss 2.1041 | Acc 0.7657
# Val   Loss 1.5945 | Acc 0.7949
#
# Epoch 181/350
# Train Loss 2.0130 | Acc 0.7860
# Val   Loss 1.5967 | Acc 0.7909
#
# Epoch 182/350
# Train Loss 2.0934 | Acc 0.7628
# Val   Loss 1.5787 | Acc 0.7936
#
# Epoch 183/350
# Train Loss 1.9816 | Acc 0.7940
# Val   Loss 1.5956 | Acc 0.7855
#
# Epoch 184/350
# Train Loss 2.0414 | Acc 0.7774
# Val   Loss 1.5225 | Acc 0.8137
#
# Epoch 185/350
# Train Loss 2.0158 | Acc 0.7850
# Val   Loss 1.5643 | Acc 0.7936
#
# Epoch 186/350
# Train Loss 2.1143 | Acc 0.7610
# Val   Loss 1.5656 | Acc 0.8029
#
# Epoch 187/350
# Train Loss 1.9511 | Acc 0.7945
# Val   Loss 1.5308 | Acc 0.8164
#
# Epoch 188/350
# Train Loss 2.0408 | Acc 0.7837
# Val   Loss 1.6665 | Acc 0.7574
#
# Epoch 189/350
# Train Loss 2.0551 | Acc 0.7830
# Val   Loss 1.5540 | Acc 0.8137
#
# Epoch 190/350
# Train Loss 1.9467 | Acc 0.8063
# Val   Loss 1.5595 | Acc 0.8097
#
# Epoch 191/350
# Train Loss 1.9581 | Acc 0.8055
# Val   Loss 1.5669 | Acc 0.8029
#
# Epoch 192/350
# Train Loss 2.0877 | Acc 0.7720
# Val   Loss 1.6200 | Acc 0.7989
# Early stopping
#
# FINAL TEST ACC: 0.8449258836944128
