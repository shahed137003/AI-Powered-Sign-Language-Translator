# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('gloss_counts.csv')
df1 = df1[['gloss']].rename(columns={'gloss': 'Gloss'})
df1.head()
# Out:
#         Gloss
# 0    1 DOLLAR
# 1   5 DOLLARS
# 2      8 HOUR
# 3    9 OCLOCK
# 4  A LINE BOB

# %%
len(df1)
# Out:
# 147

# %%
top_250_df=pd.read_csv('asl_top_250_essential.csv')
top_250_df.head()
# Out:
#    Rank Gloss
# 0     1    ME
# 1     2   YOU
# 2     3    HE
# 3     4   SHE
# 4     5    IT

# %%
df_103_research=pd.read_csv('sorted_mean_rating.csv')
df_103_research=df_103_research[0:103]
df_103_research.head()
# Out:
#    Unnamed: 0      Sign  Mean Rating  Median Rating Median RT  Mean Log (RT)
# 0           0      Time         6.42              7     2,335           7.82
# 1           1      Home         6.37              7     2,451           7.92
# 2           2     Night         6.34              7     2,359           7.87
# 3           3  Internet         6.24              7     2,628           7.89
# 4           4     Drink         6.22              7     2,543           7.87

# %%
top_250_df = top_250_df[['Gloss']]
top_250_df.head()
# Out:
#   Gloss
# 0    ME
# 1   YOU
# 2    HE
# 3   SHE
# 4    IT

# %%
len(top_250_df)
# Out:
# 250

# %%
df_103_research = df_103_research[['Sign']].rename(columns={'Sign': 'Gloss'})
df_103_research.head()
# Out:
#       Gloss
# 0      Time
# 1      Home
# 2     Night
# 3  Internet
# 4     Drink

# %%
len(df_103_research)
# Out:
# 103

# %%
df1[df1['Gloss'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Gloss]
# Index: []

# %%
top_250_df[top_250_df['Gloss'].duplicated()]
# Out:
#     Gloss
# 136  SLOW

# %%
top_250_df = top_250_df.drop_duplicates(subset=['Gloss'])
top_250_df[top_250_df['Gloss'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Gloss]
# Index: []

# %%
len(top_250_df)
# Out:
# 249

# %%
df = pd.read_csv('sorted_mean_rating.csv')
word_103 = df.loc[[103], ['Sign']].rename(columns={'Sign': 'Gloss'})
top_250_df = pd.concat([top_250_df, word_103], ignore_index=True)
top_250_df.head()
# Out:
#   Gloss
# 0    ME
# 1   YOU
# 2    HE
# 3   SHE
# 4    IT

# %%
len(top_250_df)
# Out:
# 250

# %%
df_103_research[df_103_research['Gloss'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Gloss]
# Index: []

# %%
common = (
    set(top_250_df['Gloss'].str.strip().str.lower()) &
    set(df_103_research['Gloss'].str.strip().str.lower())
)

len(common)
# Out:
# 51

# %%
common = set(
    top_250_df['Gloss'].str.strip().str.lower()
) & set(
    df_103_research['Gloss'].str.strip().str.lower()
)

top_250_df = top_250_df[
    ~top_250_df['Gloss'].str.strip().str.lower().isin(common)
]

top_250_df.head()
# Out:
#   Gloss
# 1   YOU
# 2    HE
# 3   SHE
# 4    IT
# 5    WE

# %%
len(top_250_df)
# Out:
# 199

# %%
df_ref = pd.read_csv('sorted_mean_rating.csv')
extra_51_words = df_ref.iloc[104:155][['Sign']].rename(columns={'Sign': 'Gloss'})
top_250_df = pd.concat([top_250_df, extra_51_words], ignore_index=True)
top_250_df.head()
# Out:
#   Gloss
# 0   YOU
# 1    HE
# 2   SHE
# 3    IT
# 4    WE

# %%
len(top_250_df)
# Out:
# 250

# %%
len(df_103_research)
# Out:
# 103

# %%
common = (
    set(top_250_df['Gloss'].str.strip().str.lower()) &
    set(df1['Gloss'].str.strip().str.lower())
)

len(common)
# Out:
# 28

# %%
common = set(
    top_250_df['Gloss'].str.strip().str.lower()
) & set(
    df1['Gloss'].str.strip().str.lower()
)

top_250_df = top_250_df[
    ~top_250_df['Gloss'].str.strip().str.lower().isin(common)
]

top_250_df.head()
# Out:
#   Gloss
# 1    HE
# 2   SHE
# 3    IT
# 4    WE
# 5  THEY

# %%
len(top_250_df)
# Out:
# 220

# %%
extra_28_words = df_ref.iloc[156:184][['Sign']].rename(columns={'Sign': 'Gloss'})
top_250_df = pd.concat([top_250_df, extra_51_words], ignore_index=True)
top_250_df.head()
# Out:
#   Gloss
# 0    HE
# 1   SHE
# 2    IT
# 3    WE
# 4  THEY

# %%
len(top_250_df)
# Out:
# 271

# %%
cv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cv
#
# NameError: name 'cv' is not defined

# %%
common = set(top_250_df['Gloss']) & set(df1['Gloss'])
top_250_df = top_250_df[~top_250_df['Gloss'].isin(common)]
top_250_df.head()

# %%
len(top_250_df)

# %%
df_ref = pd.read_csv('sorted_mean_rating.csv')
extra_36_words = df_ref.iloc[104:140][['Sign']].rename(columns={'Sign': 'Gloss'})
top_250_df = pd.concat([top_250_df, extra_36_words], ignore_index=True)
top_250_df.head()

# %%
len(top_250_df)

# %%
common = set(df_103_research['Gloss']) & set(df1['Gloss'])
len(common)

# %%
merged_df = pd.concat([top_250_df, df_103_research,df1], ignore_index=True)
merged_df.head()

# %%
len(merged_df)

# %%
merged_df['Gloss'].duplicated().sum()

# %%
merged_df[merged_df['Gloss'].duplicated()]

# %%
merged_df.to_csv('500_Gloss_List.csv')
